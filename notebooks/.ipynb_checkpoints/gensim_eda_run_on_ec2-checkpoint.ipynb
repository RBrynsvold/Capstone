# %%
import os, codecs
import gensim
from gensim import corpora
from collections import defaultdict
import string
from string import punctuation
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
import pandas as pd
import numpy as np

# %% [markdown]
# ### THESE SHOULD BE ALL THE RELATIVE PATHS

# %%
source_dir = '/home/ubuntu/Capstone/books/clean/'

# %%
outputs_dir = '/home/ubuntu/Capstone/outputs/ec2/'

# %%
class IterFile(object):
    '''
    class object to do the iterating on individual book txt documents, including file i/o.
    '''
    
    def __init__(self, filepath):
        self.filepath = filepath
        
    def _open_file(self):
        self.file = codecs.open(self.filepath, 'r', encoding='utf_8')
        
    def _close_file(self):
        self.file.close()
    
    def __iter__(self):
        '''
        overwrite iteration to include file i/o
        '''
        self._open_file()
        
        for line in self.file:
            yield line
        
        self._close_file()

# %%
def transform_txt_file_v1(fname, root=source_dir):
    '''
    Initial pass at text transformation
    Reimplemented later (v2 etc) as a caller of various subfunctions to do all the transformation
    '''
    fp = root + fname

    book_as_lst = []
    for line in IterFile(fp):
        if line == "\n":
            pass
        else: 
            line_lst= [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
            book_as_lst.extend(line_lst)
            
    #add in stop word removal and frequency threshhold
    return book_as_lst

# %% [markdown]
# ## EDA Step 0: Test transform function with short book (Fall of the House of Usher)

# %%
usher = '932-clean.txt'
print transform_txt_file_v1(usher)
# Out:
# [u'the', u'fall', u'of', u'the', u'house', u'of', u'usher', u'son', u'coeur', u'est', u'un', u'luth', u'suspendu', u'sitot', u"qu'on", u'le', u'touche', u'il', u'resonne', u'de', u'beranger', u'during', u'the', u'whole', u'of', u'a', u'dull', u'dark', u'and', u'soundless', u'day', u'in', u'the', u'autumn', u'of', u'the', u'year', u'when', u'the', u'clouds', u'hung', u'oppressively', u'low', u'in', u'the', u'heavens', u'i', u'had', u'been', u'passing', u'alone', u'on', u'horseback', u'through', u'a', u'singularly', u'dreary', u'tract', u'of', u'country', u'and', u'at', u'length', u'found', u'myself', u'as', u'the', u'shades', u'of', u'the', u'evening', u'drew', u'on', u'within', u'view', u'of', u'the', u'melancholy', u'house', u'of', u'usher', u'i', u'know', u'not', u'how', u'it', u'was--but', u'with', u'the', u'first', u'glimpse', u'of', u'the', u'building', u'a', u'sense', u'of', u'insufferable', u'gloom', u'pervaded', u'my', u'spirit', u'i', u'say', u'insufferable', u'for', u'the', u'feeling', u'was', u'unrelieved', u'by', u'any', u'of', u'that', u'half-pleasureable', u'because', u'poetic', u'sentiment', u'with', u'which', u'the', u'mind', u'usually', u'receives', u'even', u'the', u'sternest', u'natural', u'images', u'of', u'the', u'desolate', u'or', u'terrible', u'i', u'looked', u'upon', u'the', u'scene', u'before', u'me--upon', u'the', u'mere', u'house', u'and', u'the', u'simple', u'landscape', u'features', u'of', u'the', u'domain--upon', u'the', u'bleak', u'walls--upon', u'the', u'vacant', u'eye-like', u'windows--upon', u'a', u'few', u'rank', u'sedges--and', u'upon', u'a', u'few', u'white', u'trunks', u'of', u'decayed', u'trees--with', u'an', u'utter', u'depression', u'of', u'soul', u'which', u'i', u'can', u'compare', u'to', u'no', u'earthly', u'sensation', u'more', u'properly', u'than', u'to', u'the', u'after-dream', u'of', u'the', u'reveller', u'upon', u'opium--the', u'bitter', u'lapse', u'into', u'everyday', u'life--the', u'hideous', u'dropping', u'off', u'of', u'the', u'veil', u'there', u'was', u'an', u'iciness', u'a', u'sinking', u'a', u'sickening', u'of', u'the', u'heart--an', u'unredeemed', u'dreariness', u'of', u'thought', u'which', u'no', u'goading', u'of', u'the', u'imagination', u'could', u'torture', u'into', u'aught', u'of', u'the', u'sublime', u'what', u'was', u'it--i', u'paused', u'to', u'think--what', u'was', u'it', u'that', u'so', u'unnerved', u'me', u'in', u'the', u'contemplation', u'of', u'the', u'house', u'of', u'usher', u'it', u'was', u'a', u'mystery', u'all', u'insoluble', u'nor', u'could', u'i', u'grapple', u'with', u'the', u'shadowy', u'fancies', u'that', u'crowded', u'upon', u'me', u'as', u'i', u'pondered', u'i', u'was', u'forced', u'to', u'fall', u'back', u'upon', u'the', u'unsatisfactory', u'conclusion', u'that', u'while', u'beyond', u'doubt', u'there', u'are', u'combinations', u'of', u'very', u'simple', u'natural', u'objects', u'which', u'have', u'the', u'power', u'of', u'thus', u'affecting', u'us', u'still', u'the', u'analysis', u'of', u'this', u'power', u'lies', u'among', u'considerations', u'beyond', u'our', u'depth', u'it', u'was', u'possible', u'i', u'reflected', u'that', u'a', u'mere', u'different', u'arrangement', u'of', u'the', u'particulars', u'of', u'the', u'scene', u'of', u'the', u'details', u'of', u'the', u'picture', u'would', u'be', u'sufficient', u'to', u'modify', u'or', u'perhaps', u'to', u'annihilate', u'its', u'capacity', u'for', u'sorrowful', u'impression', u'and', u'acting', u'upon', u'this', u'idea', u'i', u'reined', u'my', u'horse', u'to', u'the', u'precipitous', u'brink', u'of', u'a', u'black', u'and', u'lurid', u'tarn', u'that', u'lay', u'in', u'unruffled', u'lustre', u'by', u'the', u'dwelling', u'and', u'gazed', u'down--but', u'with', u'a', u'shudder', u'even', u'more', u'thrilling', u'than', u'before--upon', u'the', u'remodelled', u'and', u'inverted', u'images', u'of', u'the', u'grey', u'sedge', u'and', u'the', u'ghastly', u'tree-stems', u'and', u'the', u'vacant', u'and' ...

# %% [markdown]
# Get list of file names by using nltk... this feels a bit like cheating... should probably change this for final code

# %%
temp_corp = PlaintextCorpusReader(source_dir, '.*\.txt')
fileid_lst = temp_corp.fileids()
fileid_lst
# Out:
# ['10-clean.txt',
#  '100-clean.txt',
#  '105-clean.txt',
#  '108-clean.txt',
#  '1080-clean.txt',
#  '11-clean.txt',
#  '1112-clean.txt',
#  '1184-clean.txt',
#  '12-clean.txt',
#  '120-clean.txt',
#  '1232-clean.txt',
#  '1260-clean.txt',
#  '1322-clean.txt',
#  '1342-clean.txt',
#  '135-clean.txt',
#  '1399-clean.txt',
#  '140-clean.txt',
#  '1400-clean.txt',
#  '1404-clean.txt',
#  '14264-clean.txt',
#  '147-clean.txt',
#  '1497-clean.txt',
#  '15399-clean.txt',
#  '158-clean.txt',
#  '16-clean.txt',
#  '160-clean.txt',
#  '161-clean.txt',
#  '16382-clean.txt',
#  '1661-clean.txt',
#  '1727-clean.txt',
#  '174-clean.txt',
#  '1952-yellow_wallpaper-clean.txt',
#  '19942-clean.txt',
#  '20-clean.txt',
#  '20203-clean.txt',
#  '203-clean.txt',
#  '205-clean.txt',
#  '21279-clean.txt',
#  '2148-clean.txt',
#  '2174-clean.txt',
#  '219-clean.txt',
#  '224-clean.txt',
#  '23-clean.txt',
#  '236-clean.txt',
#  '2500-clean.txt',
#  '25305-clean.txt',
#  '2591-clean.txt',
#  '2600-clean.txt',
#  '2680-clean.txt',
#  '2701-moby-clean.txt',
#  '28054-clean.txt',
#  '2814-clean.txt',
#  '2852-clean.txt',
#  '28520-clean.txt',
#  '30360-clean.txt',
#  '30601-clean.txt',
#  '3207-clean.txt',
#  '33-clean.txt',
#  '33283-clean.txt',
#  '345-clean.txt',
#  '34901-clean.txt',
#  '35-clean.txt',
#  '36-clean.txt',
#  '3600-clean.txt',
#  '38427-clean.txt',
#  '408-clean.txt',
#  '41-clean.txt',
#  '42-clean.txt',
#  '4300-clean.txt',
#  '4363-clean.txt',
#  '45-clean.txt',
#  '4517-clean.txt',
#  '46-clean.txt',
#  '514-clean.txt',
#  '5200-clean.txt',
#  '521-clean.txt',
#  '526-clean.txt',
#  '55-clean.txt',
#  '55387-clean.txt',
#  '55404-clean.txt',
#  '6130-clean.txt',
#  '730-clean.txt',
#  '7370-clean.txt',
#  '74-clean.txt',
#  '76-clean.txt',
#  '768-clean.txt',
#  '829-clean.txt',
#  '84-clean.txt',
#  '844-clean.txt',
#  '851-clean.txt',
#  '863-clean.txt',
#  '8800-clean.txt',
#  '932-clean.txt',
#  '98-clean.txt',
#  '996-clean.txt']

# %% [markdown]
# ## EDA Step 1: Most basic transformation (tokenization only)

# %% [markdown]
# Apply transformation function to all books

# %%
all_transf_books_lst = []
for f in fileid_lst:
    all_transf_books_lst.append(transform_txt_file_v1(f))

all_transf_books_lst
# Out:
# [[u'the',
#   u'old',
#   u'testament',
#   u'of',
#   u'the',
#   u'king',
#   u'james',
#   u'version',
#   u'of',
#   u'the',
#   u'bible',
#   u'the',
#   u'first',
#   u'book',
#   u'of',
#   u'moses',
#   u'called',
#   u'genesis',
#   u'1:1',
#   u'in',
#   u'the',
#   u'beginning',
#   u'god',
#   u'created',
#   u'the',
#   u'heavens',
#   u'and',
#   u'the',
#   u'earth',
#   u'1:2',
#   u'and',
#   u'the',
#   u'earth',
#   u'was',
#   u'without',
#   u'form',
#   u'and',
#   u'void',
#   u'and',
#   u'darkness',
#   u'was',
#   u'upon',
#   u'the',
#   u'face',
#   u'of',
#   u'the',
#   u'deep',
#   u'and',
#   u'the',
#   u'spirit',
#   u'of',
#   u'god',
#   u'moved',
#   u'upon',
#   u'the',
#   u'face',
#   u'of',
#   u'the',
#   u'waters',
#   u'1:3',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'there',
#   u'be',
#   u'light',
#   u'and',
#   u'there',
#   u'was',
#   u'light',
#   u'1:4',
#   u'and',
#   u'god',
#   u'saw',
#   u'the',
#   u'light',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'and',
#   u'god',
#   u'divided',
#   u'the',
#   u'light',
#   u'from',
#   u'the',
#   u'darkness',
#   u'1:5',
#   u'and',
#   u'god',
#   u'called',
#   u'the',
#   u'light',
#   u'day',
#   u'and',
#   u'the',
#   u'darkness',
#   u'he',
#   u'called',
#   u'night',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'first',
#   u'day',
#   u'1:6',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'there',
#   u'be',
#   u'a',
#   u'firmament',
#   u'in',
#   u'the',
#   u'midst',
#   u'of',
#   u'the',
#   u'waters',
#   u'and',
#   u'let',
#   u'it',
#   u'divide',
#   u'the',
#   u'waters',
#   u'from',
#   u'the',
#   u'waters',
#   u'1:7',
#   u'and',
#   u'god',
#   u'made',
#   u'the',
#   u'firmament',
#   u'and',
#   u'divided',
#   u'the',
#   u'waters',
#   u'which',
#   u'were',
#   u'under',
#   u'the',
#   u'firmament',
#   u'from',
#   u'the',
#   u'waters',
#   u'which',
#   u'were',
#   u'above',
#   u'the',
#   u'firmament',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:8',
#   u'and',
#   u'god',
#   u'called',
#   u'the',
#   u'firmament',
#   u'heaven',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'second',
#   u'day',
#   u'1:9',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'the',
#   u'waters',
#   u'under',
#   u'the',
#   u'heaven',
#   u'be',
#   u'gathered',
#   u'together',
#   u'unto',
#   u'one',
#   u'place',
#   u'and',
#   u'let',
#   u'the',
#   u'dry',
#   u'land',
#   u'appear',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:10',
#   u'and',
#   u'god',
#   u'called',
#   u'the',
#   u'dry',
#   u'land',
#   u'earth',
#   u'and',
#   u'the',
#   u'gathering',
#   u'together',
#   u'of',
#   u'the',
#   u'waters',
#   u'called',
#   u'he',
#   u'seas',
#   u'and',
#   u'god',
#   u'saw',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'1:11',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'the',
#   u'earth',
#   u'bring',
#   u'forth',
#   u'grass',
#   u'the',
#   u'herb',
#   u'yielding',
#   u'seed',
#   u'and',
#   u'the',
#   u'fruit',
#   u'tree',
#   u'yielding',
#   u'fruit',
#   u'after',
#   u'his',
#   u'kind',
#   u'whose',
#   u'seed',
#   u'is',
#   u'in',
#   u'itself',
#   u'upon',
#   u'the',
#   u'earth',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:12',
#   u'and',
#   u'the',
#   u'earth',
#   u'brought',
#   u'forth',
#   u'grass',
#   u'and',
#   u'herb',
#   u'yielding',
#   u'seed',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'the',
#   u'tree',
#   u'yielding',
#   u'fruit',
#   u'whose',
#   u'seed',
#   u'was',
#   u'in',
#   u'itself',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'god',
#   u'saw',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'1:13',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'third',
#   u'day',
#   u'1:14',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'there',
#   u'be',
#   u'lights',
#   u'in',
#   u'the',
#   u'firmament',
#   u'of',
#   u'the',
#   u'heaven',
#   u'to',
#   u'divide',
#   u'the',
#   u'day',
#   u'from',
#   u'the',
#   u'night',
#   u'and',
#   u'let',
#   u'them',
#   u'be',
#   u'for',
#   u'signs',
#   u'and',
#   u'for',
#   u'seasons',
#   u'and',
#   u'for',
#   u'days',
#   u'and',
#   u'years',
#   u'1:15',
#   u'and',
#   u'let',
#   u'them',
#   u'be',
#   u'for',
#   u'lights',
#   u'in',
#   u'the',
#   u'firmament',
#   u'of',
#   u'the',
#   u'heaven',
#   u'to',
#   u'give',
#   u'light',
#   u'upon',
#   u'the',
#   u'earth',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:16',
#   u'and',
#   u'god',
#   u'made',
#   u'two',
#   u'great',
#   u'lights',
#   u'the',
#   u'greater',
#   u'light',
#   u'to',
#   u'rule',
#   u'the',
#   u'day',
#   u'and',
#   u'the',
#   u'lesser',
#   u'light',
#   u'to',
#   u'rule',
#   u'the',
#   u'night',
#   u'he',
#   u'made',
#   u'the',
#   u'stars',
#   u'also',
#   u'1:17',
#   u'and',
#   u'god',
#   u'set',
#   u'them',
#   u'in',
#   u'the',
#   u'firmament',
#   u'of',
#   u'the',
#   u'heaven',
#   u'to',
#   u'give',
#   u'light',
#   u'upon',
#   u'the',
#   u'earth',
#   u'1:18',
#   u'and',
#   u'to',
#   u'rule',
#   u'over',
#   u'the',
#   u'day',
#   u'and',
#   u'over',
#   u'the',
#   u'night',
#   u'and',
#   u'to',
#   u'divide',
#   u'the',
#   u'light',
#   u'from',
#   u'the',
#   u'darkness',
#   u'and',
#   u'god',
#   u'saw',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'1:19',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'fourth',
#   u'day',
#   u'1:20',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'the',
#   u'waters',
#   u'bring',
#   u'forth',
#   u'abundantly',
#   u'the',
#   u'moving',
#   u'creature',
#   u'that',
#   u'hath',
#   u'life',
#   u'and',
#   u'fowl',
#   u'that',
#   u'may',
#   u'fly',
#   u'above',
#   u'the',
#   u'earth',
#   u'in',
#   u'the',
#   u'open',
#   u'firmament',
#   u'of',
#   u'heaven',
#   u'1:21',
#   u'and',
#   u'god',
#   u'created',
#   u'great',
#   u'whales',
#   u'and',
#   u'every',
#   u'living',
#   u'creature',
#   u'that',
#   u'moveth',
#   u'which',
#   u'the',
#   u'waters',
#   u'brought',
#   u'forth',
#   u'abundantly',
#   u'after',
#   u'their',
#   u'kind',
#   u'and',
#   u'every',
#   u'winged',
#   u'fowl',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'god',
#   u'saw',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'1:22',
#   u'and',
#   u'god',
#   u'blessed',
#   u'them',
#   u'saying',
#   u'be',
#   u'fruitful',
#   u'and',
#   u'multiply',
#   u'and',
#   u'fill',
#   u'the',
#   u'waters',
#   u'in',
#   u'the',
#   u'seas',
#   u'and',
#   u'let',
#   u'fowl',
#   u'multiply',
#   u'in',
#   u'the',
#   u'earth',
#   u'1:23',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'fifth',
#   u'day',
#   u'1:24',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'the',
#   u'earth',
#   u'bring',
#   u'forth',
#   u'the',
#   u'living',
#   u'creature',
#   u'after',
#   u'his',
#   u'kind',
#   u'cattle',
#   u'and',
#   u'creeping',
#   u'thing',
#   u'and',
#   u'beast',
#   u'of',
#   u'the',
#   u'earth',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:25',
#   u'and',
#   u'god',
#   u'made',
#   u'the',
#   u'beast',
#   u'of',
#   u'the',
#   u'earth',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'cattle',
#   u'after',
#   u'their',
#   u'kind',
#   u'and',
#   u'every',
#   u'thing',
#   u'that',
#   u'creepeth',
#   u'upon',
#   u'the',
#   u'earth',
#   u'after',
#   u'his',
#   u'kind',
#   u'and',
#   u'god',
#   u'saw',
#   u'that',
#   u'it',
#   u'was',
#   u'good',
#   u'1:26',
#   u'and',
#   u'god',
#   u'said',
#   u'let',
#   u'us',
#   u'make',
#   u'man',
#   u'in',
#   u'our',
#   u'image',
#   u'after',
#   u'our',
#   u'likeness',
#   u'and',
#   u'let',
#   u'them',
#   u'have',
#   u'dominion',
#   u'over',
#   u'the',
#   u'fish',
#   u'of',
#   u'the',
#   u'sea',
#   u'and',
#   u'over',
#   u'the',
#   u'fowl',
#   u'of',
#   u'the',
#   u'air',
#   u'and',
#   u'over',
#   u'the',
#   u'cattle',
#   u'and',
#   u'over',
#   u'all',
#   u'the',
#   u'earth',
#   u'and',
#   u'over',
#   u'every',
#   u'creeping',
#   u'thing',
#   u'that',
#   u'creepeth',
#   u'upon',
#   u'the',
#   u'earth',
#   u'1:27',
#   u'so',
#   u'god',
#   u'created',
#   u'man',
#   u'in',
#   u'his',
#   u'own',
#   u'image',
#   u'in',
#   u'the',
#   u'image',
#   u'of',
#   u'god',
#   u'created',
#   u'he',
#   u'him',
#   u'male',
#   u'and',
#   u'female',
#   u'created',
#   u'he',
#   u'them',
#   u'1:28',
#   u'and',
#   u'god',
#   u'blessed',
#   u'them',
#   u'and',
#   u'god',
#   u'said',
#   u'unto',
#   u'them',
#   u'be',
#   u'fruitful',
#   u'and',
#   u'multiply',
#   u'and',
#   u'replenish',
#   u'the',
#   u'earth',
#   u'and',
#   u'subdue',
#   u'it',
#   u'and',
#   u'have',
#   u'dominion',
#   u'over',
#   u'the',
#   u'fish',
#   u'of',
#   u'the',
#   u'sea',
#   u'and',
#   u'over',
#   u'the',
#   u'fowl',
#   u'of',
#   u'the',
#   u'air',
#   u'and',
#   u'over',
#   u'every',
#   u'living',
#   u'thing',
#   u'that',
#   u'moveth',
#   u'upon',
#   u'the',
#   u'earth',
#   u'1:29',
#   u'and',
#   u'god',
#   u'said',
#   u'behold',
#   u'i',
#   u'have',
#   u'given',
#   u'you',
#   u'every',
#   u'herb',
#   u'bearing',
#   u'seed',
#   u'which',
#   u'is',
#   u'upon',
#   u'the',
#   u'face',
#   u'of',
#   u'all',
#   u'the',
#   u'earth',
#   u'and',
#   u'every',
#   u'tree',
#   u'in',
#   u'the',
#   u'which',
#   u'is',
#   u'the',
#   u'fruit',
#   u'of',
#   u'a',
#   u'tree',
#   u'yielding',
#   u'seed',
#   u'to',
#   u'you',
#   u'it',
#   u'shall',
#   u'be',
#   u'for',
#   u'meat',
#   u'1:30',
#   u'and',
#   u'to',
#   u'every',
#   u'beast',
#   u'of',
#   u'the',
#   u'earth',
#   u'and',
#   u'to',
#   u'every',
#   u'fowl',
#   u'of',
#   u'the',
#   u'air',
#   u'and',
#   u'to',
#   u'every',
#   u'thing',
#   u'that',
#   u'creepeth',
#   u'upon',
#   u'the',
#   u'earth',
#   u'wherein',
#   u'there',
#   u'is',
#   u'life',
#   u'i',
#   u'have',
#   u'given',
#   u'every',
#   u'green',
#   u'herb',
#   u'for',
#   u'meat',
#   u'and',
#   u'it',
#   u'was',
#   u'so',
#   u'1:31',
#   u'and',
#   u'god',
#   u'saw',
#   u'every',
#   u'thing',
#   u'that',
#   u'he',
#   u'had',
#   u'made',
#   u'and',
#   u'behold',
#   u'it',
#   u'was',
#   u'very',
#   u'good',
#   u'and',
#   u'the',
#   u'evening',
#   u'and',
#   u'the',
#   u'morning',
#   u'were',
#   u'the',
#   u'sixth',
#   u'day',
#   u'2:1',
#   u'thus',
#   u'the',
#   u'heavens',
#   u'and',
#   u'the',
#   u'earth',
#   u'were',
#   u'finished',
#   u'and',
#   u'all',
#   u'the',
#   u'host',
#   u'of',
#   u'them',
#   u'2:2',
#   u'and',
#   u'on',
#   u'the',
#   u'seventh',
#   u'day',
#   u'god',
#   u'ended',
#   u'his',
#   u'work',
#   u'which',
#   u'he',
#   u'had',
#   u'made',
#   u'and',
#   u'he',
#   u'rested',
#   u'on',
#   u'the',
#   u'seventh',
#   u'day',
#   u'from',
#   u'all',
#   u'his',
#   u'work',
#   u'which',
#   u'he',
#   u'had',
#   u'made',
#   u'2:3',
#   u'and',
#   u'god',
#   u'blessed',
#   u'the',
#   u'seventh',
#   u'day',
#   u'and',
#   u'sanctified',
#   u'it',
#   u'because',
#   u'that',
#   u'in',
#   u'it',
#   u'he',
#   u'had',
#   u'rested',
#   u'from',
#   u'all',
#   u'his',
#   u'work',
#   u'which',
#   u'god',
#   u'created',
#   u'and',
#   u'made',
#   u'2:4',
#   u'these',
#   u'are',
#   u'the',
#   u'generations',
#   u'of',
#   u'the',
#   u'heavens',
#   u'and',
#   u'of',
#   u'the',
#   u'earth',
#   u'when',
#   u'they',
#   u'were',
#   u'created',
#   u'in',
#   u'the',
#   u'day',
#   u'that',
#   u'the',
#   u'lord',
#   u'god',
#   u'made',
#   u'the',
#   u'earth',
#   u'and',
#   u'the',
#   u'heavens',
#   u'2:5',
#   u'and',
#   u'every',
#   u'plant',
#   u'of',
#   u'the',
#   u'field',
#   u'before',
#   u'it',
#   u'was',
#   u'in',
#   u'the',
#   u'earth',
#   u'and',
#   u'every',
#   u'herb',
#   u'of',
#   u'the',
#   u'field',
#   u'before',
#   u'it',
#   u'grew',
#   u'for',
#   u'the',
#   u'lord',
#   u'god',
#   u'had',
#   u'not',
#   u'caused',
#   u'it',
#   u'to',
#   u'rain',
#   u'upon',
#   u'the',
#   u'earth',
#   u'and',
#   u'there',
#   u'was',
#   u'not',
#   u'a',
#   u'man',
#   u'to',
#   u'till',
#   u'the',
#   u'ground',
#   u'2:6',
#   u'but',
#   u'there',
#   u'went',
#   u'up',
#   u'a',
#   u'mist',
#   u'from',
#   u'the',
#   u'earth',
#   ...],
#  [u'1609',
#   u'the',
#   u'sonnets',
#   u'by',
#   u'william',
#   u'shakespeare',
#   u'1',
#   u'from',
#   u'fairest',
#   u'creatures',
#   u'we',
#   u'desire',
#   u'increase',
#   u'that',
#   u'thereby',
#   u"beauty's",
#   u'rose',
#   u'might',
#   u'never',
#   u'die',
#   u'but',
#   u'as',
#   u'the',
#   u'riper',
#   u'should',
#   u'by',
#   u'time',
#   u'decease',
#   u'his',
#   u'tender',
#   u'heir',
#   u'might',
#   u'bear',
#   u'his',
#   u'memory',
#   u'but',
#   u'thou',
#   u'contracted',
#   u'to',
#   u'thine',
#   u'own',
#   u'bright',
#   u'eyes',
#   u"feed'st",
#   u'thy',
#   u"light's",
#   u'flame',
#   u'with',
#   u'self-substantial',
#   u'fuel',
#   u'making',
#   u'a',
#   u'famine',
#   u'where',
#   u'abundance',
#   u'lies',
#   u'thy',
#   u'self',
#   u'thy',
#   u'foe',
#   u'to',
#   u'thy',
#   u'sweet',
#   u'self',
#   u'too',
#   u'cruel',
#   u'thou',
#   u'that',
#   u'art',
#   u'now',
#   u'the',
#   u"world's",
#   u'fresh',
#   u'ornament',
#   u'and',
#   u'only',
#   u'herald',
#   u'to',
#   u'the',
#   u'gaudy',
#   u'spring',
#   u'within',
#   u'thine',
#   u'own',
#   u'bud',
#   u'buriest',
#   u'thy',
#   u'content',
#   u'and',
#   u'tender',
#   u'churl',
#   u"mak'st",
#   u'waste',
#   u'in',
#   u'niggarding',
#   u'pity',
#   u'the',
#   u'world',
#   u'or',
#   u'else',
#   u'this',
#   u'glutton',
#   u'be',
#   u'to',
#   u'eat',
#   u'the',
#   u"world's",
#   u'due',
#   u'by',
#   u'the',
#   u'grave',
#   u'and',
#   u'thee',
#   u'2',
#   u'when',
#   u'forty',
#   u'winters',
#   u'shall',
#   u'besiege',
#   u'thy',
#   u'brow',
#   u'and',
#   u'dig',
#   u'deep',
#   u'trenches',
#   u'in',
#   u'thy',
#   u"beauty's",
#   u'field',
#   u'thy',
#   u"youth's",
#   u'proud',
#   u'livery',
#   u'so',
#   u'gazed',
#   u'on',
#   u'now',
#   u'will',
#   u'be',
#   u'a',
#   u'tattered',
#   u'weed',
#   u'of',
#   u'small',
#   u'worth',
#   u'held',
#   u'then',
#   u'being',
#   u'asked',
#   u'where',
#   u'all',
#   u'thy',
#   u'beauty',
#   u'lies',
#   u'where',
#   u'all',
#   u'the',
#   u'treasure',
#   u'of',
#   u'thy',
#   u'lusty',
#   u'days',
#   u'to',
#   u'say',
#   u'within',
#   u'thine',
#   u'own',
#   u'deep',
#   u'sunken',
#   u'eyes',
#   u'were',
#   u'an',
#   u'all-eating',
#   u'shame',
#   u'and',
#   u'thriftless',
#   u'praise',
#   u'how',
#   u'much',
#   u'more',
#   u'praise',
#   u'deserved',
#   u'thy',
#   u"beauty's",
#   u'use',
#   u'if',
#   u'thou',
#   u'couldst',
#   u'answer',
#   u'this',
#   u'fair',
#   u'child',
#   u'of',
#   u'mine',
#   u'shall',
#   u'sum',
#   u'my',
#   u'count',
#   u'and',
#   u'make',
#   u'my',
#   u'old',
#   u'excuse',
#   u'proving',
#   u'his',
#   u'beauty',
#   u'by',
#   u'succession',
#   u'thine',
#   u'this',
#   u'were',
#   u'to',
#   u'be',
#   u'new',
#   u'made',
#   u'when',
#   u'thou',
#   u'art',
#   u'old',
#   u'and',
#   u'see',
#   u'thy',
#   u'blood',
#   u'warm',
#   u'when',
#   u'thou',
#   u"feel'st",
#   u'it',
#   u'cold',
#   u'3',
#   u'look',
#   u'in',
#   u'thy',
#   u'glass',
#   u'and',
#   u'tell',
#   u'the',
#   u'face',
#   u'thou',
#   u'viewest',
#   u'now',
#   u'is',
#   u'the',
#   u'time',
#   u'that',
#   u'face',
#   u'should',
#   u'form',
#   u'another',
#   u'whose',
#   u'fresh',
#   u'repair',
#   u'if',
#   u'now',
#   u'thou',
#   u'not',
#   u'renewest',
#   u'thou',
#   u'dost',
#   u'beguile',
#   u'the',
#   u'world',
#   u'unbless',
#   u'some',
#   u'mother',
#   u'for',
#   u'where',
#   u'is',
#   u'she',
#   u'so',
#   u'fair',
#   u'whose',
#   u'uneared',
#   u'womb',
#   u'disdains',
#   u'the',
#   u'tillage',
#   u'of',
#   u'thy',
#   u'husbandry',
#   u'or',
#   u'who',
#   u'is',
#   u'he',
#   u'so',
#   u'fond',
#   u'will',
#   u'be',
#   u'the',
#   u'tomb',
#   u'of',
#   u'his',
#   u'self-love',
#   u'to',
#   u'stop',
#   u'posterity',
#   u'thou',
#   u'art',
#   u'thy',
#   u"mother's",
#   u'glass',
#   u'and',
#   u'she',
#   u'in',
#   u'thee',
#   u'calls',
#   u'back',
#   u'the',
#   u'lovely',
#   u'april',
#   u'of',
#   u'her',
#   u'prime',
#   u'so',
#   u'thou',
#   u'through',
#   u'windows',
#   u'of',
#   u'thine',
#   u'age',
#   u'shalt',
#   u'see',
#   u'despite',
#   u'of',
#   u'wrinkles',
#   u'this',
#   u'thy',
#   u'golden',
#   u'time',
#   u'but',
#   u'if',
#   u'thou',
#   u'live',
#   u'remembered',
#   u'not',
#   u'to',
#   u'be',
#   u'die',
#   u'single',
#   u'and',
#   u'thine',
#   u'image',
#   u'dies',
#   u'with',
#   u'thee',
#   u'4',
#   u'unthrifty',
#   u'loveliness',
#   u'why',
#   u'dost',
#   u'thou',
#   u'spend',
#   u'upon',
#   u'thy',
#   u'self',
#   u'thy',
#   u"beauty's",
#   u'legacy',
#   u"nature's",
#   u'bequest',
#   u'gives',
#   u'nothing',
#   u'but',
#   u'doth',
#   u'lend',
#   u'and',
#   u'being',
#   u'frank',
#   u'she',
#   u'lends',
#   u'to',
#   u'those',
#   u'are',
#   u'free',
#   u'then',
#   u'beauteous',
#   u'niggard',
#   u'why',
#   u'dost',
#   u'thou',
#   u'abuse',
#   u'the',
#   u'bounteous',
#   u'largess',
#   u'given',
#   u'thee',
#   u'to',
#   u'give',
#   u'profitless',
#   u'usurer',
#   u'why',
#   u'dost',
#   u'thou',
#   u'use',
#   u'so',
#   u'great',
#   u'a',
#   u'sum',
#   u'of',
#   u'sums',
#   u'yet',
#   u'canst',
#   u'not',
#   u'live',
#   u'for',
#   u'having',
#   u'traffic',
#   u'with',
#   u'thy',
#   u'self',
#   u'alone',
#   u'thou',
#   u'of',
#   u'thy',
#   u'self',
#   u'thy',
#   u'sweet',
#   u'self',
#   u'dost',
#   u'deceive',
#   u'then',
#   u'how',
#   u'when',
#   u'nature',
#   u'calls',
#   u'thee',
#   u'to',
#   u'be',
#   u'gone',
#   u'what',
#   u'acceptable',
#   u'audit',
#   u'canst',
#   u'thou',
#   u'leave',
#   u'thy',
#   u'unused',
#   u'beauty',
#   u'must',
#   u'be',
#   u'tombed',
#   u'with',
#   u'thee',
#   u'which',
#   u'used',
#   u'lives',
#   u'th',
#   u'executor',
#   u'to',
#   u'be',
#   u'5',
#   u'those',
#   u'hours',
#   u'that',
#   u'with',
#   u'gentle',
#   u'work',
#   u'did',
#   u'frame',
#   u'the',
#   u'lovely',
#   u'gaze',
#   u'where',
#   u'every',
#   u'eye',
#   u'doth',
#   u'dwell',
#   u'will',
#   u'play',
#   u'the',
#   u'tyrants',
#   u'to',
#   u'the',
#   u'very',
#   u'same',
#   u'and',
#   u'that',
#   u'unfair',
#   u'which',
#   u'fairly',
#   u'doth',
#   u'excel',
#   u'for',
#   u'never-resting',
#   u'time',
#   u'leads',
#   u'summer',
#   u'on',
#   u'to',
#   u'hideous',
#   u'winter',
#   u'and',
#   u'confounds',
#   u'him',
#   u'there',
#   u'sap',
#   u'checked',
#   u'with',
#   u'frost',
#   u'and',
#   u'lusty',
#   u'leaves',
#   u'quite',
#   u'gone',
#   u'beauty',
#   u"o'er-snowed",
#   u'and',
#   u'bareness',
#   u'every',
#   u'where',
#   u'then',
#   u'were',
#   u'not',
#   u"summer's",
#   u'distillation',
#   u'left',
#   u'a',
#   u'liquid',
#   u'prisoner',
#   u'pent',
#   u'in',
#   u'walls',
#   u'of',
#   u'glass',
#   u"beauty's",
#   u'effect',
#   u'with',
#   u'beauty',
#   u'were',
#   u'bereft',
#   u'nor',
#   u'it',
#   u'nor',
#   u'no',
#   u'remembrance',
#   u'what',
#   u'it',
#   u'was',
#   u'but',
#   u'flowers',
#   u'distilled',
#   u'though',
#   u'they',
#   u'with',
#   u'winter',
#   u'meet',
#   u'leese',
#   u'but',
#   u'their',
#   u'show',
#   u'their',
#   u'substance',
#   u'still',
#   u'lives',
#   u'sweet',
#   u'6',
#   u'then',
#   u'let',
#   u'not',
#   u"winter's",
#   u'ragged',
#   u'hand',
#   u'deface',
#   u'in',
#   u'thee',
#   u'thy',
#   u'summer',
#   u'ere',
#   u'thou',
#   u'be',
#   u'distilled',
#   u'make',
#   u'sweet',
#   u'some',
#   u'vial',
#   u'treasure',
#   u'thou',
#   u'some',
#   u'place',
#   u'with',
#   u"beauty's",
#   u'treasure',
#   u'ere',
#   u'it',
#   u'be',
#   u'self-killed',
#   u'that',
#   u'use',
#   u'is',
#   u'not',
#   u'forbidden',
#   u'usury',
#   u'which',
#   u'happies',
#   u'those',
#   u'that',
#   u'pay',
#   u'the',
#   u'willing',
#   u'loan',
#   u"that's",
#   u'for',
#   u'thy',
#   u'self',
#   u'to',
#   u'breed',
#   u'another',
#   u'thee',
#   u'or',
#   u'ten',
#   u'times',
#   u'happier',
#   u'be',
#   u'it',
#   u'ten',
#   u'for',
#   u'one',
#   u'ten',
#   u'times',
#   u'thy',
#   u'self',
#   u'were',
#   u'happier',
#   u'than',
#   u'thou',
#   u'art',
#   u'if',
#   u'ten',
#   u'of',
#   u'thine',
#   u'ten',
#   u'times',
#   u'refigured',
#   u'thee',
#   u'then',
#   u'what',
#   u'could',
#   u'death',
#   u'do',
#   u'if',
#   u'thou',
#   u'shouldst',
#   u'depart',
#   u'leaving',
#   u'thee',
#   u'living',
#   u'in',
#   u'posterity',
#   u'be',
#   u'not',
#   u'self-willed',
#   u'for',
#   u'thou',
#   u'art',
#   u'much',
#   u'too',
#   u'fair',
#   u'to',
#   u'be',
#   u"death's",
#   u'conquest',
#   u'and',
#   u'make',
#   u'worms',
#   u'thine',
#   u'heir',
#   u'7',
#   u'lo',
#   u'in',
#   u'the',
#   u'orient',
#   u'when',
#   u'the',
#   u'gracious',
#   u'light',
#   u'lifts',
#   u'up',
#   u'his',
#   u'burning',
#   u'head',
#   u'each',
#   u'under',
#   u'eye',
#   u'doth',
#   u'homage',
#   u'to',
#   u'his',
#   u'new-appearing',
#   u'sight',
#   u'serving',
#   u'with',
#   u'looks',
#   u'his',
#   u'sacred',
#   u'majesty',
#   u'and',
#   u'having',
#   u'climbed',
#   u'the',
#   u'steep-up',
#   u'heavenly',
#   u'hill',
#   u'resembling',
#   u'strong',
#   u'youth',
#   u'in',
#   u'his',
#   u'middle',
#   u'age',
#   u'yet',
#   u'mortal',
#   u'looks',
#   u'adore',
#   u'his',
#   u'beauty',
#   u'still',
#   u'attending',
#   u'on',
#   u'his',
#   u'golden',
#   u'pilgrimage',
#   u'but',
#   u'when',
#   u'from',
#   u'highmost',
#   u'pitch',
#   u'with',
#   u'weary',
#   u'car',
#   u'like',
#   u'feeble',
#   u'age',
#   u'he',
#   u'reeleth',
#   u'from',
#   u'the',
#   u'day',
#   u'the',
#   u'eyes',
#   u'fore',
#   u'duteous',
#   u'now',
#   u'converted',
#   u'are',
#   u'from',
#   u'his',
#   u'low',
#   u'tract',
#   u'and',
#   u'look',
#   u'another',
#   u'way',
#   u'so',
#   u'thou',
#   u'thy',
#   u'self',
#   u'out-going',
#   u'in',
#   u'thy',
#   u'noon',
#   u'unlooked',
#   u'on',
#   u'diest',
#   u'unless',
#   u'thou',
#   u'get',
#   u'a',
#   u'son',
#   u'8',
#   u'music',
#   u'to',
#   u'hear',
#   u'why',
#   u"hear'st",
#   u'thou',
#   u'music',
#   u'sadly',
#   u'sweets',
#   u'with',
#   u'sweets',
#   u'war',
#   u'not',
#   u'joy',
#   u'delights',
#   u'in',
#   u'joy',
#   u'why',
#   u"lov'st",
#   u'thou',
#   u'that',
#   u'which',
#   u'thou',
#   u"receiv'st",
#   u'not',
#   u'gladly',
#   u'or',
#   u'else',
#   u"receiv'st",
#   u'with',
#   u'pleasure',
#   u'thine',
#   u'annoy',
#   u'if',
#   u'the',
#   u'true',
#   u'concord',
#   u'of',
#   u'well-tuned',
#   u'sounds',
#   u'by',
#   u'unions',
#   u'married',
#   u'do',
#   u'offend',
#   u'thine',
#   u'ear',
#   u'they',
#   u'do',
#   u'but',
#   u'sweetly',
#   u'chide',
#   u'thee',
#   u'who',
#   u'confounds',
#   u'in',
#   u'singleness',
#   u'the',
#   u'parts',
#   u'that',
#   u'thou',
#   u'shouldst',
#   u'bear',
#   u'mark',
#   u'how',
#   u'one',
#   u'string',
#   u'sweet',
#   u'husband',
#   u'to',
#   u'another',
#   u'strikes',
#   u'each',
#   u'in',
#   u'each',
#   u'by',
#   u'mutual',
#   u'ordering',
#   u'resembling',
#   u'sire',
#   u'and',
#   u'child',
#   u'and',
#   u'happy',
#   u'mother',
#   u'who',
#   u'all',
#   u'in',
#   u'one',
#   u'one',
#   u'pleasing',
#   u'note',
#   u'do',
#   u'sing',
#   u'whose',
#   u'speechless',
#   u'song',
#   u'being',
#   u'many',
#   u'seeming',
#   u'one',
#   u'sings',
#   u'this',
#   u'to',
#   u'thee',
#   u'thou',
#   u'single',
#   u'wilt',
#   u'prove',
#   u'none',
#   u'9',
#   u'is',
#   u'it',
#   u'for',
#   u'fear',
#   u'to',
#   u'wet',
#   u'a',
#   u"widow's",
#   u'eye',
#   u'that',
#   u'thou',
#   u"consum'st",
#   u'thy',
#   u'self',
#   u'in',
#   u'single',
#   u'life',
#   u'ah',
#   u'if',
#   u'thou',
#   u'issueless',
#   u'shalt',
#   u'hap',
#   u'to',
#   u'die',
#   u'the',
#   u'world',
#   u'will',
#   u'wail',
#   u'thee',
#   u'like',
#   u'a',
#   u'makeless',
#   u'wife',
#   u'the',
#   u'world',
#   u'will',
#   u'be',
#   u'thy',
#   u'widow',
#   u'and',
#   u'still',
#   u'weep',
#   u'that',
#   u'thou',
#   u'no',
#   u'form',
#   u'of',
#   u'thee',
#   u'hast',
#   u'left',
#   u'behind',
#   u'when',
#   u'every',
#   u'private',
#   u'widow',
#   u'well',
#   u'may',
#   u'keep',
#   u'by',
#   u"children's",
#   u'eyes',
#   u'her',
#   u"husband's",
#   u'shape',
#   u'in',
#   u'mind',
#   u'look',
#   u'what',
#   u'an',
#   u'unthrift',
#   u'in',
#   u'the',
#   u'world',
#   u'doth',
#   u'spend',
#   u'shifts',
#   u'but',
#   u'his',
#   u'place',
#   u'for',
#   u'still',
#   u'the',
#   u'world',
#   u'enjoys',
#   u'it',
#   u'but',
#   u"beauty's",
#   u'waste',
#   u'hath',
#   u'in',
#   u'the',
#   u'world',
#   u'an',
#   u'end',
#   u'and',
#   u'kept',
#   u'unused',
#   u'the',
#   u'user',
#   u'so',
#   u'destroys',
#   u'it',
#   u'no',
#   u'love',
#   u'toward',
#   u'others',
#   u'in',
#   u'that',
#   u'bosom',
#   u'sits',
#   u'that',
#   u'on',
#   u'himself',
#   u'such',
#   u"murd'rous",
#   u'shame',
#   u'commits',
#   u'10',
#   u'for',
#   ...],
#  [u'by',
#   u'al',
#   u'haines',
#   u'persuasion',
#   u'by',
#   u'jane',
#   u'austen',
#   u'1818',
#   u'chapter',
#   u'1',
#   u'sir',
#   u'walter',
#   u'elliot',
#   u'of',
#   u'kellynch',
#   u'hall',
#   u'in',
#   u'somersetshire',
#   u'was',
#   u'a',
#   u'man',
#   u'who',
#   u'for',
#   u'his',
#   u'own',
#   u'amusement',
#   u'never',
#   u'took',
#   u'up',
#   u'any',
#   u'book',
#   u'but',
#   u'the',
#   u'baronetage',
#   u'there',
#   u'he',
#   u'found',
#   u'occupation',
#   u'for',
#   u'an',
#   u'idle',
#   u'hour',
#   u'and',
#   u'consolation',
#   u'in',
#   u'a',
#   u'distressed',
#   u'one',
#   u'there',
#   u'his',
#   u'faculties',
#   u'were',
#   u'roused',
#   u'into',
#   u'admiration',
#   u'and',
#   u'respect',
#   u'by',
#   u'contemplating',
#   u'the',
#   u'limited',
#   u'remnant',
#   u'of',
#   u'the',
#   u'earliest',
#   u'patents',
#   u'there',
#   u'any',
#   u'unwelcome',
#   u'sensations',
#   u'arising',
#   u'from',
#   u'domestic',
#   u'affairs',
#   u'changed',
#   u'naturally',
#   u'into',
#   u'pity',
#   u'and',
#   u'contempt',
#   u'as',
#   u'he',
#   u'turned',
#   u'over',
#   u'the',
#   u'almost',
#   u'endless',
#   u'creations',
#   u'of',
#   u'the',
#   u'last',
#   u'century',
#   u'and',
#   u'there',
#   u'if',
#   u'every',
#   u'other',
#   u'leaf',
#   u'were',
#   u'powerless',
#   u'he',
#   u'could',
#   u'read',
#   u'his',
#   u'own',
#   u'history',
#   u'with',
#   u'an',
#   u'interest',
#   u'which',
#   u'never',
#   u'failed',
#   u'this',
#   u'was',
#   u'the',
#   u'page',
#   u'at',
#   u'which',
#   u'the',
#   u'favourite',
#   u'volume',
#   u'always',
#   u'opened',
#   u'elliot',
#   u'of',
#   u'kellynch',
#   u'hall',
#   u'walter',
#   u'elliot',
#   u'born',
#   u'march',
#   u'1',
#   u'1760',
#   u'married',
#   u'july',
#   u'15',
#   u'1784',
#   u'elizabeth',
#   u'daughter',
#   u'of',
#   u'james',
#   u'stevenson',
#   u'esq',
#   u'of',
#   u'south',
#   u'park',
#   u'in',
#   u'the',
#   u'county',
#   u'of',
#   u'gloucester',
#   u'by',
#   u'which',
#   u'lady',
#   u'who',
#   u'died',
#   u'1800',
#   u'he',
#   u'has',
#   u'issue',
#   u'elizabeth',
#   u'born',
#   u'june',
#   u'1',
#   u'1785',
#   u'anne',
#   u'born',
#   u'august',
#   u'9',
#   u'1787',
#   u'a',
#   u'still-born',
#   u'son',
#   u'november',
#   u'5',
#   u'1789',
#   u'mary',
#   u'born',
#   u'november',
#   u'20',
#   u'1791',
#   u'precisely',
#   u'such',
#   u'had',
#   u'the',
#   u'paragraph',
#   u'originally',
#   u'stood',
#   u'from',
#   u'the',
#   u"printer's",
#   u'hands',
#   u'but',
#   u'sir',
#   u'walter',
#   u'had',
#   u'improved',
#   u'it',
#   u'by',
#   u'adding',
#   u'for',
#   u'the',
#   u'information',
#   u'of',
#   u'himself',
#   u'and',
#   u'his',
#   u'family',
#   u'these',
#   u'words',
#   u'after',
#   u'the',
#   u'date',
#   u'of',
#   u"mary's",
#   u'birth',
#   u'married',
#   u'december',
#   u'16',
#   u'1810',
#   u'charles',
#   u'son',
#   u'and',
#   u'heir',
#   u'of',
#   u'charles',
#   u'musgrove',
#   u'esq',
#   u'of',
#   u'uppercross',
#   u'in',
#   u'the',
#   u'county',
#   u'of',
#   u'somerset',
#   u'and',
#   u'by',
#   u'inserting',
#   u'most',
#   u'accurately',
#   u'the',
#   u'day',
#   u'of',
#   u'the',
#   u'month',
#   u'on',
#   u'which',
#   u'he',
#   u'had',
#   u'lost',
#   u'his',
#   u'wife',
#   u'then',
#   u'followed',
#   u'the',
#   u'history',
#   u'and',
#   u'rise',
#   u'of',
#   u'the',
#   u'ancient',
#   u'and',
#   u'respectable',
#   u'family',
#   u'in',
#   u'the',
#   u'usual',
#   u'terms',
#   u'how',
#   u'it',
#   u'had',
#   u'been',
#   u'first',
#   u'settled',
#   u'in',
#   u'cheshire',
#   u'how',
#   u'mentioned',
#   u'in',
#   u'dugdale',
#   u'serving',
#   u'the',
#   u'office',
#   u'of',
#   u'high',
#   u'sheriff',
#   u'representing',
#   u'a',
#   u'borough',
#   u'in',
#   u'three',
#   u'successive',
#   u'parliaments',
#   u'exertions',
#   u'of',
#   u'loyalty',
#   u'and',
#   u'dignity',
#   u'of',
#   u'baronet',
#   u'in',
#   u'the',
#   u'first',
#   u'year',
#   u'of',
#   u'charles',
#   u'ii',
#   u'with',
#   u'all',
#   u'the',
#   u'marys',
#   u'and',
#   u'elizabeths',
#   u'they',
#   u'had',
#   u'married',
#   u'forming',
#   u'altogether',
#   u'two',
#   u'handsome',
#   u'duodecimo',
#   u'pages',
#   u'and',
#   u'concluding',
#   u'with',
#   u'the',
#   u'arms',
#   u'and',
#   u'motto:--"principal',
#   u'seat',
#   u'kellynch',
#   u'hall',
#   u'in',
#   u'the',
#   u'county',
#   u'of',
#   u'somerset',
#   u'and',
#   u'sir',
#   u"walter's",
#   u'handwriting',
#   u'again',
#   u'in',
#   u'this',
#   u'finale',
#   u'heir',
#   u'presumptive',
#   u'william',
#   u'walter',
#   u'elliot',
#   u'esq',
#   u'great',
#   u'grandson',
#   u'of',
#   u'the',
#   u'second',
#   u'sir',
#   u'walter',
#   u'vanity',
#   u'was',
#   u'the',
#   u'beginning',
#   u'and',
#   u'the',
#   u'end',
#   u'of',
#   u'sir',
#   u'walter',
#   u"elliot's",
#   u'character',
#   u'vanity',
#   u'of',
#   u'person',
#   u'and',
#   u'of',
#   u'situation',
#   u'he',
#   u'had',
#   u'been',
#   u'remarkably',
#   u'handsome',
#   u'in',
#   u'his',
#   u'youth',
#   u'and',
#   u'at',
#   u'fifty-four',
#   u'was',
#   u'still',
#   u'a',
#   u'very',
#   u'fine',
#   u'man',
#   u'few',
#   u'women',
#   u'could',
#   u'think',
#   u'more',
#   u'of',
#   u'their',
#   u'personal',
#   u'appearance',
#   u'than',
#   u'he',
#   u'did',
#   u'nor',
#   u'could',
#   u'the',
#   u'valet',
#   u'of',
#   u'any',
#   u'new',
#   u'made',
#   u'lord',
#   u'be',
#   u'more',
#   u'delighted',
#   u'with',
#   u'the',
#   u'place',
#   u'he',
#   u'held',
#   u'in',
#   u'society',
#   u'he',
#   u'considered',
#   u'the',
#   u'blessing',
#   u'of',
#   u'beauty',
#   u'as',
#   u'inferior',
#   u'only',
#   u'to',
#   u'the',
#   u'blessing',
#   u'of',
#   u'a',
#   u'baronetcy',
#   u'and',
#   u'the',
#   u'sir',
#   u'walter',
#   u'elliot',
#   u'who',
#   u'united',
#   u'these',
#   u'gifts',
#   u'was',
#   u'the',
#   u'constant',
#   u'object',
#   u'of',
#   u'his',
#   u'warmest',
#   u'respect',
#   u'and',
#   u'devotion',
#   u'his',
#   u'good',
#   u'looks',
#   u'and',
#   u'his',
#   u'rank',
#   u'had',
#   u'one',
#   u'fair',
#   u'claim',
#   u'on',
#   u'his',
#   u'attachment',
#   u'since',
#   u'to',
#   u'them',
#   u'he',
#   u'must',
#   u'have',
#   u'owed',
#   u'a',
#   u'wife',
#   u'of',
#   u'very',
#   u'superior',
#   u'character',
#   u'to',
#   u'any',
#   u'thing',
#   u'deserved',
#   u'by',
#   u'his',
#   u'own',
#   u'lady',
#   u'elliot',
#   u'had',
#   u'been',
#   u'an',
#   u'excellent',
#   u'woman',
#   u'sensible',
#   u'and',
#   u'amiable',
#   u'whose',
#   u'judgement',
#   u'and',
#   u'conduct',
#   u'if',
#   u'they',
#   u'might',
#   u'be',
#   u'pardoned',
#   u'the',
#   u'youthful',
#   u'infatuation',
#   u'which',
#   u'made',
#   u'her',
#   u'lady',
#   u'elliot',
#   u'had',
#   u'never',
#   u'required',
#   u'indulgence',
#   u'afterwards.--she',
#   u'had',
#   u'humoured',
#   u'or',
#   u'softened',
#   u'or',
#   u'concealed',
#   u'his',
#   u'failings',
#   u'and',
#   u'promoted',
#   u'his',
#   u'real',
#   u'respectability',
#   u'for',
#   u'seventeen',
#   u'years',
#   u'and',
#   u'though',
#   u'not',
#   u'the',
#   u'very',
#   u'happiest',
#   u'being',
#   u'in',
#   u'the',
#   u'world',
#   u'herself',
#   u'had',
#   u'found',
#   u'enough',
#   u'in',
#   u'her',
#   u'duties',
#   u'her',
#   u'friends',
#   u'and',
#   u'her',
#   u'children',
#   u'to',
#   u'attach',
#   u'her',
#   u'to',
#   u'life',
#   u'and',
#   u'make',
#   u'it',
#   u'no',
#   u'matter',
#   u'of',
#   u'indifference',
#   u'to',
#   u'her',
#   u'when',
#   u'she',
#   u'was',
#   u'called',
#   u'on',
#   u'to',
#   u'quit',
#   u'them.--three',
#   u'girls',
#   u'the',
#   u'two',
#   u'eldest',
#   u'sixteen',
#   u'and',
#   u'fourteen',
#   u'was',
#   u'an',
#   u'awful',
#   u'legacy',
#   u'for',
#   u'a',
#   u'mother',
#   u'to',
#   u'bequeath',
#   u'an',
#   u'awful',
#   u'charge',
#   u'rather',
#   u'to',
#   u'confide',
#   u'to',
#   u'the',
#   u'authority',
#   u'and',
#   u'guidance',
#   u'of',
#   u'a',
#   u'conceited',
#   u'silly',
#   u'father',
#   u'she',
#   u'had',
#   u'however',
#   u'one',
#   u'very',
#   u'intimate',
#   u'friend',
#   u'a',
#   u'sensible',
#   u'deserving',
#   u'woman',
#   u'who',
#   u'had',
#   u'been',
#   u'brought',
#   u'by',
#   u'strong',
#   u'attachment',
#   u'to',
#   u'herself',
#   u'to',
#   u'settle',
#   u'close',
#   u'by',
#   u'her',
#   u'in',
#   u'the',
#   u'village',
#   u'of',
#   u'kellynch',
#   u'and',
#   u'on',
#   u'her',
#   u'kindness',
#   u'and',
#   u'advice',
#   u'lady',
#   u'elliot',
#   u'mainly',
#   u'relied',
#   u'for',
#   u'the',
#   u'best',
#   u'help',
#   u'and',
#   u'maintenance',
#   u'of',
#   u'the',
#   u'good',
#   u'principles',
#   u'and',
#   u'instruction',
#   u'which',
#   u'she',
#   u'had',
#   u'been',
#   u'anxiously',
#   u'giving',
#   u'her',
#   u'daughters',
#   u'this',
#   u'friend',
#   u'and',
#   u'sir',
#   u'walter',
#   u'did',
#   u'not',
#   u'marry',
#   u'whatever',
#   u'might',
#   u'have',
#   u'been',
#   u'anticipated',
#   u'on',
#   u'that',
#   u'head',
#   u'by',
#   u'their',
#   u'acquaintance',
#   u'thirteen',
#   u'years',
#   u'had',
#   u'passed',
#   u'away',
#   u'since',
#   u'lady',
#   u"elliot's",
#   u'death',
#   u'and',
#   u'they',
#   u'were',
#   u'still',
#   u'near',
#   u'neighbours',
#   u'and',
#   u'intimate',
#   u'friends',
#   u'and',
#   u'one',
#   u'remained',
#   u'a',
#   u'widower',
#   u'the',
#   u'other',
#   u'a',
#   u'widow',
#   u'that',
#   u'lady',
#   u'russell',
#   u'of',
#   u'steady',
#   u'age',
#   u'and',
#   u'character',
#   u'and',
#   u'extremely',
#   u'well',
#   u'provided',
#   u'for',
#   u'should',
#   u'have',
#   u'no',
#   u'thought',
#   u'of',
#   u'a',
#   u'second',
#   u'marriage',
#   u'needs',
#   u'no',
#   u'apology',
#   u'to',
#   u'the',
#   u'public',
#   u'which',
#   u'is',
#   u'rather',
#   u'apt',
#   u'to',
#   u'be',
#   u'unreasonably',
#   u'discontented',
#   u'when',
#   u'a',
#   u'woman',
#   u'does',
#   u'marry',
#   u'again',
#   u'than',
#   u'when',
#   u'she',
#   u'does',
#   u'not',
#   u'but',
#   u'sir',
#   u"walter's",
#   u'continuing',
#   u'in',
#   u'singleness',
#   u'requires',
#   u'explanation',
#   u'be',
#   u'it',
#   u'known',
#   u'then',
#   u'that',
#   u'sir',
#   u'walter',
#   u'like',
#   u'a',
#   u'good',
#   u'father',
#   u'having',
#   u'met',
#   u'with',
#   u'one',
#   u'or',
#   u'two',
#   u'private',
#   u'disappointments',
#   u'in',
#   u'very',
#   u'unreasonable',
#   u'applications',
#   u'prided',
#   u'himself',
#   u'on',
#   u'remaining',
#   u'single',
#   u'for',
#   u'his',
#   u'dear',
#   u'daughters',
#   u'sake',
#   u'for',
#   u'one',
#   u'daughter',
#   u'his',
#   u'eldest',
#   u'he',
#   u'would',
#   u'really',
#   u'have',
#   u'given',
#   u'up',
#   u'any',
#   u'thing',
#   u'which',
#   u'he',
#   u'had',
#   u'not',
#   u'been',
#   u'very',
#   u'much',
#   u'tempted',
#   u'to',
#   u'do',
#   u'elizabeth',
#   u'had',
#   u'succeeded',
#   u'at',
#   u'sixteen',
#   u'to',
#   u'all',
#   u'that',
#   u'was',
#   u'possible',
#   u'of',
#   u'her',
#   u"mother's",
#   u'rights',
#   u'and',
#   u'consequence',
#   u'and',
#   u'being',
#   u'very',
#   u'handsome',
#   u'and',
#   u'very',
#   u'like',
#   u'himself',
#   u'her',
#   u'influence',
#   u'had',
#   u'always',
#   u'been',
#   u'great',
#   u'and',
#   u'they',
#   u'had',
#   u'gone',
#   u'on',
#   u'together',
#   u'most',
#   u'happily',
#   u'his',
#   u'two',
#   u'other',
#   u'children',
#   u'were',
#   u'of',
#   u'very',
#   u'inferior',
#   u'value',
#   u'mary',
#   u'had',
#   u'acquired',
#   u'a',
#   u'little',
#   u'artificial',
#   u'importance',
#   u'by',
#   u'becoming',
#   u'mrs',
#   u'charles',
#   u'musgrove',
#   u'but',
#   u'anne',
#   u'with',
#   u'an',
#   u'elegance',
#   u'of',
#   u'mind',
#   u'and',
#   u'sweetness',
#   u'of',
#   u'character',
#   u'which',
#   u'must',
#   u'have',
#   u'placed',
#   u'her',
#   u'high',
#   u'with',
#   u'any',
#   u'people',
#   u'of',
#   u'real',
#   u'understanding',
#   u'was',
#   u'nobody',
#   u'with',
#   u'either',
#   u'father',
#   u'or',
#   u'sister',
#   u'her',
#   u'word',
#   u'had',
#   u'no',
#   u'weight',
#   u'her',
#   u'convenience',
#   u'was',
#   u'always',
#   u'to',
#   u'give',
#   u'way--she',
#   u'was',
#   u'only',
#   u'anne',
#   u'to',
#   u'lady',
#   u'russell',
#   u'indeed',
#   u'she',
#   u'was',
#   u'a',
#   u'most',
#   u'dear',
#   u'and',
#   u'highly',
#   u'valued',
#   u'god-daughter',
#   u'favourite',
#   u'and',
#   u'friend',
#   u'lady',
#   u'russell',
#   u'loved',
#   u'them',
#   u'all',
#   u'but',
#   u'it',
#   u'was',
#   u'only',
#   u'in',
#   u'anne',
#   u'that',
#   u'she',
#   u'could',
#   u'fancy',
#   u'the',
#   u'mother',
#   u'to',
#   u'revive',
#   u'again',
#   u'a',
#   u'few',
#   u'years',
#   u'before',
#   u'anne',
#   u'elliot',
#   u'had',
#   u'been',
#   u'a',
#   u'very',
#   u'pretty',
#   u'girl',
#   u'but',
#   u'her',
#   u'bloom',
#   u'had',
#   u'vanished',
#   u'early',
#   u'and',
#   u'as',
#   u'even',
#   u'in',
#   u'its',
#   u'height',
#   u'her',
#   u'father',
#   u'had',
#   u'found',
#   u'little',
#   ...],
#  [u'the',
#   u'return',
#   u'of',
#   u'sherlock',
#   u'holmes',
#   u'a',
#   u'collection',
#   u'of',
#   u'holmes',
#   u'adventures',
#   u'by',
#   u'sir',
#   u'arthur',
#   u'conan',
#   u'doyle',
#   u'contents',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'empty',
#   u'house',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'norwood',
#   u'builder',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'dancing',
#   u'men',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'solitary',
#   u'cyclist',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'priory',
#   u'school',
#   u'the',
#   u'adventure',
#   u'of',
#   u'black',
#   u'peter',
#   u'the',
#   u'adventure',
#   u'of',
#   u'charles',
#   u'augustus',
#   u'milverton',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'six',
#   u'napoleons',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'three',
#   u'students',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'golden',
#   u'pince-nez',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'missing',
#   u'three-quarter',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'abbey',
#   u'grange',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'second',
#   u'stain',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'empty',
#   u'house',
#   u'it',
#   u'was',
#   u'in',
#   u'the',
#   u'spring',
#   u'of',
#   u'the',
#   u'year',
#   u'1894',
#   u'that',
#   u'all',
#   u'london',
#   u'was',
#   u'interested',
#   u'and',
#   u'the',
#   u'fashionable',
#   u'world',
#   u'dismayed',
#   u'by',
#   u'the',
#   u'murder',
#   u'of',
#   u'the',
#   u'honourable',
#   u'ronald',
#   u'adair',
#   u'under',
#   u'most',
#   u'unusual',
#   u'and',
#   u'inexplicable',
#   u'circumstances',
#   u'the',
#   u'public',
#   u'has',
#   u'already',
#   u'learned',
#   u'those',
#   u'particulars',
#   u'of',
#   u'the',
#   u'crime',
#   u'which',
#   u'came',
#   u'out',
#   u'in',
#   u'the',
#   u'police',
#   u'investigation',
#   u'but',
#   u'a',
#   u'good',
#   u'deal',
#   u'was',
#   u'suppressed',
#   u'upon',
#   u'that',
#   u'occasion',
#   u'since',
#   u'the',
#   u'case',
#   u'for',
#   u'the',
#   u'prosecution',
#   u'was',
#   u'so',
#   u'overwhelmingly',
#   u'strong',
#   u'that',
#   u'it',
#   u'was',
#   u'not',
#   u'necessary',
#   u'to',
#   u'bring',
#   u'forward',
#   u'all',
#   u'the',
#   u'facts',
#   u'only',
#   u'now',
#   u'at',
#   u'the',
#   u'end',
#   u'of',
#   u'nearly',
#   u'ten',
#   u'years',
#   u'am',
#   u'i',
#   u'allowed',
#   u'to',
#   u'supply',
#   u'those',
#   u'missing',
#   u'links',
#   u'which',
#   u'make',
#   u'up',
#   u'the',
#   u'whole',
#   u'of',
#   u'that',
#   u'remarkable',
#   u'chain',
#   u'the',
#   u'crime',
#   u'was',
#   u'of',
#   u'interest',
#   u'in',
#   u'itself',
#   u'but',
#   u'that',
#   u'interest',
#   u'was',
#   u'as',
#   u'nothing',
#   u'to',
#   u'me',
#   u'compared',
#   u'to',
#   u'the',
#   u'inconceivable',
#   u'sequel',
#   u'which',
#   u'afforded',
#   u'me',
#   u'the',
#   u'greatest',
#   u'shock',
#   u'and',
#   u'surprise',
#   u'of',
#   u'any',
#   u'event',
#   u'in',
#   u'my',
#   u'adventurous',
#   u'life',
#   u'even',
#   u'now',
#   u'after',
#   u'this',
#   u'long',
#   u'interval',
#   u'i',
#   u'find',
#   u'myself',
#   u'thrilling',
#   u'as',
#   u'i',
#   u'think',
#   u'of',
#   u'it',
#   u'and',
#   u'feeling',
#   u'once',
#   u'more',
#   u'that',
#   u'sudden',
#   u'flood',
#   u'of',
#   u'joy',
#   u'amazement',
#   u'and',
#   u'incredulity',
#   u'which',
#   u'utterly',
#   u'submerged',
#   u'my',
#   u'mind',
#   u'let',
#   u'me',
#   u'say',
#   u'to',
#   u'that',
#   u'public',
#   u'which',
#   u'has',
#   u'shown',
#   u'some',
#   u'interest',
#   u'in',
#   u'those',
#   u'glimpses',
#   u'which',
#   u'i',
#   u'have',
#   u'occasionally',
#   u'given',
#   u'them',
#   u'of',
#   u'the',
#   u'thoughts',
#   u'and',
#   u'actions',
#   u'of',
#   u'a',
#   u'very',
#   u'remarkable',
#   u'man',
#   u'that',
#   u'they',
#   u'are',
#   u'not',
#   u'to',
#   u'blame',
#   u'me',
#   u'if',
#   u'i',
#   u'have',
#   u'not',
#   u'shared',
#   u'my',
#   u'knowledge',
#   u'with',
#   u'them',
#   u'for',
#   u'i',
#   u'should',
#   u'have',
#   u'considered',
#   u'it',
#   u'my',
#   u'first',
#   u'duty',
#   u'to',
#   u'do',
#   u'so',
#   u'had',
#   u'i',
#   u'not',
#   u'been',
#   u'barred',
#   u'by',
#   u'a',
#   u'positive',
#   u'prohibition',
#   u'from',
#   u'his',
#   u'own',
#   u'lips',
#   u'which',
#   u'was',
#   u'only',
#   u'withdrawn',
#   u'upon',
#   u'the',
#   u'third',
#   u'of',
#   u'last',
#   u'month',
#   u'it',
#   u'can',
#   u'be',
#   u'imagined',
#   u'that',
#   u'my',
#   u'close',
#   u'intimacy',
#   u'with',
#   u'sherlock',
#   u'holmes',
#   u'had',
#   u'interested',
#   u'me',
#   u'deeply',
#   u'in',
#   u'crime',
#   u'and',
#   u'that',
#   u'after',
#   u'his',
#   u'disappearance',
#   u'i',
#   u'never',
#   u'failed',
#   u'to',
#   u'read',
#   u'with',
#   u'care',
#   u'the',
#   u'various',
#   u'problems',
#   u'which',
#   u'came',
#   u'before',
#   u'the',
#   u'public',
#   u'and',
#   u'i',
#   u'even',
#   u'attempted',
#   u'more',
#   u'than',
#   u'once',
#   u'for',
#   u'my',
#   u'own',
#   u'private',
#   u'satisfaction',
#   u'to',
#   u'employ',
#   u'his',
#   u'methods',
#   u'in',
#   u'their',
#   u'solution',
#   u'though',
#   u'with',
#   u'indifferent',
#   u'success',
#   u'there',
#   u'was',
#   u'none',
#   u'however',
#   u'which',
#   u'appealed',
#   u'to',
#   u'me',
#   u'like',
#   u'this',
#   u'tragedy',
#   u'of',
#   u'ronald',
#   u'adair',
#   u'as',
#   u'i',
#   u'read',
#   u'the',
#   u'evidence',
#   u'at',
#   u'the',
#   u'inquest',
#   u'which',
#   u'led',
#   u'up',
#   u'to',
#   u'a',
#   u'verdict',
#   u'of',
#   u'willful',
#   u'murder',
#   u'against',
#   u'some',
#   u'person',
#   u'or',
#   u'persons',
#   u'unknown',
#   u'i',
#   u'realized',
#   u'more',
#   u'clearly',
#   u'than',
#   u'i',
#   u'had',
#   u'ever',
#   u'done',
#   u'the',
#   u'loss',
#   u'which',
#   u'the',
#   u'community',
#   u'had',
#   u'sustained',
#   u'by',
#   u'the',
#   u'death',
#   u'of',
#   u'sherlock',
#   u'holmes',
#   u'there',
#   u'were',
#   u'points',
#   u'about',
#   u'this',
#   u'strange',
#   u'business',
#   u'which',
#   u'would',
#   u'i',
#   u'was',
#   u'sure',
#   u'have',
#   u'specially',
#   u'appealed',
#   u'to',
#   u'him',
#   u'and',
#   u'the',
#   u'efforts',
#   u'of',
#   u'the',
#   u'police',
#   u'would',
#   u'have',
#   u'been',
#   u'supplemented',
#   u'or',
#   u'more',
#   u'probably',
#   u'anticipated',
#   u'by',
#   u'the',
#   u'trained',
#   u'observation',
#   u'and',
#   u'the',
#   u'alert',
#   u'mind',
#   u'of',
#   u'the',
#   u'first',
#   u'criminal',
#   u'agent',
#   u'in',
#   u'europe',
#   u'all',
#   u'day',
#   u'as',
#   u'i',
#   u'drove',
#   u'upon',
#   u'my',
#   u'round',
#   u'i',
#   u'turned',
#   u'over',
#   u'the',
#   u'case',
#   u'in',
#   u'my',
#   u'mind',
#   u'and',
#   u'found',
#   u'no',
#   u'explanation',
#   u'which',
#   u'appeared',
#   u'to',
#   u'me',
#   u'to',
#   u'be',
#   u'adequate',
#   u'at',
#   u'the',
#   u'risk',
#   u'of',
#   u'telling',
#   u'a',
#   u'twice-told',
#   u'tale',
#   u'i',
#   u'will',
#   u'recapitulate',
#   u'the',
#   u'facts',
#   u'as',
#   u'they',
#   u'were',
#   u'known',
#   u'to',
#   u'the',
#   u'public',
#   u'at',
#   u'the',
#   u'conclusion',
#   u'of',
#   u'the',
#   u'inquest',
#   u'the',
#   u'honourable',
#   u'ronald',
#   u'adair',
#   u'was',
#   u'the',
#   u'second',
#   u'son',
#   u'of',
#   u'the',
#   u'earl',
#   u'of',
#   u'maynooth',
#   u'at',
#   u'that',
#   u'time',
#   u'governor',
#   u'of',
#   u'one',
#   u'of',
#   u'the',
#   u'australian',
#   u'colonies',
#   u"adair's",
#   u'mother',
#   u'had',
#   u'returned',
#   u'from',
#   u'australia',
#   u'to',
#   u'undergo',
#   u'the',
#   u'operation',
#   u'for',
#   u'cataract',
#   u'and',
#   u'she',
#   u'her',
#   u'son',
#   u'ronald',
#   u'and',
#   u'her',
#   u'daughter',
#   u'hilda',
#   u'were',
#   u'living',
#   u'together',
#   u'at',
#   u'427',
#   u'park',
#   u'lane',
#   u'the',
#   u'youth',
#   u'moved',
#   u'in',
#   u'the',
#   u'best',
#   u'society--had',
#   u'so',
#   u'far',
#   u'as',
#   u'was',
#   u'known',
#   u'no',
#   u'enemies',
#   u'and',
#   u'no',
#   u'particular',
#   u'vices',
#   u'he',
#   u'had',
#   u'been',
#   u'engaged',
#   u'to',
#   u'miss',
#   u'edith',
#   u'woodley',
#   u'of',
#   u'carstairs',
#   u'but',
#   u'the',
#   u'engagement',
#   u'had',
#   u'been',
#   u'broken',
#   u'off',
#   u'by',
#   u'mutual',
#   u'consent',
#   u'some',
#   u'months',
#   u'before',
#   u'and',
#   u'there',
#   u'was',
#   u'no',
#   u'sign',
#   u'that',
#   u'it',
#   u'had',
#   u'left',
#   u'any',
#   u'very',
#   u'profound',
#   u'feeling',
#   u'behind',
#   u'it',
#   u'for',
#   u'the',
#   u'rest',
#   u'sic',
#   u'the',
#   u"man's",
#   u'life',
#   u'moved',
#   u'in',
#   u'a',
#   u'narrow',
#   u'and',
#   u'conventional',
#   u'circle',
#   u'for',
#   u'his',
#   u'habits',
#   u'were',
#   u'quiet',
#   u'and',
#   u'his',
#   u'nature',
#   u'unemotional',
#   u'yet',
#   u'it',
#   u'was',
#   u'upon',
#   u'this',
#   u'easy-going',
#   u'young',
#   u'aristocrat',
#   u'that',
#   u'death',
#   u'came',
#   u'in',
#   u'most',
#   u'strange',
#   u'and',
#   u'unexpected',
#   u'form',
#   u'between',
#   u'the',
#   u'hours',
#   u'of',
#   u'ten',
#   u'and',
#   u'eleven-twenty',
#   u'on',
#   u'the',
#   u'night',
#   u'of',
#   u'march',
#   u'30',
#   u'1894',
#   u'ronald',
#   u'adair',
#   u'was',
#   u'fond',
#   u'of',
#   u'cards--playing',
#   u'continually',
#   u'but',
#   u'never',
#   u'for',
#   u'such',
#   u'stakes',
#   u'as',
#   u'would',
#   u'hurt',
#   u'him',
#   u'he',
#   u'was',
#   u'a',
#   u'member',
#   u'of',
#   u'the',
#   u'baldwin',
#   u'the',
#   u'cavendish',
#   u'and',
#   u'the',
#   u'bagatelle',
#   u'card',
#   u'clubs',
#   u'it',
#   u'was',
#   u'shown',
#   u'that',
#   u'after',
#   u'dinner',
#   u'on',
#   u'the',
#   u'day',
#   u'of',
#   u'his',
#   u'death',
#   u'he',
#   u'had',
#   u'played',
#   u'a',
#   u'rubber',
#   u'of',
#   u'whist',
#   u'at',
#   u'the',
#   u'latter',
#   u'club',
#   u'he',
#   u'had',
#   u'also',
#   u'played',
#   u'there',
#   u'in',
#   u'the',
#   u'afternoon',
#   u'the',
#   u'evidence',
#   u'of',
#   u'those',
#   u'who',
#   u'had',
#   u'played',
#   u'with',
#   u'him--mr',
#   u'murray',
#   u'sir',
#   u'john',
#   u'hardy',
#   u'and',
#   u'colonel',
#   u'moran--showed',
#   u'that',
#   u'the',
#   u'game',
#   u'was',
#   u'whist',
#   u'and',
#   u'that',
#   u'there',
#   u'was',
#   u'a',
#   u'fairly',
#   u'equal',
#   u'fall',
#   u'of',
#   u'the',
#   u'cards',
#   u'adair',
#   u'might',
#   u'have',
#   u'lost',
#   u'five',
#   u'pounds',
#   u'but',
#   u'not',
#   u'more',
#   u'his',
#   u'fortune',
#   u'was',
#   u'a',
#   u'considerable',
#   u'one',
#   u'and',
#   u'such',
#   u'a',
#   u'loss',
#   u'could',
#   u'not',
#   u'in',
#   u'any',
#   u'way',
#   u'affect',
#   u'him',
#   u'he',
#   u'had',
#   u'played',
#   u'nearly',
#   u'every',
#   u'day',
#   u'at',
#   u'one',
#   u'club',
#   u'or',
#   u'other',
#   u'but',
#   u'he',
#   u'was',
#   u'a',
#   u'cautious',
#   u'player',
#   u'and',
#   u'usually',
#   u'rose',
#   u'a',
#   u'winner',
#   u'it',
#   u'came',
#   u'out',
#   u'in',
#   u'evidence',
#   u'that',
#   u'in',
#   u'partnership',
#   u'with',
#   u'colonel',
#   u'moran',
#   u'he',
#   u'had',
#   u'actually',
#   u'won',
#   u'as',
#   u'much',
#   u'as',
#   u'four',
#   u'hundred',
#   u'and',
#   u'twenty',
#   u'pounds',
#   u'in',
#   u'a',
#   u'sitting',
#   u'some',
#   u'weeks',
#   u'before',
#   u'from',
#   u'godfrey',
#   u'milner',
#   u'and',
#   u'lord',
#   u'balmoral',
#   u'so',
#   u'much',
#   u'for',
#   u'his',
#   u'recent',
#   u'history',
#   u'as',
#   u'it',
#   u'came',
#   u'out',
#   u'at',
#   u'the',
#   u'inquest',
#   u'on',
#   u'the',
#   u'evening',
#   u'of',
#   u'the',
#   u'crime',
#   u'he',
#   u'returned',
#   u'from',
#   u'the',
#   u'club',
#   u'exactly',
#   u'at',
#   u'ten',
#   u'his',
#   u'mother',
#   u'and',
#   u'sister',
#   u'were',
#   u'out',
#   u'spending',
#   u'the',
#   u'evening',
#   u'with',
#   u'a',
#   u'relation',
#   u'the',
#   u'servant',
#   u'deposed',
#   u'that',
#   u'she',
#   u'heard',
#   u'him',
#   u'enter',
#   u'the',
#   u'front',
#   u'room',
#   u'on',
#   u'the',
#   u'second',
#   u'floor',
#   u'generally',
#   u'used',
#   u'as',
#   u'his',
#   u'sitting-room',
#   u'she',
#   u'had',
#   u'lit',
#   u'a',
#   u'fire',
#   u'there',
#   u'and',
#   u'as',
#   u'it',
#   u'smoked',
#   u'she',
#   u'had',
#   u'opened',
#   u'the',
#   u'window',
#   u'no',
#   u'sound',
#   u'was',
#   u'heard',
#   u'from',
#   u'the',
#   u'room',
#   u'until',
#   u'eleven-twenty',
#   u'the',
#   u'hour',
#   u'of',
#   u'the',
#   u'return',
#   u'of',
#   u'lady',
#   u'maynooth',
#   u'and',
#   ...],
#  [u'a',
#   u'modest',
#   u'proposal',
#   u'for',
#   u'preventing',
#   u'the',
#   u'children',
#   u'of',
#   u'poor',
#   u'people',
#   u'in',
#   u'ireland',
#   u'from',
#   u'being',
#   u'a',
#   u'burden',
#   u'on',
#   u'their',
#   u'parents',
#   u'or',
#   u'country',
#   u'and',
#   u'for',
#   u'making',
#   u'them',
#   u'beneficial',
#   u'to',
#   u'the',
#   u'publick',
#   u'by',
#   u'dr',
#   u'jonathan',
#   u'swift',
#   u'1729',
#   u'it',
#   u'is',
#   u'a',
#   u'melancholy',
#   u'object',
#   u'to',
#   u'those',
#   u'who',
#   u'walk',
#   u'through',
#   u'this',
#   u'great',
#   u'town',
#   u'or',
#   u'travel',
#   u'in',
#   u'the',
#   u'country',
#   u'when',
#   u'they',
#   u'see',
#   u'the',
#   u'streets',
#   u'the',
#   u'roads',
#   u'and',
#   u'cabbin-doors',
#   u'crowded',
#   u'with',
#   u'beggars',
#   u'of',
#   u'the',
#   u'female',
#   u'sex',
#   u'followed',
#   u'by',
#   u'three',
#   u'four',
#   u'or',
#   u'six',
#   u'children',
#   u'all',
#   u'in',
#   u'rags',
#   u'and',
#   u'importuning',
#   u'every',
#   u'passenger',
#   u'for',
#   u'an',
#   u'alms',
#   u'these',
#   u'mothers',
#   u'instead',
#   u'of',
#   u'being',
#   u'able',
#   u'to',
#   u'work',
#   u'for',
#   u'their',
#   u'honest',
#   u'livelihood',
#   u'are',
#   u'forced',
#   u'to',
#   u'employ',
#   u'all',
#   u'their',
#   u'time',
#   u'in',
#   u'stroling',
#   u'to',
#   u'beg',
#   u'sustenance',
#   u'for',
#   u'their',
#   u'helpless',
#   u'infants',
#   u'who',
#   u'as',
#   u'they',
#   u'grow',
#   u'up',
#   u'either',
#   u'turn',
#   u'thieves',
#   u'for',
#   u'want',
#   u'of',
#   u'work',
#   u'or',
#   u'leave',
#   u'their',
#   u'dear',
#   u'native',
#   u'country',
#   u'to',
#   u'fight',
#   u'for',
#   u'the',
#   u'pretender',
#   u'in',
#   u'spain',
#   u'or',
#   u'sell',
#   u'themselves',
#   u'to',
#   u'the',
#   u'barbadoes',
#   u'i',
#   u'think',
#   u'it',
#   u'is',
#   u'agreed',
#   u'by',
#   u'all',
#   u'parties',
#   u'that',
#   u'this',
#   u'prodigious',
#   u'number',
#   u'of',
#   u'children',
#   u'in',
#   u'the',
#   u'arms',
#   u'or',
#   u'on',
#   u'the',
#   u'backs',
#   u'or',
#   u'at',
#   u'the',
#   u'heels',
#   u'of',
#   u'their',
#   u'mothers',
#   u'and',
#   u'frequently',
#   u'of',
#   u'their',
#   u'fathers',
#   u'is',
#   u'in',
#   u'the',
#   u'present',
#   u'deplorable',
#   u'state',
#   u'of',
#   u'the',
#   u'kingdom',
#   u'a',
#   u'very',
#   u'great',
#   u'additional',
#   u'grievance',
#   u'and',
#   u'therefore',
#   u'whoever',
#   u'could',
#   u'find',
#   u'out',
#   u'a',
#   u'fair',
#   u'cheap',
#   u'and',
#   u'easy',
#   u'method',
#   u'of',
# ...
#   u'he',
#   u'had',
#   u'not',
#   u'kneeled',
#   u'down',
#   u'in',
#   u'the',
#   u'rain',
#   u'to',
#   u'do',
#   u'honour',
#   u'to',
#   u'a',
#   u'dirty',
#   u'procession',
#   u'of',
#   u'monks',
#   u'which',
#   u'passed',
#   u'within',
#   u'his',
#   u'view',
#   u'at',
#   u'a',
#   u'distance',
#   u'of',
#   u'some',
#   u'fifty',
#   u'or',
#   u'sixty',
#   u'yards',
#   u'it',
#   u'is',
#   u'likely',
#   u'enough',
#   u'that',
#   u'rooted',
#   u'in',
#   u'the',
#   u'woods',
#   u'of',
#   u'france',
#   u'and',
#   u'norway',
#   u'there',
#   u'were',
#   u'growing',
#   u'trees',
#   u'when',
#   u'that',
#   u'sufferer',
#   u'was',
#   u'put',
#   u'to',
#   u'death',
#   u'already',
#   u'marked',
#   u'by',
#   u'the',
#   u'woodman',
#   u'fate',
#   u'to',
#   u'come',
#   u'down',
#   u'and',
#   u'be',
#   u'sawn',
#   u'into',
#   u'boards',
#   u'to',
#   u'make',
#   u'a',
#   u'certain',
#   u'movable',
#   u'framework',
#   u'with',
#   u'a',
#   u'sack',
#   u'and',
#   u'a',
#   u'knife',
#   u'in',
#   u'it',
#   u'terrible',
#   u'in',
#   u'history',
#   u'it',
#   u'is',
#   u'likely',
#   u'enough',
#   u'that',
#   u'in',
#   u'the',
#   u'rough',
#   u'outhouses',
#   u'of',
#   u'some',
#   u'tillers',
#   u'of',
#   u'the',
#   u'heavy',
#   u'lands',
#   u'adjacent',
#   u'to',
#   u'paris',
#   u'there',
#   u'were',
#   u'sheltered',
#   u'from',
#   u'the',
#   u'weather',
#   u'that',
#   u'very',
#   u'day',
#   u'rude',
#   u'carts',
#   u'bespattered',
#   u'with',
#   u'rustic',
#   u'mire',
#   u'snuffed',
#   u'about',
#   u'by',
#   u'pigs',
#   u'and',
#   u'roosted',
#   u'in',
#   u'by',
#   u'poultry',
#   u'which',
#   u'the',
#   u'farmer',
#   u'death',
#   u'had',
#   u'already',
#   u'set',
#   u'apart',
#   u'to',
#   u'be',
#   u'his',
#   u'tumbrils',
#   u'of',
#   u'the',
#   u'revolution',
#   u'but',
#   u'that',
#   u'woodman',
#   u'and',
#   u'that',
#   u'farmer',
#   u'though',
#   u'they',
#   u'work',
#   u'unceasingly',
#   u'work',
#   u'silently',
#   u'and',
#   u'no',
#   u'one',
#   u'heard',
#   u'them',
#   u'as',
#   u'they',
#   u'went',
#   u'about',
#   u'with',
#   u'muffled',
#   u'tread',
#   u'the',
#   u'rather',
#   u'forasmuch',
#   u'as',
#   u'to',
#   u'entertain',
#   u'any',
#   u'suspicion',
#   u'that',
#   u'they',
#   u'were',
#   u'awake',
#   u'was',
#   u'to',
#   u'be',
#   u'atheistical',
#   u'and',
#   u'traitorous',
#   u'in',
#   u'england',
#   u'there',
#   u'was',
#   u'scarcely',
#   u'an',
#   u'amount',
#   u'of',
#   u'order',
#   u'and',
#   u'protection',
#   u'to',
#   u'justify',
#   u'much',
#   u'national',
#   u'boasting',
#   u'daring',
#   u'burglaries',
#   u'by',
#   u'armed',
#   u'men',
#   u'and',
#   u'highway',
#   u'robberies',
#   u'took',
#   u'place',
#   u'in',
#   u'the',
#   u'capital',
#   u'itself',
#   u'every',
#   u'night',
#   u'families',
#   u'were',
#   u'publicly',
#   u'cautioned',
#   u'not',
#   u'to',
#   u'go',
#   u'out',
#   u'of',
#   u'town',
#   u'without',
#   u'removing',
#   u'their',
#   u'furniture',
#   u'to',
#   u'upholsterers',
#   u'warehouses',
#   u'for',
#   u'security',
#   u'the',
#   u'highwayman',
#   u'in',
#   u'the',
#   u'dark',
#   u'was',
#   u'a',
#   u'city',
#   u'tradesman',
#   u'in',
#   u'the',
#   u'light',
#   u'and',
#   u'being',
#   u'recognised',
#   u'and',
#   u'challenged',
#   u'by',
#   u'his',
#   u'fellow-tradesman',
#   u'whom',
#   u'he',
#   u'stopped',
#   u'in',
#   u'his',
#   u'character',
#   u'of',
#   u'the',
#   u'captain',
#   u'gallantly',
#   u'shot',
#   u'him',
#   u'through',
#   u'the',
#   u'head',
#   u'and',
#   u'rode',
#   u'away',
#   u'the',
#   u'mail',
#   u'was',
#   u'waylaid',
#   u'by',
#   u'seven',
#   u'robbers',
#   u'and',
#   u'the',
#   u'guard',
#   u'shot',
#   u'three',
#   u'dead',
#   u'and',
#   u'then',
#   u'got',
#   u'shot',
#   u'dead',
#   u'himself',
#   u'by',
#   u'the',
#   u'other',
#   u'four',
#   u'in',
#   u'consequence',
#   u'of',
#   u'the',
#   u'failure',
#   u'of',
#   u'his',
#   u'ammunition',
#   u'after',
#   u'which',
#   u'the',
#   u'mail',
#   u'was',
#   u'robbed',
#   u'in',
#   u'peace',
#   u'that',
#   u'magnificent',
#   u'potentate',
#   u'the',
#   u'lord',
#   u'mayor',
#   u'of',
#   u'london',
#   u'was',
#   u'made',
#   u'to',
#   u'stand',
#   u'and',
#   u'deliver',
#   u'on',
#   u'turnham',
#   u'green',
#   u'by',
#   u'one',
#   u'highwayman',
#   u'who',
#   u'despoiled',
#   u'the',
#   u'illustrious',
#   u'creature',
#   u'in',
#   u'sight',
#   u'of',
#   u'all',
#   u'his',
#   u'retinue',
#   u'prisoners',
#   u'in',
#   u'london',
#   u'gaols',
#   u'fought',
#   u'battles',
#   ...],
#  [u'don',
#   u'quixote',
#   u'complete',
#   u'by',
#   u'miguel',
#   u'de',
#   u'cervantes',
#   u'saavedra',
#   u'translated',
#   u'by',
#   u'john',
#   u'ormsby',
#   u'contents',
#   u'volume',
#   u'i',
#   u'chapter',
#   u'i',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'character',
#   u'and',
#   u'pursuits',
#   u'of',
#   u'the',
#   u'famous',
#   u'gentleman',
#   u'don',
#   u'quixote',
#   u'of',
#   u'la',
#   u'mancha',
#   u'chapter',
#   u'ii',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'first',
#   u'sally',
#   u'the',
#   u'ingenious',
#   u'don',
#   u'quixote',
#   u'made',
#   u'from',
#   u'home',
#   u'chapter',
#   u'iii',
#   u'wherein',
#   u'is',
#   u'related',
#   u'the',
#   u'droll',
#   u'way',
#   u'in',
#   u'which',
#   u'don',
#   u'quixote',
#   u'had',
#   u'himself',
#   u'dubbed',
#   u'a',
#   u'knight',
#   u'chapter',
#   u'iv',
#   u'of',
#   u'what',
#   u'happened',
#   u'to',
#   u'our',
#   u'knight',
#   u'when',
#   u'he',
#   u'left',
#   u'the',
#   u'inn',
#   u'chapter',
#   u'v',
#   u'in',
#   u'which',
#   u'the',
#   u'narrative',
#   u'of',
#   u'our',
#   u"knight's",
#   u'mishap',
#   u'is',
#   u'continued',
#   u'chapter',
#   u'vi',
#   u'of',
#   u'the',
#   u'diverting',
#   u'and',
#   u'important',
#   u'scrutiny',
#   u'which',
#   u'the',
#   u'curate',
#   u'and',
#   u'the',
#   u'barber',
#   u'made',
#   u'in',
#   u'the',
#   u'library',
#   u'of',
#   u'our',
#   u'ingenious',
#   u'gentleman',
#   u'chapter',
#   u'vii',
#   u'of',
#   u'the',
#   u'second',
#   u'sally',
#   u'of',
#   u'our',
#   u'worthy',
#   u'knight',
#   u'don',
#   u'quixote',
#   u'of',
#   u'la',
#   u'mancha',
#   u'chapter',
#   u'viii',
#   u'of',
#   u'the',
#   u'good',
#   u'fortune',
#   u'which',
#   u'the',
#   u'valiant',
#   u'don',
#   u'quixote',
#   u'had',
#   u'in',
#   u'the',
#   u'terrible',
#   u'and',
#   u'undreamt-of',
#   u'adventure',
#   u'of',
#   u'the',
#   u'windmills',
#   u'with',
#   u'other',
#   u'occurrences',
#   u'worthy',
#   u'to',
#   u'be',
#   u'fitly',
#   u'recorded',
#   u'chapter',
#   u'ix',
#   u'in',
#   u'which',
#   u'is',
#   u'concluded',
#   u'and',
#   u'finished',
#   u'the',
#   u'terrific',
#   u'battle',
#   u'between',
#   u'the',
#   u'gallant',
#   u'biscayan',
#   u'and',
#   u'the',
#   u'valiant',
#   u'manchegan',
#   u'chapter',
#   u'x',
#   u'of',
#   u'the',
#   u'pleasant',
#   u'discourse',
#   u'that',
#   u'passed',
#   u'between',
#   u'don',
#   u'quixote',
#   u'and',
#   u'his',
#   u'squire',
#   u'sancho',
#   u'panza',
#   u'chapter',
#   u'xi',
#   u'of',
#   u'what',
#   u'befell',
#   u'don',
#   u'quixote',
#   u'with',
#   u'certain',
#   u'goatherds',
#   u'chapter',
#   u'xii',
#   u'of',
#   u'what',
#   u'a',
#   u'goatherd',
#   u'related',
#   u'to',
#   u'those',
#   u'with',
#   u'don',
#   u'quixote',
#   u'chapter',
#   u'xiii',
#   u'in',
#   u'which',
#   u'is',
#   u'ended',
#   u'the',
#   u'story',
#   u'of',
#   u'the',
#   u'shepherdess',
#   u'marcela',
#   u'with',
#   u'other',
#   u'incidents',
#   u'chapter',
#   u'xiv',
#   u'wherein',
#   u'are',
#   u'inserted',
#   u'the',
#   u'despairing',
#   u'verses',
#   u'of',
#   u'the',
#   u'dead',
#   u'shepherd',
#   u'together',
#   u'with',
#   u'other',
#   u'incidents',
#   u'not',
#   u'looked',
#   u'for',
#   u'chapter',
#   u'xv',
#   u'in',
#   u'which',
#   u'is',
#   u'related',
#   u'the',
#   u'unfortunate',
#   u'adventure',
#   u'that',
#   u'don',
#   u'quixote',
#   u'fell',
#   u'in',
#   u'with',
#   u'when',
#   u'he',
#   u'fell',
#   u'out',
#   u'with',
#   u'certain',
#   u'heartless',
#   u'yanguesans',
#   u'chapter',
#   u'xvi',
#   u'of',
#   u'what',
#   u'happened',
#   u'to',
#   u'the',
#   u'ingenious',
#   u'gentleman',
#   u'in',
#   u'the',
#   u'inn',
#   u'which',
#   u'he',
#   u'took',
#   u'to',
#   u'be',
#   u'a',
#   u'castle',
#   u'chapter',
#   u'xvii',
#   u'in',
#   u'which',
#   u'are',
#   u'contained',
#   u'the',
#   u'innumerable',
#   u'troubles',
#   u'which',
#   u'the',
#   u'brave',
#   u'don',
#   u'quixote',
#   u'and',
#   u'his',
#   u'good',
#   u'squire',
#   u'sancho',
#   u'panza',
#   u'endured',
#   u'in',
#   u'the',
#   u'inn',
#   u'which',
#   u'to',
#   u'his',
#   u'misfortune',
#   u'he',
#   u'took',
#   u'to',
#   u'be',
#   u'a',
#   u'castle',
#   u'chapter',
#   u'xviii',
#   u'in',
#   u'which',
#   u'is',
#   u'related',
#   u'the',
#   u'discourse',
#   u'sancho',
#   u'panza',
#   u'held',
#   u'with',
#   u'his',
#   u'master',
#   u'don',
#   u'quixote',
#   u'and',
#   u'other',
#   u'adventures',
#   u'worth',
#   u'relating',
#   u'chapter',
#   u'xix',
#   u'of',
#   u'the',
#   u'shrewd',
#   u'discourse',
#   u'which',
#   u'sancho',
#   u'held',
#   u'with',
#   u'his',
#   u'master',
#   u'and',
#   u'of',
#   u'the',
#   u'adventure',
#   u'that',
#   u'befell',
#   u'him',
#   u'with',
#   u'a',
#   u'dead',
#   u'body',
#   u'together',
#   u'with',
#   u'other',
#   u'notable',
#   u'occurrences',
#   u'chapter',
#   u'xx',
#   u'of',
#   u'the',
#   u'unexampled',
#   u'and',
#   u'unheard-of',
#   u'adventure',
#   u'which',
#   u'was',
#   u'achieved',
#   u'by',
#   u'the',
#   u'valiant',
#   u'don',
#   u'quixote',
#   u'of',
#   u'la',
#   u'mancha',
#   u'with',
#   u'less',
#   u'peril',
#   u'than',
#   u'any',
#   u'ever',
#   u'achieved',
#   u'by',
#   u'any',
#   u'famous',
#   u'knight',
#   u'in',
#   u'the',
#   u'world',
#   u'chapter',
#   u'xxi',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'exalted',
#   u'adventure',
#   u'and',
#   u'rich',
#   u'prize',
#   u'of',
#   u"mambrino's",
#   u'helmet',
#   u'together',
#   u'with',
#   u'other',
#   u'things',
#   u'that',
#   u'happened',
#   u'to',
#   u'our',
#   u'invincible',
#   u'knight',
#   u'chapter',
#   u'xxii',
#   u'of',
#   u'the',
#   u'freedom',
#   u'don',
#   u'quixote',
#   u'conferred',
#   u'on',
#   u'several',
#   u'unfortunates',
#   u'who',
#   u'against',
#   u'their',
#   u'will',
#   u'were',
#   u'being',
#   u'carried',
#   u'where',
#   u'they',
#   u'had',
#   u'no',
#   u'wish',
#   u'to',
#   u'go',
#   u'chapter',
#   u'xxiii',
#   u'of',
#   u'what',
#   u'befell',
#   u'don',
#   u'quixote',
#   u'in',
#   u'the',
#   u'sierra',
#   u'morena',
#   u'which',
#   u'was',
#   u'one',
#   u'of',
#   u'the',
#   u'rarest',
#   u'adventures',
#   u'related',
#   u'in',
#   u'this',
#   u'veracious',
#   u'history',
#   u'chapter',
#   u'xxiv',
#   u'in',
#   u'which',
#   u'is',
#   u'continued',
#   u'the',
#   u'adventure',
#   u'of',
#   u'the',
#   u'sierra',
#   u'morena',
#   u'chapter',
#   u'xxv',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'strange',
#   u'things',
#   u'that',
#   u'happened',
#   u'to',
#   u'the',
#   u'stout',
#   u'knight',
#   u'of',
#   u'la',
#   u'mancha',
#   u'in',
#   u'the',
#   u'sierra',
#   u'morena',
#   u'and',
#   u'of',
#   u'his',
#   u'imitation',
#   u'of',
#   u'the',
#   u'penance',
#   u'of',
#   u'beltenebros',
#   u'chapter',
#   u'xxvi',
#   u'in',
#   u'which',
#   u'are',
#   u'continued',
#   u'the',
#   u'refinements',
#   u'wherewith',
#   u'don',
#   u'quixote',
#   u'played',
#   u'the',
#   u'part',
#   u'of',
#   u'a',
#   u'lover',
#   u'in',
#   u'the',
#   u'sierra',
#   u'morena',
#   u'chapter',
#   u'xxvii',
#   u'of',
#   u'how',
#   u'the',
#   u'curate',
#   u'and',
#   u'the',
#   u'barber',
#   u'proceeded',
#   u'with',
#   u'their',
#   u'scheme',
#   u'together',
#   u'with',
#   u'other',
#   u'matters',
#   u'worthy',
#   u'of',
#   u'record',
#   u'in',
#   u'this',
#   u'great',
#   u'history',
#   u'chapter',
#   u'xxviii',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'strange',
#   u'and',
#   u'delightful',
#   u'adventure',
#   u'that',
#   u'befell',
#   u'the',
#   u'curate',
#   u'and',
#   u'the',
#   u'barber',
#   u'in',
#   u'the',
#   u'same',
#   u'sierra',
#   u'chapter',
#   u'xxix',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'droll',
#   u'device',
#   u'and',
#   u'method',
#   u'adopted',
#   u'to',
#   u'extricate',
#   u'our',
#   u'love-stricken',
#   u'knight',
#   u'from',
#   u'the',
#   u'severe',
#   u'penance',
#   u'he',
#   u'had',
#   u'imposed',
#   u'upon',
#   u'himself',
#   u'chapter',
#   u'xxx',
#   u'which',
#   u'treats',
#   u'of',
#   u'address',
#   u'displayed',
#   u'by',
#   u'the',
#   u'fair',
#   u'dorothea',
#   u'with',
#   u'other',
#   u'matters',
#   u'pleasant',
#   u'and',
#   u'amusing',
#   u'chapter',
#   u'xxxi',
#   u'of',
#   u'the',
#   u'delectable',
#   u'discussion',
#   u'between',
#   u'don',
#   u'quixote',
#   u'and',
#   u'sancho',
#   u'panza',
#   u'his',
#   u'squire',
#   u'together',
#   u'with',
#   u'other',
#   u'incidents',
#   u'chapter',
#   u'xxxii',
#   u'which',
#   u'treats',
#   u'of',
#   u'what',
#   u'befell',
#   u'don',
#   u"quixote's",
#   u'party',
#   u'at',
#   u'the',
#   u'inn',
#   u'chapter',
#   u'xxxiii',
#   u'in',
#   u'which',
#   u'is',
#   u'related',
#   u'the',
#   u'novel',
#   u'of',
#   u'the',
#   u'ill-advised',
#   u'curiosity',
#   u'chapter',
#   u'xxxiv',
#   u'in',
#   u'which',
#   u'is',
#   u'continued',
#   u'the',
#   u'novel',
#   u'of',
#   u'the',
#   u'ill-advised',
#   u'curiosity',
#   u'chapter',
#   u'xxxv',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'heroic',
#   u'and',
#   u'prodigious',
#   u'battle',
#   u'don',
#   u'quixote',
#   u'had',
#   u'with',
#   u'certain',
#   u'skins',
#   u'of',
#   u'red',
#   u'wine',
#   u'and',
#   u'brings',
#   u'the',
#   u'novel',
#   u'of',
#   u'the',
#   u'ill-advised',
#   u'curiosity',
#   u'to',
#   u'a',
#   u'close',
#   u'chapter',
#   u'xxxvi',
#   u'which',
#   u'treats',
#   u'of',
#   u'more',
#   u'curious',
#   u'incidents',
#   u'that',
#   u'occurred',
#   u'at',
#   u'the',
#   u'inn',
#   u'chapter',
#   u'xxxvii',
#   u'in',
#   u'which',
#   u'is',
#   u'continued',
#   u'the',
#   u'story',
#   u'of',
#   u'the',
#   u'famous',
#   u'princess',
#   u'micomicona',
#   u'with',
#   u'other',
#   u'droll',
#   u'adventures',
#   u'chapter',
#   u'xxxviii',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'curious',
#   u'discourse',
#   u'don',
#   u'quixote',
#   u'delivered',
#   u'on',
#   u'arms',
#   u'and',
#   u'letters',
#   u'chapter',
#   u'xxxix',
#   u'wherein',
#   u'the',
#   u'captive',
#   u'relates',
#   u'his',
#   u'life',
#   u'and',
#   u'adventures',
#   u'chapter',
#   u'xl',
#   u'in',
#   u'which',
#   u'the',
#   u'story',
#   u'of',
#   u'the',
#   u'captive',
#   u'is',
#   u'continued',
#   u'chapter',
#   u'xli',
#   u'in',
#   u'which',
#   u'the',
#   u'captive',
#   u'still',
#   u'continues',
#   u'his',
#   u'adventures',
#   u'chapter',
#   u'xlii',
#   u'which',
#   u'treats',
#   u'of',
#   u'what',
#   u'further',
#   u'took',
#   u'place',
#   u'in',
#   u'the',
#   u'inn',
#   u'and',
#   u'of',
#   u'several',
#   u'other',
#   u'things',
#   u'worth',
#   u'knowing',
#   u'chapter',
#   u'xliii',
#   u'wherein',
#   u'is',
#   u'related',
#   u'the',
#   u'pleasant',
#   u'story',
#   u'of',
#   u'the',
#   u'muleteer',
#   u'together',
#   u'with',
#   u'other',
#   u'strange',
#   u'things',
#   u'that',
#   u'came',
#   u'to',
#   u'pass',
#   u'in',
#   u'the',
#   u'inn',
#   u'chapter',
#   u'xliv',
#   u'in',
#   u'which',
#   u'are',
#   u'continued',
#   u'the',
#   u'unheard-of',
#   u'adventures',
#   u'of',
#   u'the',
#   u'inn',
#   u'chapter',
#   u'xlv',
#   u'in',
#   u'which',
#   u'the',
#   u'doubtful',
#   u'question',
#   u'of',
#   u"mambrino's",
#   u'helmet',
#   u'and',
#   u'the',
#   u'pack-saddle',
#   u'is',
#   u'finally',
#   u'settled',
#   u'with',
#   u'other',
#   u'adventures',
#   u'that',
#   u'occurred',
#   u'in',
#   u'truth',
#   u'and',
#   u'earnest',
#   u'chapter',
#   u'xlvi',
#   u'of',
#   u'the',
#   u'end',
#   u'of',
#   u'the',
#   u'notable',
#   u'adventure',
#   u'of',
#   u'the',
#   u'officers',
#   u'of',
#   u'the',
#   u'holy',
#   u'brotherhood',
#   u'and',
#   u'of',
#   u'the',
#   u'great',
#   u'ferocity',
#   u'of',
#   u'our',
#   u'worthy',
#   u'knight',
#   u'don',
#   u'quixote',
#   u'chapter',
#   u'xlvii',
#   u'of',
#   u'the',
#   u'strange',
#   u'manner',
#   u'in',
#   u'which',
#   u'don',
#   u'quixote',
#   u'of',
#   u'la',
#   u'mancha',
#   u'was',
#   u'carried',
#   u'away',
#   u'enchanted',
#   u'together',
#   u'with',
#   u'other',
#   u'remarkable',
#   u'incidents',
#   u'chapter',
#   u'xlviii',
#   u'in',
#   u'which',
#   u'the',
#   u'canon',
#   u'pursues',
#   u'the',
#   u'subject',
#   u'of',
#   u'the',
#   u'books',
#   u'of',
#   u'chivalry',
#   u'with',
#   u'other',
#   u'matters',
#   u'worthy',
#   u'of',
#   u'his',
#   u'wit',
#   u'chapter',
#   u'xlix',
#   u'which',
#   u'treats',
#   u'of',
#   u'the',
#   u'shrewd',
#   u'conversation',
#   u'which',
#   u'sancho',
#   u'panza',
#   u'held',
#   u'with',
#   u'his',
#   u'master',
#   u'don',
#   u'quixote',
#   u'chapter',
#   u'l',
#   u'of',
#   u'the',
#   u'shrewd',
#   u'controversy',
#   u'which',
#   u'don',
#   u'quixote',
#   u'and',
#   u'the',
#   u'canon',
#   u'held',
#   u'together',
#   u'with',
#   u'other',
#   u'incidents',
#   u'chapter',
#   u'li',
#   u'which',
#   u'deals',
#   u'with',
#   u'what',
#   u'the',
#   u'goatherd',
#   u'told',
#   u'those',
#   u'who',
#   u'were',
#   u'carrying',
#   u'off',
#   u'don',
#   u'quixote',
#   u'chapter',
#   u'lii',
#   u'of',
#   u'the',
#   u'quarrel',
#   u'that',
#   u'don',
#   u'quixote',
#   u'had',
#   u'with',
#   u'the',
#   u'goatherd',
#   u'together',
#   ...]]

# %% [markdown]
# Cool - looks like I've got all the books in there

# %%
len(all_transf_books_lst)
# Out:
# 95

# %% [markdown]
# ## EDA Step 1.5: Write code snippets to do all the calculations, print-outs, and obj creation that I'll use for the rest of the EDA

# %% [markdown]
# How long is each book (hom many totoal words?)

# %%
book_lengths = []

for tup in zip(fileid_lst, all_transf_books_lst):
    book_lengths.append((tup[0], len(tup[1])))
    
book_lengths
# Out:
# [('10-clean.txt', 821133),
#  ('100-clean.txt', 883320),
#  ('105-clean.txt', 83286),
#  ('108-clean.txt', 112139),
#  ('1080-clean.txt', 3410),
#  ('11-clean.txt', 26449),
#  ('1112-clean.txt', 25898),
#  ('1184-clean.txt', 461184),
#  ('12-clean.txt', 29293),
#  ('120-clean.txt', 68589),
#  ('1232-clean.txt', 49612),
#  ('1260-clean.txt', 185468),
#  ('1322-clean.txt', 121712),
#  ('1342-clean.txt', 121567),
#  ('135-clean.txt', 565761),
#  ('1399-clean.txt', 349978),
#  ('140-clean.txt', 149124),
#  ('1400-clean.txt', 184403),
#  ('1404-clean.txt', 192349),
#  ('14264-clean.txt', 76656),
#  ('147-clean.txt', 21997),
#  ('1497-clean.txt', 216243),
#  ('15399-clean.txt', 82564),
#  ('158-clean.txt', 157441),
#  ('16-clean.txt', 47439),
#  ('160-clean.txt', 63992),
#  ('161-clean.txt', 118580),
#  ('16382-clean.txt', 135922),
#  ('1661-clean.txt', 104493),
#  ('1727-clean.txt', 129410),
#  ('174-clean.txt', 78934),
#  ('1952-yellow_wallpaper-clean.txt', 6067),
#  ('19942-clean.txt', 35861),
#  ('20-clean.txt', 80059),
#  ('20203-clean.txt', 76167),
#  ('203-clean.txt', 180605),
#  ('205-clean.txt', 115797),
#  ('21279-clean.txt', 2591),
#  ('2148-clean.txt', 95057),
#  ('2174-clean.txt', 23416),
#  ('219-clean.txt', 37908),
#  ('224-clean.txt', 130250),
#  ('23-clean.txt', 40747),
#  ('236-clean.txt', 50836),
#  ('2500-clean.txt', 39140),
#  ('25305-clean.txt', 84605),
#  ('2591-clean.txt', 101109),
#  ('2600-clean.txt', 563288),
#  ('2680-clean.txt', 72026),
#  ('2701-moby-clean.txt', 212103),
#  ('28054-clean.txt', 350856),
#  ('2814-clean.txt', 67560),
#  ('2852-clean.txt', 59122),
#  ('28520-clean.txt', 32090),
#  ('30360-clean.txt', 260892),
#  ('30601-clean.txt', 60458),
#  ('3207-clean.txt', 213339),
#  ('33-clean.txt', 83620),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 161380),
#  ('34901-clean.txt', 52040),
#  ('35-clean.txt', 32306),
#  ('36-clean.txt', 59973),
#  ('3600-clean.txt', 525860),
#  ('38427-clean.txt', 200563),
#  ('408-clean.txt', 68689),
#  ('41-clean.txt', 12214),
#  ('42-clean.txt', 25740),
#  ('4300-clean.txt', 264936),
#  ('4363-clean.txt', 62655),
#  ('45-clean.txt', 102520),
#  ('4517-clean.txt', 34712),
#  ('46-clean.txt', 28541),
#  ('514-clean.txt', 186061),
#  ('5200-clean.txt', 22099),
#  ('521-clean.txt', 120826),
#  ('526-clean.txt', 38122),
#  ('55-clean.txt', 39588),
#  ('55387-clean.txt', 21463),
#  ('55404-clean.txt', 91629),
#  ('6130-clean.txt', 189451),
#  ('730-clean.txt', 157981),
#  ('7370-clean.txt', 56563),
#  ('74-clean.txt', 70801),
#  ('76-clean.txt', 111217),
#  ('768-clean.txt', 115911),
#  ('829-clean.txt', 104294),
#  ('84-clean.txt', 74960),
#  ('844-clean.txt', 20733),
#  ('851-clean.txt', 20204),
#  ('863-clean.txt', 56543),
#  ('8800-clean.txt', 108517),
#  ('932-clean.txt', 7065),
#  ('98-clean.txt', 135842),
#  ('996-clean.txt', 425901)]

# %% [markdown]
# Average number of tokens per book

# %%
int(np.mean([len(book) for book in all_transf_books_lst]))
# Out:
# 132124

# %% [markdown]
# Make a dictionary - a count of the number of times each word appears in each book

# %%
dictionary = corpora.Dictionary(all_transf_books_lst)

# %% [markdown]
# Confirm: yup, it's got words in it

# %%
dictionary[0], dictionary[10], dictionary[1000], dictionary[5000]
# Out:
# (u'', u'mozah', u'tookest', u'89:4')

# %%
type(dictionary)
# Out:
# gensim.corpora.dictionary.Dictionary

# %% [markdown]
# I'd be interested to see this as pandas dataframe - but this doesn't work

# %%
#df = pd.DataFrame(dictionary)
#df.head()

# %% [markdown]
# How many words in this dictionary?

# %%
len(dictionary)
# Out:
# 195104

# %% [markdown]
# Do the contents look right?

# %%
print(dictionary)
# Out:
# Dictionary(195104 unique tokens: [u'', u'biennials', u'lenitives', u'unsupportable', u'nunnery']...)

# %% [markdown]
# Save out the dictionary

# %%
filename = 'tokenized.dict'

dictionary.save(outputs_dir + filename)

# %%
zip(fileid_lst, [len(dictionary.doc2bow(book)) for book in all_transf_books_lst])
# Out:
# [('10-clean.txt', 17331),
#  ('100-clean.txt', 28919),
#  ('105-clean.txt', 6046),
#  ('108-clean.txt', 8707),
#  ('1080-clean.txt', 1087),
#  ('11-clean.txt', 2780),
#  ('1112-clean.txt', 3821),
#  ('1184-clean.txt', 26118),
#  ('12-clean.txt', 3097),
#  ('120-clean.txt', 6603),
#  ('1232-clean.txt', 5284),
#  ('1260-clean.txt', 14991),
#  ('1322-clean.txt', 14721),
#  ('1342-clean.txt', 6842),
#  ('135-clean.txt', 26112),
#  ('1399-clean.txt', 14473),
#  ('140-clean.txt', 11656),
#  ('1400-clean.txt', 12334),
#  ('1404-clean.txt', 8954),
#  ('14264-clean.txt', 5571),
#  ('147-clean.txt', 3595),
#  ('1497-clean.txt', 11362),
#  ('15399-clean.txt', 7436),
#  ('158-clean.txt', 10057),
#  ('16-clean.txt', 5026),
#  ('160-clean.txt', 7204),
#  ('161-clean.txt', 7509),
#  ('16382-clean.txt', 11299),
#  ('1661-clean.txt', 8459),
#  ('1727-clean.txt', 8066),
#  ('174-clean.txt', 7324),
#  ('1952-yellow_wallpaper-clean.txt', 1270),
#  ('19942-clean.txt', 5207),
#  ('20-clean.txt', 10237),
#  ('20203-clean.txt', 8300),
#  ('203-clean.txt', 13909),
#  ('205-clean.txt', 11930),
#  ('21279-clean.txt', 839),
#  ('2148-clean.txt', 11743),
#  ('2174-clean.txt', 3685),
#  ('219-clean.txt', 6024),
#  ('224-clean.txt', 11724),
#  ('23-clean.txt', 5394),
#  ('236-clean.txt', 5125),
#  ('2500-clean.txt', 3666),
#  ('25305-clean.txt', 8226),
#  ('2591-clean.txt', 5054),
#  ('2600-clean.txt', 25635),
#  ('2680-clean.txt', 6370),
#  ('2701-moby-clean.txt', 20244),
#  ('28054-clean.txt', 13684),
#  ('2814-clean.txt', 8688),
#  ('2852-clean.txt', 5838),
#  ('28520-clean.txt', 3631),
#  ('30360-clean.txt', 12374),
#  ('30601-clean.txt', 6910),
#  ('3207-clean.txt', 10055),
#  ('33-clean.txt', 9687),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10633),
#  ('34901-clean.txt', 5886),
#  ('35-clean.txt', 4814),
#  ('36-clean.txt', 7153),
#  ('3600-clean.txt', 27588),
#  ('38427-clean.txt', 10638),
#  ('408-clean.txt', 9327),
#  ('41-clean.txt', 3234),
#  ('42-clean.txt', 4176),
#  ('4300-clean.txt', 30767),
#  ('4363-clean.txt', 9280),
#  ('45-clean.txt', 8278),
#  ('4517-clean.txt', 4755),
#  ('46-clean.txt', 4459),
#  ('514-clean.txt', 11344),
#  ('5200-clean.txt', 2631),
#  ('521-clean.txt', 6553),
#  ('526-clean.txt', 6038),
#  ('55-clean.txt', 2996),
#  ('55387-clean.txt', 3164),
#  ('55404-clean.txt', 9243),
#  ('6130-clean.txt', 14263),
#  ('730-clean.txt', 11424),
#  ('7370-clean.txt', 4753),
#  ('74-clean.txt', 8378),
#  ('76-clean.txt', 7584),
#  ('768-clean.txt', 10220),
#  ('829-clean.txt', 8411),
#  ('84-clean.txt', 7203),
#  ('844-clean.txt', 2699),
#  ('851-clean.txt', 2355),
#  ('863-clean.txt', 5774),
#  ('8800-clean.txt', 11335),
#  ('932-clean.txt', 2124),
#  ('98-clean.txt', 10803),
#  ('996-clean.txt', 16872)]

# %% [markdown]
# Make a corpus!

# %%
corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]

# %% [markdown]
# Check that it has all the books

# %%
len(corpus)
# Out:
# 95

# %% [markdown]
# View it as a dataframe

# %%
df = pd.DataFrame(corpus)
df.head()
# Out:
#       0        1         2         3         4          5         6      \
# 0    (0, 3)   (1, 4)    (2, 1)    (3, 1)    (4, 1)     (5, 1)    (6, 1)
# 1  (0, 324)  (8, 28)  (9, 148)  (13, 38)  (15, 28)   (18, 28)  (21, 29)
# 2    (0, 1)  (9, 14)   (13, 3)   (18, 5)   (21, 2)    (23, 9)   (32, 1)
# 3   (0, 22)   (8, 7)   (9, 15)   (13, 7)   (21, 3)   (23, 41)   (44, 3)
# 4    (9, 5)  (23, 1)   (57, 2)   (98, 4)  (132, 1)  (154, 10)  (155, 1)
#
#         7         8         9      ...  30757 30758 30759 30760 30761 30762  \
# 0      (7, 1)    (8, 4)  (9, 328)  ...   None  None  None  None  None  None
# 1  (23, 3059)   (25, 3)   (26, 1)  ...   None  None  None  None  None  None
# 2    (44, 12)   (48, 2)   (57, 3)  ...   None  None  None  None  None  None
# 3     (47, 1)   (48, 2)   (55, 4)  ...   None  None  None  None  None  None
# 4    (205, 5)  (213, 1)  (215, 4)  ...   None  None  None  None  None  None
#
#   30763 30764 30765 30766
# 0  None  None  None  None
# 1  None  None  None  None
# 2  None  None  None  None
# 3  None  None  None  None
# 4  None  None  None  None
#
# [5 rows x 30767 columns]

# %% [markdown]
# Why doesn't it have the same number of cols as the length of the dictionary...

# %%
#check same process with 1 book - see how dict/corp/df size differ

# %% [markdown]
# Number of unique words in each book

# %%
unique_toks_num_lst = [len(book) for book in corpus]
unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)

unique_toks_per_fileid
# Out:
# [('10-clean.txt', 17331),
#  ('100-clean.txt', 28919),
#  ('105-clean.txt', 6046),
#  ('108-clean.txt', 8707),
#  ('1080-clean.txt', 1087),
#  ('11-clean.txt', 2780),
#  ('1112-clean.txt', 3821),
#  ('1184-clean.txt', 26118),
#  ('12-clean.txt', 3097),
#  ('120-clean.txt', 6603),
#  ('1232-clean.txt', 5284),
#  ('1260-clean.txt', 14991),
#  ('1322-clean.txt', 14721),
#  ('1342-clean.txt', 6842),
#  ('135-clean.txt', 26112),
#  ('1399-clean.txt', 14473),
#  ('140-clean.txt', 11656),
#  ('1400-clean.txt', 12334),
#  ('1404-clean.txt', 8954),
#  ('14264-clean.txt', 5571),
#  ('147-clean.txt', 3595),
#  ('1497-clean.txt', 11362),
#  ('15399-clean.txt', 7436),
#  ('158-clean.txt', 10057),
#  ('16-clean.txt', 5026),
#  ('160-clean.txt', 7204),
#  ('161-clean.txt', 7509),
#  ('16382-clean.txt', 11299),
#  ('1661-clean.txt', 8459),
#  ('1727-clean.txt', 8066),
#  ('174-clean.txt', 7324),
#  ('1952-yellow_wallpaper-clean.txt', 1270),
#  ('19942-clean.txt', 5207),
#  ('20-clean.txt', 10237),
#  ('20203-clean.txt', 8300),
#  ('203-clean.txt', 13909),
#  ('205-clean.txt', 11930),
#  ('21279-clean.txt', 839),
#  ('2148-clean.txt', 11743),
#  ('2174-clean.txt', 3685),
#  ('219-clean.txt', 6024),
#  ('224-clean.txt', 11724),
#  ('23-clean.txt', 5394),
#  ('236-clean.txt', 5125),
#  ('2500-clean.txt', 3666),
#  ('25305-clean.txt', 8226),
#  ('2591-clean.txt', 5054),
#  ('2600-clean.txt', 25635),
#  ('2680-clean.txt', 6370),
#  ('2701-moby-clean.txt', 20244),
#  ('28054-clean.txt', 13684),
#  ('2814-clean.txt', 8688),
#  ('2852-clean.txt', 5838),
#  ('28520-clean.txt', 3631),
#  ('30360-clean.txt', 12374),
#  ('30601-clean.txt', 6910),
#  ('3207-clean.txt', 10055),
#  ('33-clean.txt', 9687),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10633),
#  ('34901-clean.txt', 5886),
#  ('35-clean.txt', 4814),
#  ('36-clean.txt', 7153),
#  ('3600-clean.txt', 27588),
#  ('38427-clean.txt', 10638),
#  ('408-clean.txt', 9327),
#  ('41-clean.txt', 3234),
#  ('42-clean.txt', 4176),
#  ('4300-clean.txt', 30767),
#  ('4363-clean.txt', 9280),
#  ('45-clean.txt', 8278),
#  ('4517-clean.txt', 4755),
#  ('46-clean.txt', 4459),
#  ('514-clean.txt', 11344),
#  ('5200-clean.txt', 2631),
#  ('521-clean.txt', 6553),
#  ('526-clean.txt', 6038),
#  ('55-clean.txt', 2996),
#  ('55387-clean.txt', 3164),
#  ('55404-clean.txt', 9243),
#  ('6130-clean.txt', 14263),
#  ('730-clean.txt', 11424),
#  ('7370-clean.txt', 4753),
#  ('74-clean.txt', 8378),
#  ('76-clean.txt', 7584),
#  ('768-clean.txt', 10220),
#  ('829-clean.txt', 8411),
#  ('84-clean.txt', 7203),
#  ('844-clean.txt', 2699),
#  ('851-clean.txt', 2355),
#  ('863-clean.txt', 5774),
#  ('8800-clean.txt', 11335),
#  ('932-clean.txt', 2124),
#  ('98-clean.txt', 10803),
#  ('996-clean.txt', 16872)]

# %% [markdown]
# Average unique words per book

# %%
avg_unique_toks = int(np.mean(unique_toks_num_lst))
avg_unique_toks
# Out:
# 9004

# %% [markdown]
# Save out the corpus

# %%
filename = 'tokenized_corpus.mm'

corpora.MmCorpus.serialize(outputs_dir + filename, corpus)

# %% [markdown]
# ## EDA and Saving helper funtions
#
# To automate next few EDA rounds

# %%
def eda(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, outputs_dir=outputs_dir):
    '''
    Save the outputs of the most recent eda step
    '''
    dictionary.save(outputs_dir + distinguishing_str + '.dict')
    corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)

# %% [markdown]
# ### EDA items
# * List of book lengths (total num of tokens for each book)
# * Average number of tokens per book
# * Number of words in corpus (dictionary length)
#     * Dictionary (not viewed)
# * Unique tokens per book
# * Average number of unique tokens per book
#     * Corpus (not viewe)
#
# Save everything after eda step

# %% [markdown]
# ### To summarize the 'simple tokenization' EDA step (#1):

# %%
output_v1 = eda(transform_txt_file_v1)

# %%
book_lengths1, avg_num_tokens1, dictionary1, dictionary_length1, unique_toks_per_fileid1, \
    avg_unique_toks1, corpus1 = output_v1

# %%
print "Average number of tokens in a book: ", avg_num_tokens1
print "   "
print "Average unique tokens in a book: ", avg_unique_toks1
print "   "
print "Total number of words (dictionary length): ", dictionary_length1
# Out:
# Average number of tokens in a book:  132124
#
# Average unique tokens in a book:  9004
#
# Total number of words (dictionary length):  195104

# %%
##for pres, note the sparcity problem - 9000 vs. 195k == 186k empty

# %%
book_lengths1
# Out:
# [('10-clean.txt', 821133),
#  ('100-clean.txt', 883320),
#  ('105-clean.txt', 83286),
#  ('108-clean.txt', 112139),
#  ('1080-clean.txt', 3410),
#  ('11-clean.txt', 26449),
#  ('1112-clean.txt', 25898),
#  ('1184-clean.txt', 461184),
#  ('12-clean.txt', 29293),
#  ('120-clean.txt', 68589),
#  ('1232-clean.txt', 49612),
#  ('1260-clean.txt', 185468),
#  ('1322-clean.txt', 121712),
#  ('1342-clean.txt', 121567),
#  ('135-clean.txt', 565761),
#  ('1399-clean.txt', 349978),
#  ('140-clean.txt', 149124),
#  ('1400-clean.txt', 184403),
#  ('1404-clean.txt', 192349),
#  ('14264-clean.txt', 76656),
#  ('147-clean.txt', 21997),
#  ('1497-clean.txt', 216243),
#  ('15399-clean.txt', 82564),
#  ('158-clean.txt', 157441),
#  ('16-clean.txt', 47439),
#  ('160-clean.txt', 63992),
#  ('161-clean.txt', 118580),
#  ('16382-clean.txt', 135922),
#  ('1661-clean.txt', 104493),
#  ('1727-clean.txt', 129410),
#  ('174-clean.txt', 78934),
#  ('1952-yellow_wallpaper-clean.txt', 6067),
#  ('19942-clean.txt', 35861),
#  ('20-clean.txt', 80059),
#  ('20203-clean.txt', 76167),
#  ('203-clean.txt', 180605),
#  ('205-clean.txt', 115797),
#  ('21279-clean.txt', 2591),
#  ('2148-clean.txt', 95057),
#  ('2174-clean.txt', 23416),
#  ('219-clean.txt', 37908),
#  ('224-clean.txt', 130250),
#  ('23-clean.txt', 40747),
#  ('236-clean.txt', 50836),
#  ('2500-clean.txt', 39140),
#  ('25305-clean.txt', 84605),
#  ('2591-clean.txt', 101109),
#  ('2600-clean.txt', 563288),
#  ('2680-clean.txt', 72026),
#  ('2701-moby-clean.txt', 212103),
#  ('28054-clean.txt', 350856),
#  ('2814-clean.txt', 67560),
#  ('2852-clean.txt', 59122),
#  ('28520-clean.txt', 32090),
#  ('30360-clean.txt', 260892),
#  ('30601-clean.txt', 60458),
#  ('3207-clean.txt', 213339),
#  ('33-clean.txt', 83620),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 161380),
#  ('34901-clean.txt', 52040),
#  ('35-clean.txt', 32306),
#  ('36-clean.txt', 59973),
#  ('3600-clean.txt', 525860),
#  ('38427-clean.txt', 200563),
#  ('408-clean.txt', 68689),
#  ('41-clean.txt', 12214),
#  ('42-clean.txt', 25740),
#  ('4300-clean.txt', 264936),
#  ('4363-clean.txt', 62655),
#  ('45-clean.txt', 102520),
#  ('4517-clean.txt', 34712),
#  ('46-clean.txt', 28541),
#  ('514-clean.txt', 186061),
#  ('5200-clean.txt', 22099),
#  ('521-clean.txt', 120826),
#  ('526-clean.txt', 38122),
#  ('55-clean.txt', 39588),
#  ('55387-clean.txt', 21463),
#  ('55404-clean.txt', 91629),
#  ('6130-clean.txt', 189451),
#  ('730-clean.txt', 157981),
#  ('7370-clean.txt', 56563),
#  ('74-clean.txt', 70801),
#  ('76-clean.txt', 111217),
#  ('768-clean.txt', 115911),
#  ('829-clean.txt', 104294),
#  ('84-clean.txt', 74960),
#  ('844-clean.txt', 20733),
#  ('851-clean.txt', 20204),
#  ('863-clean.txt', 56543),
#  ('8800-clean.txt', 108517),
#  ('932-clean.txt', 7065),
#  ('98-clean.txt', 135842),
#  ('996-clean.txt', 425901)]

# %%
unique_toks_per_fileid1
# Out:
# [('10-clean.txt', 17331),
#  ('100-clean.txt', 28919),
#  ('105-clean.txt', 6046),
#  ('108-clean.txt', 8707),
#  ('1080-clean.txt', 1087),
#  ('11-clean.txt', 2780),
#  ('1112-clean.txt', 3821),
#  ('1184-clean.txt', 26118),
#  ('12-clean.txt', 3097),
#  ('120-clean.txt', 6603),
#  ('1232-clean.txt', 5284),
#  ('1260-clean.txt', 14991),
#  ('1322-clean.txt', 14721),
#  ('1342-clean.txt', 6842),
#  ('135-clean.txt', 26112),
#  ('1399-clean.txt', 14473),
#  ('140-clean.txt', 11656),
#  ('1400-clean.txt', 12334),
#  ('1404-clean.txt', 8954),
#  ('14264-clean.txt', 5571),
#  ('147-clean.txt', 3595),
#  ('1497-clean.txt', 11362),
#  ('15399-clean.txt', 7436),
#  ('158-clean.txt', 10057),
#  ('16-clean.txt', 5026),
#  ('160-clean.txt', 7204),
#  ('161-clean.txt', 7509),
#  ('16382-clean.txt', 11299),
#  ('1661-clean.txt', 8459),
#  ('1727-clean.txt', 8066),
#  ('174-clean.txt', 7324),
#  ('1952-yellow_wallpaper-clean.txt', 1270),
#  ('19942-clean.txt', 5207),
#  ('20-clean.txt', 10237),
#  ('20203-clean.txt', 8300),
#  ('203-clean.txt', 13909),
#  ('205-clean.txt', 11930),
#  ('21279-clean.txt', 839),
#  ('2148-clean.txt', 11743),
#  ('2174-clean.txt', 3685),
#  ('219-clean.txt', 6024),
#  ('224-clean.txt', 11724),
#  ('23-clean.txt', 5394),
#  ('236-clean.txt', 5125),
#  ('2500-clean.txt', 3666),
#  ('25305-clean.txt', 8226),
#  ('2591-clean.txt', 5054),
#  ('2600-clean.txt', 25635),
#  ('2680-clean.txt', 6370),
#  ('2701-moby-clean.txt', 20244),
#  ('28054-clean.txt', 13684),
#  ('2814-clean.txt', 8688),
#  ('2852-clean.txt', 5838),
#  ('28520-clean.txt', 3631),
#  ('30360-clean.txt', 12374),
#  ('30601-clean.txt', 6910),
#  ('3207-clean.txt', 10055),
#  ('33-clean.txt', 9687),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10633),
#  ('34901-clean.txt', 5886),
#  ('35-clean.txt', 4814),
#  ('36-clean.txt', 7153),
#  ('3600-clean.txt', 27588),
#  ('38427-clean.txt', 10638),
#  ('408-clean.txt', 9327),
#  ('41-clean.txt', 3234),
#  ('42-clean.txt', 4176),
#  ('4300-clean.txt', 30767),
#  ('4363-clean.txt', 9280),
#  ('45-clean.txt', 8278),
#  ('4517-clean.txt', 4755),
#  ('46-clean.txt', 4459),
#  ('514-clean.txt', 11344),
#  ('5200-clean.txt', 2631),
#  ('521-clean.txt', 6553),
#  ('526-clean.txt', 6038),
#  ('55-clean.txt', 2996),
#  ('55387-clean.txt', 3164),
#  ('55404-clean.txt', 9243),
#  ('6130-clean.txt', 14263),
#  ('730-clean.txt', 11424),
#  ('7370-clean.txt', 4753),
#  ('74-clean.txt', 8378),
#  ('76-clean.txt', 7584),
#  ('768-clean.txt', 10220),
#  ('829-clean.txt', 8411),
#  ('84-clean.txt', 7203),
#  ('844-clean.txt', 2699),
#  ('851-clean.txt', 2355),
#  ('863-clean.txt', 5774),
#  ('8800-clean.txt', 11335),
#  ('932-clean.txt', 2124),
#  ('98-clean.txt', 10803),
#  ('996-clean.txt', 16872)]

# %%
save_stuff('simple_tok', dictionary1, corpus1)

# %% [markdown]
# ## EDA Step 2: + stop word removal

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = set(stopwords.words('english'))
print stop
# Out:
# [nltk_data] Downloading package stopwords to /home/ubuntu/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# set([u'all', u'just', u'being', u'over', u'both', u'through', u'yourselves', u'its', u'before', u'o', u'hadn', u'herself', u'll', u'had', u'should', u'to', u'only', u'won', u'under', u'ours', u'has', u'do', u'them', u'his', u'very', u'they', u'not', u'during', u'now', u'him', u'nor', u'd', u'did', u'didn', u'this', u'she', u'each', u'further', u'where', u'few', u'because', u'doing', u'some', u'hasn', u'are', u'our', u'ourselves', u'out', u'what', u'for', u'while', u're', u'does', u'above', u'between', u'mustn', u't', u'be', u'we', u'who', u'were', u'here', u'shouldn', u'hers', u'by', u'on', u'about', u'couldn', u'of', u'against', u's', u'isn', u'or', u'own', u'into', u'yourself', u'down', u'mightn', u'wasn', u'your', u'from', u'her', u'their', u'aren', u'there', u'been', u'whom', u'too', u'wouldn', u'themselves', u'weren', u'was', u'until', u'more', u'himself', u'that', u'but', u'don', u'with', u'than', u'those', u'he', u'me', u'myself', u'ma', u'these', u'up', u'will', u'below', u'ain', u'can', u'theirs', u'my', u'and', u've', u'then', u'is', u'am', u'it', u'doesn', u'an', u'as', u'itself', u'at', u'have', u'in', u'any', u'if', u'again', u'no', u'when', u'same', u'how', u'other', u'which', u'you', u'shan', u'needn', u'haven', u'after', u'most', u'such', u'why', u'a', u'off', u'i', u'm', u'yours', u'so', u'y', u'the', u'having', u'once'])

# %%
def transform_txt_file_v2(fname, root=source_dir, stop_words=stop):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Assumes you want to remove empty lines and tokenize (because you do)
    '''
    fp = root + fname
    book_as_lst = []
    for line in IterFile(fp):
        
        if empty_line_check(line) == False:
            line = basic_tokenize(line)
            
            if stop_words !=None:
                line = remove_stop_words(line, stop_words)
        
        book_as_lst.extend(line)
        
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty
    
def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]    
            
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
output_v2 = eda(transform_txt_file_v2)

# %%
book_lengths2, avg_num_tokens2, dictionary2, dictionary_length2, \
    unique_toks_per_fileid2, avg_unique_toks2, corpus2 = output_v2

# %%
print "Average number of tokens in a book: ", avg_num_tokens2
print "   "
print "Average unique tokens in a book: ", avg_unique_toks2
print "   "
print "Total number of words (dictionary length): ", dictionary_length2
# Out:
# Average number of tokens in a book:  66904
#
# Average unique tokens in a book:  8882
#
# Total number of words (dictionary length):  194961

# %%
#make graph of reduction

# %%
book_lengths2
# Out:
# [('10-clean.txt', 431250),
#  ('100-clean.txt', 481608),
#  ('105-clean.txt', 39320),
#  ('108-clean.txt', 54072),
#  ('1080-clean.txt', 1739),
#  ('11-clean.txt', 13616),
#  ('1112-clean.txt', 15468),
#  ('1184-clean.txt', 251348),
#  ('12-clean.txt', 15589),
#  ('120-clean.txt', 34581),
#  ('1232-clean.txt', 23021),
#  ('1260-clean.txt', 91946),
#  ('1322-clean.txt', 67400),
#  ('1342-clean.txt', 57307),
#  ('135-clean.txt', 288377),
#  ('1399-clean.txt', 173226),
#  ('140-clean.txt', 70693),
#  ('1400-clean.txt', 87450),
#  ('1404-clean.txt', 91284),
#  ('14264-clean.txt', 38978),
#  ('147-clean.txt', 10640),
#  ('1497-clean.txt', 98946),
#  ('15399-clean.txt', 38240),
#  ('158-clean.txt', 75454),
#  ('16-clean.txt', 23919),
#  ('160-clean.txt', 32962),
#  ('161-clean.txt', 56016),
#  ('16382-clean.txt', 71067),
#  ('1661-clean.txt', 49411),
#  ('1727-clean.txt', 59474),
#  ('174-clean.txt', 38744),
#  ('1952-yellow_wallpaper-clean.txt', 2978),
#  ('19942-clean.txt', 18535),
#  ('20-clean.txt', 47100),
#  ('20203-clean.txt', 37660),
#  ('203-clean.txt', 96324),
#  ('205-clean.txt', 54786),
#  ('21279-clean.txt', 1571),
#  ('2148-clean.txt', 46691),
#  ('2174-clean.txt', 23285),
#  ('219-clean.txt', 18469),
#  ('224-clean.txt', 66929),
#  ('23-clean.txt', 19473),
#  ('236-clean.txt', 26308),
#  ('2500-clean.txt', 19035),
#  ('25305-clean.txt', 38416),
#  ('2591-clean.txt', 45883),
#  ('2600-clean.txt', 296264),
#  ('2680-clean.txt', 34779),
#  ('2701-moby-clean.txt', 112067),
#  ('28054-clean.txt', 170412),
#  ('2814-clean.txt', 36937),
#  ('2852-clean.txt', 28211),
#  ('28520-clean.txt', 15768),
#  ('30360-clean.txt', 121187),
#  ('30601-clean.txt', 33035),
#  ('3207-clean.txt', 100707),
#  ('33-clean.txt', 42341),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 75049),
#  ('34901-clean.txt', 24055),
#  ('35-clean.txt', 15812),
#  ('36-clean.txt', 30839),
#  ('3600-clean.txt', 253407),
#  ('38427-clean.txt', 98400),
#  ('408-clean.txt', 36484),
#  ('41-clean.txt', 6235),
#  ('42-clean.txt', 12630),
#  ('4300-clean.txt', 155405),
#  ('4363-clean.txt', 31647),
#  ('45-clean.txt', 54620),
#  ('4517-clean.txt', 17305),
#  ('46-clean.txt', 14621),
#  ('514-clean.txt', 98108),
#  ('5200-clean.txt', 10380),
#  ('521-clean.txt', 51615),
#  ('526-clean.txt', 18687),
#  ('55-clean.txt', 19627),
#  ('55387-clean.txt', 10559),
#  ('55404-clean.txt', 49338),
#  ('6130-clean.txt', 112614),
#  ('730-clean.txt', 82789),
#  ('7370-clean.txt', 25684),
#  ('74-clean.txt', 38214),
#  ('76-clean.txt', 55732),
#  ('768-clean.txt', 57940),
#  ('829-clean.txt', 49050),
#  ('84-clean.txt', 35410),
#  ('844-clean.txt', 11846),
#  ('851-clean.txt', 9049),
#  ('863-clean.txt', 29746),
#  ('8800-clean.txt', 59373),
#  ('932-clean.txt', 3546),
#  ('98-clean.txt', 67493),
#  ('996-clean.txt', 194284)]

# %%
unique_toks_per_fileid2
# Out:
# [('10-clean.txt', 17208),
#  ('100-clean.txt', 28785),
#  ('105-clean.txt', 5922),
#  ('108-clean.txt', 8578),
#  ('1080-clean.txt', 994),
#  ('11-clean.txt', 2653),
#  ('1112-clean.txt', 3701),
#  ('1184-clean.txt', 25988),
#  ('12-clean.txt', 2977),
#  ('120-clean.txt', 6479),
#  ('1232-clean.txt', 5159),
#  ('1260-clean.txt', 14861),
#  ('1322-clean.txt', 14591),
#  ('1342-clean.txt', 6716),
#  ('135-clean.txt', 25978),
#  ('1399-clean.txt', 14342),
#  ('140-clean.txt', 11530),
#  ('1400-clean.txt', 12205),
#  ('1404-clean.txt', 8831),
#  ('14264-clean.txt', 5449),
#  ('147-clean.txt', 3472),
#  ('1497-clean.txt', 11236),
#  ('15399-clean.txt', 7306),
#  ('158-clean.txt', 9933),
#  ('16-clean.txt', 4902),
#  ('160-clean.txt', 7080),
#  ('161-clean.txt', 7387),
#  ('16382-clean.txt', 11174),
#  ('1661-clean.txt', 8332),
#  ('1727-clean.txt', 7939),
#  ('174-clean.txt', 7202),
#  ('1952-yellow_wallpaper-clean.txt', 1164),
#  ('19942-clean.txt', 5078),
#  ('20-clean.txt', 10120),
#  ('20203-clean.txt', 8169),
#  ('203-clean.txt', 13780),
#  ('205-clean.txt', 11802),
#  ('21279-clean.txt', 746),
#  ('2148-clean.txt', 11617),
#  ('2174-clean.txt', 3674),
#  ('219-clean.txt', 5903),
#  ('224-clean.txt', 11595),
#  ('23-clean.txt', 5273),
#  ('236-clean.txt', 5004),
#  ('2500-clean.txt', 3546),
#  ('25305-clean.txt', 8100),
#  ('2591-clean.txt', 4932),
#  ('2600-clean.txt', 25501),
#  ('2680-clean.txt', 6243),
#  ('2701-moby-clean.txt', 20117),
#  ('28054-clean.txt', 13556),
#  ('2814-clean.txt', 8562),
#  ('2852-clean.txt', 5714),
#  ('28520-clean.txt', 3507),
#  ('30360-clean.txt', 12243),
#  ('30601-clean.txt', 6784),
#  ('3207-clean.txt', 9933),
#  ('33-clean.txt', 9561),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10503),
#  ('34901-clean.txt', 5767),
#  ('35-clean.txt', 4693),
#  ('36-clean.txt', 7032),
#  ('3600-clean.txt', 27455),
#  ('38427-clean.txt', 10513),
#  ('408-clean.txt', 9202),
#  ('41-clean.txt', 3120),
#  ('42-clean.txt', 4053),
#  ('4300-clean.txt', 30633),
#  ('4363-clean.txt', 9158),
#  ('45-clean.txt', 8152),
#  ('4517-clean.txt', 4634),
#  ('46-clean.txt', 4340),
#  ('514-clean.txt', 11214),
#  ('5200-clean.txt', 2514),
#  ('521-clean.txt', 6430),
#  ('526-clean.txt', 5917),
#  ('55-clean.txt', 2877),
#  ('55387-clean.txt', 3037),
#  ('55404-clean.txt', 9117),
#  ('6130-clean.txt', 14134),
#  ('730-clean.txt', 11299),
#  ('7370-clean.txt', 4634),
#  ('74-clean.txt', 8250),
#  ('76-clean.txt', 7448),
#  ('768-clean.txt', 10092),
#  ('829-clean.txt', 8286),
#  ('84-clean.txt', 7077),
#  ('844-clean.txt', 2581),
#  ('851-clean.txt', 2238),
#  ('863-clean.txt', 5646),
#  ('8800-clean.txt', 11206),
#  ('932-clean.txt', 2013),
#  ('98-clean.txt', 10675),
#  ('996-clean.txt', 16742)]

# %%
save_stuff('no_stopwords', dictionary2, corpus2)

# %% [markdown]
# ## EDA Step 3: + lemmatization

# %%
from gensim.utils import lemmatize

# %%
def transform_txt_file_v3(fname, root=source_dir, stop_words=stop, \
                         lemma = True):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Note that lemmatizing takes care of the tokenize/punct stripping/lowercasing/
        stopword removal
    '''
    fp = root + fname
    book_as_lst = []
    for line in IterFile(fp):
        
        if empty_line_check(line) == False:
            
            
            if lemma == True:
                line = lemmatize(line)
            
            else:
                line = basic_tokenize(line)
                
                if stop_words !=None:
                    line = remove_stop_words(line, stop_words)
        
            book_as_lst.extend(line)
    
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty

def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
           
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
usher_v3 = transform_txt_file_v3(usher)
usher_v3
# Out:
# ['fall/NN',
#  'house/NN',
#  'usher/NN',
#  'son/NN',
#  'coeur/NN',
#  'luth/NN',
#  'suspendu/NN',
#  'sitot/NN',
#  'qu/NN',
#  'le/NN',
#  'touche/NN',
#  'il/NN',
#  'resonne/NN',
#  'beranger/JJ',
#  'whole/NN',
#  'dull/JJ',
#  'dark/NN',
#  'soundless/NN',
#  'day/NN',
#  'autumn/NN',
#  'year/NN',
#  'cloud/NN',
#  'hung/JJ',
#  'oppressively/RB',
#  'low/JJ',
#  'heaven/NN',
#  'have/VB',
#  'be/VB',
#  'pass/VB',
#  'alone/RB',
#  'horseback/NN',
#  'singularly/RB',
#  'dreary/JJ',
#  'tract/NN',
#  'country/NN',
#  'length/NN',
#  'find/VB',
#  'shade/NN',
#  'evening/NN',
#  'draw/VB',
#  'view/NN',
#  'melancholy/NN',
#  'house/NN',
#  'usher/NN',
#  'know/VB',
#  'not/RB',
#  'be/VB',
#  'first/JJ',
#  'glimpse/NN',
#  'build/VB',
#  'sense/NN',
#  'insufferable/JJ',
#  'gloom/NN',
#  'pervade/VB',
#  'spirit/NN',
#  'say/VB',
#  'insufferable/JJ',
#  'feeling/NN',
#  'be/VB',
#  'unrelieved/JJ',
#  'half/NN',
#  'pleasureable/NN',
#  'poetic/JJ',
#  'sentiment/NN',
#  'mind/NN',
#  'usually/RB',
#  'receive/VB',
#  'even/RB',
#  'sternest/NN',
#  'natural/JJ',
#  'image/NN',
#  'desolate/JJ',
#  'terrible/JJ',
#  'look/VB',
#  'scene/NN',
#  'mere/JJ',
#  'house/NN',
#  'simple/JJ',
#  'landscape/NN',
#  'feature/NN',
#  'domain/NN',
#  'bleak/JJ',
#  'wall/NN',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'few/JJ',
#  'rank/NN',
#  'sedge/NN',
#  'few/JJ',
#  'white/NN',
#  'trunk/NN',
#  'decayed/JJ',
#  'tree/NN',
#  'utter/JJ',
#  'depression/NN',
#  'soul/NN',
#  'compare/VB',
#  'earthly/JJ',
#  'sensation/NN',
#  'more/RB',
#  'properly/RB',
#  'dream/NN',
#  'reveller/JJ',
#  'opium/NN',
#  'bitter/JJ',
#  'lapse/NN',
#  'everyday/JJ',
#  'life/NN',
#  'hideous/JJ',
#  'drop/VB',
#  'veil/NN',
#  'be/VB',
#  'iciness/NN',
#  'sink/VB',
#  'sickening/JJ',
#  'heart/NN',
#  'unredeemed/JJ',
#  'dreariness/NN',
#  'thought/NN',
#  'goading/NN',
#  'imagination/NN',
#  'torture/NN',
#  'aught/NN',
#  'sublime/JJ',
#  'be/VB',
#  'pause/VB',
#  'think/VB',
#  'be/VB',
#  'so/RB',
#  'unnerved/JJ',
#  'contemplation/NN',
#  'house/NN',
#  'usher/NN',
#  'be/VB',
#  'mystery/NN',
#  'insoluble/JJ',
#  'grapple/VB',
#  'shadowy/JJ',
#  'fancy/VB',
#  'crowd/VB',
#  'ponder/VB',
#  'be/VB',
#  'force/VB',
#  'fall/VB',
#  'back/RB',
#  'unsatisfactory/JJ',
#  'conclusion/NN',
#  'doubt/NN',
#  'be/VB',
#  'combination/NN',
#  'very/RB',
#  'simple/JJ',
#  'natural/JJ',
#  'object/NN',
#  'have/VB',
#  'power/NN',
#  'thus/RB',
#  'affect/VB',
#  'still/RB',
#  'analysis/NN',
#  'power/NN',
#  'lie/VB',
#  'consideration/NN',
#  'depth/NN',
#  'be/VB',
#  'possible/JJ',
#  'reflect/VB',
#  'mere/JJ',
#  'different/JJ',
#  'arrangement/NN',
#  'particular/NN',
#  'scene/NN',
#  'detail/NN',
#  'picture/NN',
#  'be/VB',
#  'sufficient/JJ',
#  'modify/VB',
#  'perhaps/RB',
#  'annihilate/VB',
#  'capacity/NN',
#  'sorrowful/JJ',
#  'impression/NN',
#  'act/VB',
#  'idea/NN',
#  'rein/VB',
#  'horse/NN',
#  'precipitous/JJ',
#  'brink/NN',
#  'black/JJ',
#  'lurid/JJ',
#  'tarn/NN',
#  'lay/VB',
#  'unruffled/JJ',
#  'lustre/NN',
#  'dwelling/NN',
#  'gaze/VB',
#  'down/RB',
#  'shudder/VB',
#  'even/RB',
#  'more/RB',
#  'thrilling/JJ',
#  'before/RB',
#  'remodelled/JJ',
#  'inverted/JJ',
#  'image/NN',
#  'grey/JJ',
#  'sedge/NN',
#  'ghastly/JJ',
#  'tree/NN',
#  'stem/VB',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'nevertheless/RB',
#  'mansion/NN',
#  'gloom/NN',
#  'now/RB',
#  'propose/VB',
#  'sojourn/NN',
#  'week/NN',
#  'proprietor/NN',
#  'roderick/NN',
#  'usher/NN',
#  'have/VB',
#  'be/VB',
#  'boon/NN',
#  'companion/NN',
#  'boyhood/NN',
#  'many/JJ',
#  'year/NN',
#  'have/VB',
#  'elapse/VB',
#  'last/JJ',
#  'meeting/NN',
#  'letter/NN',
#  'however/RB',
#  'have/VB',
#  'lately/RB',
#  'reach/VB',
#  'distant/JJ',
#  'part/NN',
#  'country/NN',
#  'letter/NN',
#  'wildly/RB',
#  'importunate/JJ',
#  'nature/NN',
#  'have/VB',
#  'admit/VB',
#  'other/JJ',
#  'personal/JJ',
#  'reply/NN',
#  'ms/NN',
#  'give/VB',
#  'evidence/NN',
#  'nervous/JJ',
#  'agitation/NN',
#  'writer/NN',
#  'speak/VB',
#  'acute/JJ',
#  'bodily/JJ',
#  'illness/NN',
#  'mental/JJ',
#  'disorder/NN',
#  'oppressed/JJ',
#  'earnest/JJ',
#  'desire/NN',
#  'see/VB',
#  'best/NN',
#  'indeed/RB',
#  'only/JJ',
#  'personal/JJ',
#  'friend/NN',
#  'view/NN',
#  'attempt/VB',
#  'cheerfulness/NN',
#  'society/NN',
#  'alleviation/NN',
#  'malady/NN',
#  'be/VB',
#  'manner/NN',
#  'much/JJ',
#  'more/RB',
#  'be/VB',
#  'say/VB',
#  'be/VB',
#  'apparent/JJ',
#  'heart/NN',
#  'go/VB',
#  'request/NN',
#  'allow/VB',
#  'room/NN',
#  'hesitation/NN',
#  'accordingly/RB',
#  'obey/VB',
#  'forthwith/RB',
#  'still/RB',
#  'consider/VB',
#  'very/RB',
#  'singular/JJ',
#  'summons/NN',
#  'boy/NN',
#  'have/VB',
#  'be/VB',
#  'even/RB',
#  'intimate/JJ',
#  'associate/NN',
#  'yet/RB',
#  'really/RB',
#  'know/VB',
#  'little/JJ',
#  'friend/NN',
#  'reserve/NN',
#  'have/VB',
#  'be/VB',
#  'always/RB',
#  'excessive/JJ',
#  'habitual/JJ',
#  'be/VB',
#  'aware/JJ',
#  'however/RB',
#  'very/RB',
#  'ancient/JJ',
#  'family/NN',
#  'have/VB',
#  'be/VB',
#  'note/VB',
#  'time/NN',
#  'mind/NN',
#  'peculiar/JJ',
#  'sensibility/NN',
#  'temperament/NN',
#  'display/VB',
#  'long/JJ',
#  'age/NN',
#  'many/JJ',
#  'work/NN',
#  'exalted/JJ',
#  'art/NN',
#  'manifest/VB',
#  'late/JJ',
#  'repeated/JJ',
#  'deed/NN',
#  'munificent/NN',
#  'yet/RB',
#  'unobtrusive/JJ',
#  'charity/NN',
#  'as/RB',
#  'well/RB',
#  'passionate/JJ',
#  'devotion/NN',
#  'intricacy/NN',
#  'perhaps/RB',
#  'even/RB',
#  'more/RB',
#  'orthodox/JJ',
#  'easily/RB',
#  'recognisable/JJ',
#  'beauty/NN',
#  'musical/JJ',
#  'science/NN',
#  'have/VB',
#  'learn/VB',
#  'too/RB',
#  'very/RB',
#  'remarkable/JJ',
#  'fact/NN',
#  'stem/NN',
#  'usher/NN',
#  'race/NN',
#  'time/NN',
#  'honour/VB',
#  'be/VB',
#  'have/VB',
#  'put/VB',
#  'forth/RB',
#  'period/NN',
#  'enduring/JJ',
#  'branch/NN',
#  'other/JJ',
#  'word/NN',
#  'entire/JJ',
#  'family/NN',
#  'lay/VB',
#  'direct/JJ',
#  'line/NN',
#  'descent/NN',
#  'have/VB',
#  'always/RB',
#  'very/RB',
#  'trifling/JJ',
#  'very/RB',
#  'temporary/JJ',
#  'variation/NN',
#  'so/RB',
#  'lain/VB',
#  'be/VB',
#  'deficiency/NN',
#  'consider/VB',
#  'run/VB',
#  'think/VB',
#  'perfect/JJ',
#  'keep/VB',
#  'character/NN',
#  'premise/NN',
#  'accredit/VB',
#  'character/NN',
#  'person/NN',
#  'speculate/VB',
#  'possible/JJ',
#  'influence/NN',
#  'long/JJ',
#  'lapse/NN',
#  'century/NN',
#  'have/VB',
#  'exercise/VB',
#  'other/JJ',
#  'be/VB',
#  'deficiency/NN',
#  'perhaps/RB',
#  'collateral/NN',
#  'issue/NN',
#  'consequent/JJ',
#  'undeviat/VB',
#  'transmission/NN',
#  'sire/NN',
#  'son/NN',
#  'patrimony/NN',
#  'name/NN',
#  'have/VB',
#  'length/NN',
#  'so/VB',
#  'identify/VB',
#  'merge/VB',
#  'original/JJ',
#  'title/NN',
#  'estate/NN',
#  'quaint/JJ',
#  'equivocal/JJ',
#  'appellation/NN',
#  'house/NN',
#  'usher/NN',
#  'appellation/NN',
#  'seem/VB',
#  'include/VB',
#  'mind/NN',
#  'peasantry/NN',
#  'used/VB',
#  'family/NN',
#  'family/NN',
#  'mansion/NN',
#  'have/VB',
#  'say/VB',
#  'sole/JJ',
#  'effect/NN',
#  'somewhat/RB',
#  'childish/JJ',
#  'experiment/NN',
#  'look/VB',
#  'tarn/NN',
#  'have/VB',
#  'be/VB',
#  'deepen/VB',
#  'first/JJ',
#  'singular/JJ',
#  'impression/NN',
#  'be/VB',
#  'doubt/NN',
#  'consciousness/NN',
#  'rapid/JJ',
#  'increase/NN',
#  'superstition/NN',
#  'not/RB',
#  'term/NN',
#  'serve/VB',
#  'mainly/RB',
#  'accelerate/VB',
#  'increase/VB',
#  'such/JJ',
#  'have/VB',
#  'long/RB',
#  'know/VB',
#  'be/VB',
#  'paradoxical/JJ',
#  'law/NN',
#  'sentiment/NN',
#  'have/VB',
#  'terror/NN',
#  'basis/NN',
#  'have/VB',
#  'be/VB',
#  'reason/NN',
#  'only/RB',
#  'again/RB',
#  'uplift/VB',
#  'eye/NN',
#  'house/NN',
#  'image/NN',
#  'pool/NN',
#  'grow/VB',
#  'mind/VB',
#  'strange/JJ',
#  'fancy/NN',
#  'fancy/NN',
#  'so/RB',
#  'ridiculous/JJ',
#  'indeed/RB',
#  'mention/NN',
#  'show/VB',
#  'vivid/JJ',
#  'force/NN',
#  'sensation/NN',
#  'oppressed/JJ',
#  'have/VB',
#  'so/RB',
#  'work/VB',
#  'imagination/NN',
#  'really/RB',
#  'believe/VB',
#  'whole/JJ',
#  'mansion/NN',
#  'domain/NN',
#  'there/RB',
#  'hang/VB',
#  'atmosphere/NN',
#  'peculiar/JJ',
#  'immediate/JJ',
#  'vicinity/NN',
#  'atmosphere/NN',
#  'have/VB',
#  'affinity/NN',
#  'air/NN',
#  'heaven/NN',
#  'have/VB',
#  'reek/VB',
#  'decayed/JJ',
#  'tree/NN',
#  'grey/JJ',
#  'wall/NN',
#  'silent/JJ',
#  'tarn/NN',
#  'pestilent/JJ',
#  'mystic/JJ',
#  'vapour/NN',
#  'dull/JJ',
#  'sluggish/JJ',
#  'faintly/RB',
#  'discernible/JJ',
#  'leaden/JJ',
#  'hued/NN',
#  'shake/VB',
#  'spirit/NN',
#  'have/VB',
#  'be/VB',
#  'dream/NN',
#  'scan/VB',
#  'more/RB',
#  'narrowly/RB',
#  'real/JJ',
#  'aspect/NN',
#  'build/VB',
#  'principal/JJ',
#  'feature/NN',
#  'seem/VB',
#  'be/VB',
#  'excessive/JJ',
#  'antiquity/NN',
#  'discoloration/NN',
#  'age/NN',
#  'have/VB',
#  'be/VB',
#  'great/JJ',
#  'minute/NN',
#  'fungi/NN',
#  'overspread/VB',
#  'whole/JJ',
#  'exterior/JJ',
#  'hanging/NN',
#  'fine/NN',
#  'tangled/JJ',
#  'web/NN',
#  'work/NN',
#  'eave/NN',
#  'yet/RB',
#  'be/VB',
#  'apart/RB',
#  'extraordinary/JJ',
#  'dilapidation/NN',
#  'portion/NN',
#  'masonry/NN',
#  'have/VB',
#  'fall/VB',
#  'there/RB',
#  'appear/VB',
#  'be/VB',
#  'wild/JJ',
#  'inconsistency/NN',
#  'still/RB',
#  'perfect/JJ',
#  'adaptation/NN',
#  'part/NN',
#  'crumble/VB',
#  'condition/NN',
#  'individual/JJ',
#  'stone/NN',
#  'be/VB',
#  'much/JJ',
#  'remind/VB',
#  'specious/JJ',
#  'totality/NN',
#  'old/JJ',
#  'wood/NN',
#  'work/NN',
#  'have/VB',
#  'rot/VB',
#  'long/JJ',
#  'year/NN',
#  'neglected/JJ',
#  'vault/NN',
#  'disturbance/NN',
#  'breath/NN',
#  'external/JJ',
#  'air/NN',
#  'indication/NN',
#  'extensive/JJ',
#  'decay/NN',
#  'however/RB',
#  'fabric/NN',
#  'give/VB',
#  'little/JJ',
#  'token/JJ',
#  'instability/NN',
#  'perhaps/RB',
#  'eye/NN',
#  'scrutinize/VB',
#  'observer/NN',
#  'have/VB',
#  'discover/VB',
#  'barely/RB',
#  'perceptible/JJ',
#  'fissure/NN',
#  'extend/VB',
#  'roof/NN',
#  'building/NN',
#  'front/JJ',
#  'make/VB',
#  'way/NN',
#  'wall/NN',
#  'zigzag/NN',
#  'direction/NN',
#  'become/VB',
#  'lose/VB',
#  'sullen/JJ',
#  'water/NN',
#  'tarn/NN',
#  'notice/VB',
#  'thing/NN',
#  'ride/VB',
#  'short/JJ',
#  'causeway/NN',
#  'house/NN',
#  'servant/NN',
#  'wait/VB',
#  'take/VB',
#  'horse/NN',
#  'enter/VB',
#  'gothic/JJ',
#  'archway/NN',
#  'hall/NN',
#  'valet/NN',
#  'stealthy/JJ',
#  'step/NN',
#  'thence/RB',
#  'conduct/VB',
#  'silence/NN',
#  'many/JJ',
#  'dark/NN',
#  'intricate/JJ',
#  'passage/NN',
#  'progress/NN',
#  'studio/NN',
#  'master/NN',
#  'much/JJ',
#  'encounter/VB',
#  'way/NN',
#  'contribute/VB',
#  'know/VB',
#  'not/RB',
#  'heighten/VB',
#  'vague/JJ',
#  'sentiment/NN',
#  'have/VB',
#  'already/RB',
#  'speak/VB',
#  'object/NN',
#  'carving/NN',
#  'ceiling/NN',
#  'sombre/JJ',
#  'tapestry/NN',
#  'wall/NN',
#  'ebon/NN',
#  'blackness/NN',
#  'floor/NN',
#  'phantasmagoric/NN',
#  'armorial/JJ',
#  'trophy/NN',
#  'rattle/VB',
#  'stride/VB',
#  'be/VB',
#  'matter/NN',
#  'such/JJ',
#  'have/VB',
#  'be/VB',
#  'accustom/VB',
#  'infancy/NN',
#  'hesitate/VB',
#  'not/RB',
#  'acknowledge/VB',
#  'familiar/JJ',
#  'be/VB',
#  'still/RB',
#  'wonder/VB',
#  'find/VB',
#  'unfamiliar/JJ',
#  'be/VB',
#  'fancy/VB',
#  'ordinary/JJ',
#  'image/NN',
#  'be/VB',
#  'stir/VB',
#  'staircase/NN',
#  'meet/VB',
#  'physician/NN',
#  'family/NN',
#  'countenance/NN',
#  'thought/NN',
#  'wear/VB',
#  'mingle/VB',
#  'expression/NN',
#  'low/JJ',
#  'cunning/JJ',
#  'perplexity/NN',
#  'accost/VB',
#  'trepidation/NN',
#  'pass/VB',
#  'valet/NN',
#  'now/RB',
#  'throw/VB',
#  'open/JJ',
#  'door/NN',
#  'usher/VB',
#  'presence/NN',
#  'master/NN',
#  'room/NN',
#  'find/VB',
#  'be/VB',
#  'very/RB',
#  'large/JJ',
#  'lofty/JJ',
#  'window/NN',
#  'be/VB',
#  'long/RB',
#  'narrow/JJ',
#  'pointed/JJ',
#  'so/RB',
#  'vast/JJ',
#  'distance/NN',
#  'black/JJ',
#  'oaken/JJ',
#  'floor/NN',
#  'be/VB',
#  'altogether/RB',
#  'inaccessible/JJ',
#  'feeble/JJ',
#  'gleam/NN',
#  'encrimsoned/JJ',
#  'light/NN',
#  'make/VB',
#  'way/NN',
#  'trellised/JJ',
#  'pane/NN',
#  'serve/VB',
#  'render/VB',
#  'sufficiently/RB',
#  'distinct/JJ',
#  'more/RB',
#  'prominent/JJ',
#  'object/NN',
#  'eye/NN',
#  'however/RB',
#  'struggle/VB',
#  'vain/JJ',
#  'reach/VB',
#  'remoter/JJ',
#  'angle/NN',
#  'chamber/NN',
#  'recess/NN',
#  'vault/VB',
#  'fret/VB',
#  'ceiling/NN',
#  'dark/JJ',
#  'drapery/NN',
#  'hang/VB',
#  'wall/NN',
#  'general/JJ',
#  'furniture/NN',
#  'be/VB',
#  'profuse/JJ',
#  'comfortless/JJ',
#  'antique/NN',
#  'tattered/JJ',
#  'many/JJ',
#  'book/NN',
#  'musical/JJ',
#  'instrument/NN',
#  'lay/VB',
#  'scatter/VB',
#  'fail/VB',
#  'give/VB',
#  'vitality/NN',
#  'scene/NN',
#  'feel/VB',
#  'breathe/VB',
#  'atmosphere/NN',
#  'sorrow/NN',
#  'air/NN',
#  'stern/JJ',
#  'deep/JJ',
#  'irredeemable/JJ',
#  'gloom/NN',
#  'hung/NN',
#  'over/RB',
#  'pervade/VB',
#  'entrance/NN',
#  'usher/NN',
#  'rise/VB',
#  'sofa/NN',
#  'have/VB',
#  'be/VB',
#  'lie/VB',
#  'full/JJ',
#  'length/NN',
#  'greet/VB',
#  'vivacious/JJ',
#  'warmth/NN',
#  'have/VB',
#  'much/JJ',
#  'first/JJ',
#  'thought/NN',
#  'overdo/VB',
#  'cordiality/NN',
#  'constrain/VB',
#  'effort/NN',
#  'ennuye/JJ',
#  'man/NN',
#  'world/NN',
#  'glance/NN',
#  'however/RB',
#  'countenance/NN',
#  'convince/VB',
#  'perfect/JJ',
#  'sincerity/NN',
#  'sit/VB',
#  'down/RB',
#  'moment/NN',
#  'speak/VB',
#  'not/RB',
#  'gaze/VB',
#  'feeling/JJ',
#  'half/NN',
#  'pity/NN',
#  'half/NN',
#  'awe/NN',
#  'surely/RB',
#  'man/NN',
#  'have/VB',
#  'never/RB',
#  'before/RB',
#  'so/RB',
#  'terribly/RB',
#  'alter/VB',
#  'so/RB',
#  'brief/JJ',
#  'period/NN',
#  'have/VB',
#  'roderick/JJ',
#  'usher/NN',
#  'be/VB',
#  'difficulty/NN',
#  'bring/VB',
#  'admit/VB',
#  'identity/NN',
#  'wan/JJ',
#  'be/VB',
#  'companion/NN',
#  'early/JJ',
#  'boyhood/NN',
#  'yet/RB',
#  'character/NN',
#  'face/NN',
#  'have/VB',
#  'be/VB',
#  'time/NN',
#  'remarkable/JJ',
#  'cadaverousness/NN',
#  'complexion/NN',
#  'eye/NN',
#  'large/JJ',
#  'liquid/NN',
#  'luminous/JJ',
#  'comparison/NN',
#  'lip/NN',
#  'somewhat/RB',
#  'thin/JJ',
#  'very/RB',
#  'pallid/JJ',
#  'surpassingly/RB',
#  'beautiful/JJ',
#  'curve/NN',
#  'nose/NN',
#  'delicate/JJ',
#  'hebrew/NN',
#  'model/NN',
#  'breadth/NN',
#  'nostril/NN',
#  'unusual/JJ',
#  'similar/JJ',
#  'formation/NN',
#  'finely/RB',
#  'moulded/JJ',
#  'chin/NN',
#  'speaking/NN',
#  'want/NN',
#  'prominence/NN',
#  'want/NN',
#  'moral/JJ',
#  'energy/NN',
#  'hair/NN',
#  'more/JJ',
#  'web/NN',
#  'softness/NN',
#  'tenuity/NN',
#  'feature/NN',
#  'inordinate/JJ',
#  'expansion/NN',
#  'region/NN',
#  'temple/NN',
#  'make/VB',
#  'altogether/RB',
#  'countenance/NN',
#  'not/RB',
#  'easily/RB',
#  'be/VB',
#  'forget/VB',
#  'now/RB',
#  'mere/JJ',
#  'exaggeration/NN',
#  'prevailing/JJ',
#  'character/NN',
#  'feature/NN',
#  'expression/NN',
#  'be/VB',
#  'wont/JJ',
#  'convey/VB',
#  'lay/VB',
#  'so/RB',
#  'much/JJ',
#  'change/NN',
#  'doubt/VB',
#  'speak/VB',
#  'now/RB',
#  'ghastly/JJ',
#  'pallor/NN',
#  'skin/NN',
#  'now/RB',
#  'miraculous/JJ',
#  'lustre/NN',
#  'eye/NN',
#  'thing/NN',
#  'startle/VB',
#  'even/RB',
#  'awe/VB',
#  'silken/JJ',
#  'hair/NN',
#  'too/RB',
#  'have/VB',
#  'be/VB',
#  'suffer/VB',
#  'grow/VB',
#  'unheeded/JJ',
#  'wild/JJ',
#  'gossamer/NN',
#  'texture/NN',
#  'float/VB',
#  'rather/RB',
#  'fall/VB',
#  'face/NN',
#  'not/RB',
#  'even/RB',
#  'effort/NN',
#  ...]

# %%
#still doesn't run, even on ec2
#gave ~15mins

# %%
output_v3 = eda(transform_txt_file_v3)

# %%
def transform_txt_file_v3_alt(fname, root=source_dir, stop_words=stop, \
                         lemma = True):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Trying to lemmatize each book at once, rather than line-by-line - to attempt
        to fix apparent processing hang-up in v3
    '''
    fp = root + fname
    book_as_lst = []
    
    if lemma == True:
        for line in IterFile(fp):
            
            if empty_line_check(line) == False:
                book_as_lst.extend([word for word in line.split()])
                
        book_as_lst = lemmatize(" ".join(book_as_lst))
            
    else:
        for line in IterFile(fp):
            if empty_line_check(line) == False:
                line = basic_tokenize(line)
                
            if stop_words !=None:
                line = remove_stop_words(line, stop_words)
        
            book_as_lst.extend(line)
    
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty

def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
           
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
# note: need another layer of punct stripping, for sententce ending in 
#quotations.  ("I did not." => I, did, not.)

# %%
usher_v3_alt = transform_txt_file_v3_alt(usher)
usher_v3_alt
# Out:
# ['fall/NN',
#  'house/NN',
#  'usher/NN',
#  'son/NN',
#  'coeur/NN',
#  'luth/NN',
#  'suspendu/NN',
#  'sitot/NN',
#  'qu/NN',
#  'le/NN',
#  'touche/NN',
#  'il/NN',
#  'beranger/JJ',
#  'whole/NN',
#  'dull/JJ',
#  'dark/NN',
#  'soundless/NN',
#  'day/NN',
#  'autumn/NN',
#  'year/NN',
#  'cloud/NN',
#  'hung/JJ',
#  'oppressively/RB',
#  'low/JJ',
#  'heaven/NN',
#  'have/VB',
#  'be/VB',
#  'pass/VB',
#  'alone/RB',
#  'horseback/NN',
#  'singularly/RB',
#  'dreary/JJ',
#  'tract/NN',
#  'country/NN',
#  'length/NN',
#  'find/VB',
#  'shade/NN',
#  'evening/NN',
#  'draw/VB',
#  'view/NN',
#  'melancholy/NN',
#  'house/NN',
#  'usher/NN',
#  'know/VB',
#  'not/RB',
#  'be/VB',
#  'first/JJ',
#  'glimpse/NN',
#  'build/VB',
#  'sense/NN',
#  'insufferable/JJ',
#  'gloom/NN',
#  'pervade/VB',
#  'spirit/NN',
#  'say/VB',
#  'insufferable/JJ',
#  'feeling/NN',
#  'be/VB',
#  'unrelieved/JJ',
#  'half/NN',
#  'pleasureable/NN',
#  'poetic/JJ',
#  'sentiment/NN',
#  'mind/NN',
#  'usually/RB',
#  'receive/VB',
#  'even/RB',
#  'sternest/JJ',
#  'natural/JJ',
#  'image/NN',
#  'desolate/JJ',
#  'terrible/JJ',
#  'look/VB',
#  'scene/NN',
#  'mere/JJ',
#  'house/NN',
#  'simple/JJ',
#  'landscape/NN',
#  'feature/NN',
#  'domain/NN',
#  'bleak/JJ',
#  'wall/NN',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'few/JJ',
#  'rank/NN',
#  'sedge/NN',
#  'few/JJ',
#  'white/JJ',
#  'trunk/NN',
#  'decayed/JJ',
#  'tree/NN',
#  'utter/JJ',
#  'depression/NN',
#  'soul/NN',
#  'compare/VB',
#  'earthly/JJ',
#  'sensation/NN',
#  'more/RB',
#  'properly/RB',
#  'dream/NN',
#  'reveller/JJ',
#  'opium/NN',
#  'bitter/JJ',
#  'lapse/NN',
#  'everyday/JJ',
#  'life/NN',
#  'hideous/JJ',
#  'drop/VB',
#  'veil/NN',
#  'be/VB',
#  'iciness/NN',
#  'sink/VB',
#  'sickening/JJ',
#  'heart/NN',
#  'unredeemed/JJ',
#  'dreariness/NN',
#  'thought/NN',
#  'goading/NN',
#  'imagination/NN',
#  'torture/VB',
#  'aught/NN',
#  'sublime/JJ',
#  'be/VB',
#  'pause/VB',
#  'think/VB',
#  'be/VB',
#  'so/RB',
#  'unnerved/JJ',
#  'contemplation/NN',
#  'house/NN',
#  'usher/NN',
#  'be/VB',
#  'mystery/NN',
#  'insoluble/JJ',
#  'grapple/VB',
#  'shadowy/JJ',
#  'fancy/VB',
#  'crowd/VB',
#  'ponder/VB',
#  'be/VB',
#  'force/VB',
#  'fall/VB',
#  'back/RB',
#  'unsatisfactory/JJ',
#  'conclusion/NN',
#  'doubt/NN',
#  'be/VB',
#  'combination/NN',
#  'very/RB',
#  'simple/JJ',
#  'natural/JJ',
#  'object/NN',
#  'have/VB',
#  'power/NN',
#  'thus/RB',
#  'affect/VB',
#  'still/RB',
#  'analysis/NN',
#  'power/NN',
#  'lie/VB',
#  'consideration/NN',
#  'depth/NN',
#  'be/VB',
#  'possible/JJ',
#  'reflect/VB',
#  'mere/JJ',
#  'different/JJ',
#  'arrangement/NN',
#  'particular/NN',
#  'scene/NN',
#  'detail/NN',
#  'picture/NN',
#  'be/VB',
#  'sufficient/JJ',
#  'modify/VB',
#  'perhaps/RB',
#  'annihilate/VB',
#  'capacity/NN',
#  'sorrowful/JJ',
#  'impression/NN',
#  'act/VB',
#  'idea/NN',
#  'rein/VB',
#  'horse/NN',
#  'precipitous/JJ',
#  'brink/NN',
#  'black/JJ',
#  'lurid/JJ',
#  'tarn/NN',
#  'lay/VB',
#  'unruffled/JJ',
#  'lustre/NN',
#  'dwelling/NN',
#  'gaze/VB',
#  'down/RB',
#  'shudder/VB',
#  'even/RB',
#  'more/RB',
#  'thrilling/JJ',
#  'before/RB',
#  'remodelled/JJ',
#  'inverted/JJ',
#  'image/NN',
#  'grey/JJ',
#  'sedge/NN',
#  'ghastly/JJ',
#  'tree/NN',
#  'stem/VB',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'nevertheless/RB',
#  'mansion/NN',
#  'gloom/NN',
#  'now/RB',
#  'propose/VB',
#  'sojourn/NN',
#  'week/NN',
#  'proprietor/NN',
#  'roderick/NN',
#  'usher/NN',
#  'have/VB',
#  'be/VB',
#  'boon/NN',
#  'companion/NN',
#  'boyhood/NN',
#  'many/JJ',
#  'year/NN',
#  'have/VB',
#  'elapse/VB',
#  'last/JJ',
#  'meeting/NN',
#  'letter/NN',
#  'however/RB',
#  'have/VB',
#  'lately/RB',
#  'reach/VB',
#  'distant/JJ',
#  'part/NN',
#  'country/NN',
#  'letter/NN',
#  'wildly/RB',
#  'importunate/JJ',
#  'nature/NN',
#  'have/VB',
#  'admit/VB',
#  'other/JJ',
#  'personal/JJ',
#  'reply/NN',
#  'ms/NN',
#  'give/VB',
#  'evidence/NN',
#  'nervous/JJ',
#  'agitation/NN',
#  'writer/NN',
#  'speak/VB',
#  'acute/JJ',
#  'bodily/JJ',
#  'illness/NN',
#  'mental/JJ',
#  'disorder/NN',
#  'oppressed/JJ',
#  'earnest/JJ',
#  'desire/NN',
#  'see/VB',
#  'best/NN',
#  'indeed/RB',
#  'only/JJ',
#  'personal/JJ',
#  'friend/NN',
#  'view/NN',
#  'attempt/VB',
#  'cheerfulness/NN',
#  'society/NN',
#  'alleviation/NN',
#  'malady/NN',
#  'be/VB',
#  'manner/NN',
#  'much/RB',
#  'more/RB',
#  'be/VB',
#  'say/VB',
#  'be/VB',
#  'apparent/JJ',
#  'heart/NN',
#  'go/VB',
#  'request/NN',
#  'allow/VB',
#  'room/NN',
#  'hesitation/NN',
#  'accordingly/RB',
#  'obey/VB',
#  'forthwith/RB',
#  'still/RB',
#  'consider/VB',
#  'very/RB',
#  'singular/JJ',
#  'summons/NN',
#  'boy/NN',
#  'have/VB',
#  'be/VB',
#  'even/RB',
#  'intimate/JJ',
#  'associate/NN',
#  'yet/RB',
#  'really/RB',
#  'know/VB',
#  'little/JJ',
#  'friend/NN',
#  'reserve/NN',
#  'have/VB',
#  'be/VB',
#  'always/RB',
#  'excessive/JJ',
#  'habitual/JJ',
#  'be/VB',
#  'aware/JJ',
#  'however/RB',
#  'very/RB',
#  'ancient/JJ',
#  'family/NN',
#  'have/VB',
#  'be/VB',
#  'note/VB',
#  'time/NN',
#  'mind/NN',
#  'peculiar/JJ',
#  'sensibility/NN',
#  'temperament/NN',
#  'display/VB',
#  'long/JJ',
#  'age/NN',
#  'many/JJ',
#  'work/NN',
#  'exalted/JJ',
#  'art/NN',
#  'manifest/VB',
#  'late/JJ',
#  'repeated/JJ',
#  'deed/NN',
#  'munificent/NN',
#  'yet/RB',
#  'unobtrusive/JJ',
#  'charity/NN',
#  'as/RB',
#  'well/RB',
#  'passionate/JJ',
#  'devotion/NN',
#  'intricacy/NN',
#  'perhaps/RB',
#  'even/RB',
#  'more/RB',
#  'orthodox/JJ',
#  'easily/RB',
#  'recognisable/JJ',
#  'beauty/NN',
#  'musical/JJ',
#  'science/NN',
#  'have/VB',
#  'learn/VB',
#  'too/RB',
#  'very/RB',
#  'remarkable/JJ',
#  'fact/NN',
#  'stem/NN',
#  'usher/NN',
#  'race/NN',
#  'time/NN',
#  'honour/VB',
#  'be/VB',
#  'have/VB',
#  'put/VB',
#  'forth/RB',
#  'period/NN',
#  'enduring/JJ',
#  'branch/NN',
#  'other/JJ',
#  'word/NN',
#  'entire/JJ',
#  'family/NN',
#  'lay/VB',
#  'direct/JJ',
#  'line/NN',
#  'descent/NN',
#  'have/VB',
#  'always/RB',
#  'very/RB',
#  'trifling/JJ',
#  'very/RB',
#  'temporary/JJ',
#  'variation/NN',
#  'so/RB',
#  'lain/VB',
#  'be/VB',
#  'deficiency/NN',
#  'consider/VB',
#  'run/VB',
#  'think/VB',
#  'perfect/JJ',
#  'keep/VB',
#  'character/NN',
#  'premise/NN',
#  'accredit/VB',
#  'character/NN',
#  'person/NN',
#  'speculate/VB',
#  'possible/JJ',
#  'influence/NN',
#  'long/JJ',
#  'lapse/NN',
#  'century/NN',
#  'have/VB',
#  'exercise/VB',
#  'other/JJ',
#  'be/VB',
#  'deficiency/NN',
#  'perhaps/RB',
#  'collateral/NN',
#  'issue/NN',
#  'consequent/JJ',
#  'undeviat/VB',
#  'transmission/NN',
#  'sire/NN',
#  'son/NN',
#  'patrimony/NN',
#  'name/NN',
#  'have/VB',
#  'length/NN',
#  'so/VB',
#  'identify/VB',
#  'merge/VB',
#  'original/JJ',
#  'title/NN',
#  'estate/NN',
#  'quaint/JJ',
#  'equivocal/JJ',
#  'appellation/NN',
#  'house/NN',
#  'usher/NN',
#  'appellation/NN',
#  'seem/VB',
#  'include/VB',
#  'mind/NN',
#  'peasantry/NN',
#  'used/VB',
#  'family/NN',
#  'family/NN',
#  'mansion/NN',
#  'have/VB',
#  'say/VB',
#  'sole/JJ',
#  'effect/NN',
#  'somewhat/RB',
#  'childish/JJ',
#  'experiment/NN',
#  'look/VB',
#  'tarn/NN',
#  'have/VB',
#  'be/VB',
#  'deepen/VB',
#  'first/JJ',
#  'singular/JJ',
#  'impression/NN',
#  'be/VB',
#  'doubt/NN',
#  'consciousness/NN',
#  'rapid/JJ',
#  'increase/NN',
#  'superstition/NN',
#  'not/RB',
#  'term/NN',
#  'serve/VB',
#  'mainly/RB',
#  'accelerate/VB',
#  'increase/NN',
#  'such/JJ',
#  'have/VB',
#  'long/RB',
#  'know/VB',
#  'be/VB',
#  'paradoxical/JJ',
#  'law/NN',
#  'sentiment/NN',
#  'have/VB',
#  'terror/NN',
#  'basis/NN',
#  'have/VB',
#  'be/VB',
#  'reason/NN',
#  'only/RB',
#  'again/RB',
#  'uplift/VB',
#  'eye/NN',
#  'house/NN',
#  'image/NN',
#  'pool/NN',
#  'grow/VB',
#  'mind/NN',
#  'strange/JJ',
#  'fancy/NN',
#  'fancy/NN',
#  'so/RB',
#  'ridiculous/JJ',
#  'indeed/RB',
#  'mention/VB',
#  'show/VB',
#  'vivid/JJ',
#  'force/NN',
#  'sensation/NN',
#  'oppressed/JJ',
#  'have/VB',
#  'so/RB',
#  'work/VB',
#  'imagination/NN',
#  'really/RB',
#  'believe/VB',
#  'whole/JJ',
#  'mansion/NN',
#  'domain/NN',
#  'there/RB',
#  'hang/VB',
#  'atmosphere/NN',
#  'peculiar/JJ',
#  'immediate/JJ',
#  'vicinity/NN',
#  'atmosphere/NN',
#  'have/VB',
#  'affinity/NN',
#  'air/NN',
#  'heaven/NN',
#  'have/VB',
#  'reek/VB',
#  'decayed/JJ',
#  'tree/NN',
#  'grey/JJ',
#  'wall/NN',
#  'silent/JJ',
#  'tarn/NN',
#  'pestilent/JJ',
#  'mystic/JJ',
#  'vapour/NN',
#  'dull/JJ',
#  'sluggish/JJ',
#  'faintly/RB',
#  'discernible/JJ',
#  'leaden/JJ',
#  'hued/NN',
#  'shake/VB',
#  'spirit/NN',
#  'have/VB',
#  'be/VB',
#  'dream/NN',
#  'scan/VB',
#  'more/RB',
#  'narrowly/RB',
#  'real/JJ',
#  'aspect/NN',
#  'build/VB',
#  'principal/JJ',
#  'feature/NN',
#  'seem/VB',
#  'be/VB',
#  'excessive/JJ',
#  'antiquity/NN',
#  'discoloration/NN',
#  'age/NN',
#  'have/VB',
#  'be/VB',
#  'great/JJ',
#  'minute/NN',
#  'fungi/NN',
#  'overspread/VB',
#  'whole/JJ',
#  'exterior/JJ',
#  'hanging/NN',
#  'fine/NN',
#  'tangled/JJ',
#  'web/NN',
#  'work/NN',
#  'eave/NN',
#  'yet/RB',
#  'be/VB',
#  'apart/RB',
#  'extraordinary/JJ',
#  'dilapidation/NN',
#  'portion/NN',
#  'masonry/NN',
#  'have/VB',
#  'fall/VB',
#  'appear/VB',
#  'be/VB',
#  'wild/JJ',
#  'inconsistency/NN',
#  'still/RB',
#  'perfect/JJ',
#  'adaptation/NN',
#  'part/NN',
#  'crumble/VB',
#  'condition/NN',
#  'individual/JJ',
#  'stone/NN',
#  'be/VB',
#  'much/JJ',
#  'remind/VB',
#  'specious/JJ',
#  'totality/NN',
#  'old/JJ',
#  'wood/NN',
#  'work/NN',
#  'have/VB',
#  'rot/VB',
#  'long/JJ',
#  'year/NN',
#  'neglected/JJ',
#  'vault/NN',
#  'disturbance/NN',
#  'breath/NN',
#  'external/JJ',
#  'air/NN',
#  'indication/NN',
#  'extensive/JJ',
#  'decay/NN',
#  'however/RB',
#  'fabric/NN',
#  'give/VB',
#  'little/JJ',
#  'token/JJ',
#  'instability/NN',
#  'perhaps/RB',
#  'eye/NN',
#  'scrutinize/VB',
#  'observer/NN',
#  'have/VB',
#  'discover/VB',
#  'barely/RB',
#  'perceptible/JJ',
#  'fissure/NN',
#  'extend/VB',
#  'roof/NN',
#  'building/NN',
#  'front/JJ',
#  'make/VB',
#  'way/NN',
#  'wall/NN',
#  'zigzag/NN',
#  'direction/NN',
#  'become/VB',
#  'lose/VB',
#  'sullen/JJ',
#  'water/NN',
#  'tarn/NN',
#  'notice/VB',
#  'thing/NN',
#  'ride/VB',
#  'short/JJ',
#  'causeway/NN',
#  'house/NN',
#  'servant/NN',
#  'wait/VB',
#  'take/VB',
#  'horse/NN',
#  'enter/VB',
#  'gothic/JJ',
#  'archway/NN',
#  'hall/NN',
#  'valet/NN',
#  'stealthy/JJ',
#  'step/NN',
#  'thence/RB',
#  'conduct/VB',
#  'silence/NN',
#  'many/JJ',
#  'dark/NN',
#  'intricate/JJ',
#  'passage/NN',
#  'progress/NN',
#  'studio/NN',
#  'master/NN',
#  'much/JJ',
#  'encounter/VB',
#  'way/NN',
#  'contribute/VB',
#  'know/VB',
#  'not/RB',
#  'heighten/VB',
#  'vague/JJ',
#  'sentiment/NN',
#  'have/VB',
#  'already/RB',
#  'speak/VB',
#  'object/NN',
#  'carving/NN',
#  'ceiling/NN',
#  'sombre/JJ',
#  'tapestry/NN',
#  'wall/NN',
#  'ebon/NN',
#  'blackness/NN',
#  'floor/NN',
#  'phantasmagoric/NN',
#  'armorial/JJ',
#  'trophy/NN',
#  'rattle/VB',
#  'stride/VB',
#  'be/VB',
#  'matter/NN',
#  'such/JJ',
#  'have/VB',
#  'be/VB',
#  'accustom/VB',
#  'infancy/NN',
#  'hesitate/VB',
#  'not/RB',
#  'acknowledge/VB',
#  'familiar/JJ',
#  'be/VB',
#  'still/RB',
#  'wonder/VB',
#  'find/VB',
#  'unfamiliar/JJ',
#  'be/VB',
#  'fancy/VB',
#  'ordinary/JJ',
#  'image/NN',
#  'be/VB',
#  'stir/VB',
#  'staircase/NN',
#  'meet/VB',
#  'physician/NN',
#  'family/NN',
#  'countenance/NN',
#  'thought/NN',
#  'wear/VB',
#  'mingle/VB',
#  'expression/NN',
#  'low/JJ',
#  'cunning/JJ',
#  'perplexity/NN',
#  'accost/VB',
#  'trepidation/NN',
#  'pass/VB',
#  'valet/NN',
#  'now/RB',
#  'throw/VB',
#  'open/JJ',
#  'door/NN',
#  'usher/VB',
#  'presence/NN',
#  'master/NN',
#  'room/NN',
#  'find/VB',
#  'be/VB',
#  'very/RB',
#  'large/JJ',
#  'lofty/JJ',
#  'window/NN',
#  'be/VB',
#  'long/RB',
#  'narrow/JJ',
#  'pointed/JJ',
#  'so/RB',
#  'vast/JJ',
#  'distance/NN',
#  'black/JJ',
#  'oaken/JJ',
#  'floor/NN',
#  'be/VB',
#  'altogether/RB',
#  'inaccessible/JJ',
#  'feeble/JJ',
#  'gleam/NN',
#  'encrimsoned/JJ',
#  'light/NN',
#  'make/VB',
#  'way/NN',
#  'trellised/JJ',
#  'pane/NN',
#  'serve/VB',
#  'render/VB',
#  'sufficiently/RB',
#  'distinct/JJ',
#  'more/RB',
#  'prominent/JJ',
#  'object/NN',
#  'eye/NN',
#  'however/RB',
#  'struggle/VB',
#  'vain/JJ',
#  'reach/VB',
#  'remoter/JJ',
#  'angle/NN',
#  'chamber/NN',
#  'recess/NN',
#  'vault/VB',
#  'fret/VB',
#  'ceiling/NN',
#  'dark/JJ',
#  'drapery/NN',
#  'hang/VB',
#  'wall/NN',
#  'general/JJ',
#  'furniture/NN',
#  'be/VB',
#  'profuse/JJ',
#  'comfortless/NN',
#  'antique/NN',
#  'tattered/JJ',
#  'many/JJ',
#  'book/NN',
#  'musical/JJ',
#  'instrument/NN',
#  'lay/VB',
#  'scatter/VB',
#  'fail/VB',
#  'give/VB',
#  'vitality/NN',
#  'scene/NN',
#  'feel/VB',
#  'breathe/VB',
#  'atmosphere/NN',
#  'sorrow/NN',
#  'air/NN',
#  'stern/JJ',
#  'deep/JJ',
#  'irredeemable/JJ',
#  'gloom/NN',
#  'hung/NN',
#  'over/RB',
#  'pervade/VB',
#  'entrance/NN',
#  'usher/NN',
#  'rise/VB',
#  'sofa/NN',
#  'have/VB',
#  'be/VB',
#  'lie/VB',
#  'full/JJ',
#  'length/NN',
#  'greet/VB',
#  'vivacious/JJ',
#  'warmth/NN',
#  'have/VB',
#  'much/JJ',
#  'first/JJ',
#  'thought/NN',
#  'overdo/VB',
#  'cordiality/NN',
#  'constrain/VB',
#  'effort/NN',
#  'ennuye/JJ',
#  'man/NN',
#  'world/NN',
#  'glance/NN',
#  'however/RB',
#  'countenance/NN',
#  'convince/VB',
#  'perfect/JJ',
#  'sincerity/NN',
#  'sit/VB',
#  'down/RB',
#  'moment/NN',
#  'speak/VB',
#  'not/RB',
#  'gaze/VB',
#  'feeling/JJ',
#  'half/NN',
#  'pity/NN',
#  'half/NN',
#  'awe/NN',
#  'surely/RB',
#  'man/NN',
#  'have/VB',
#  'never/RB',
#  'before/RB',
#  'so/RB',
#  'terribly/RB',
#  'alter/VB',
#  'so/RB',
#  'brief/JJ',
#  'period/NN',
#  'have/VB',
#  'roderick/JJ',
#  'usher/NN',
#  'be/VB',
#  'difficulty/NN',
#  'bring/VB',
#  'admit/VB',
#  'identity/NN',
#  'wan/JJ',
#  'be/VB',
#  'companion/NN',
#  'early/JJ',
#  'boyhood/NN',
#  'yet/RB',
#  'character/NN',
#  'face/NN',
#  'have/VB',
#  'be/VB',
#  'time/NN',
#  'remarkable/JJ',
#  'cadaverousness/NN',
#  'complexion/NN',
#  'eye/NN',
#  'large/JJ',
#  'liquid/NN',
#  'luminous/JJ',
#  'comparison/NN',
#  'lip/NN',
#  'somewhat/RB',
#  'thin/JJ',
#  'very/RB',
#  'pallid/JJ',
#  'surpassingly/RB',
#  'beautiful/JJ',
#  'curve/NN',
#  'nose/NN',
#  'delicate/JJ',
#  'hebrew/NN',
#  'model/NN',
#  'breadth/NN',
#  'nostril/NN',
#  'unusual/JJ',
#  'similar/JJ',
#  'formation/NN',
#  'finely/RB',
#  'moulded/JJ',
#  'chin/NN',
#  'speaking/NN',
#  'want/NN',
#  'prominence/NN',
#  'want/NN',
#  'moral/JJ',
#  'energy/NN',
#  'hair/NN',
#  'more/JJ',
#  'web/NN',
#  'softness/NN',
#  'tenuity/NN',
#  'feature/NN',
#  'inordinate/JJ',
#  'expansion/NN',
#  'region/NN',
#  'temple/NN',
#  'make/VB',
#  'altogether/RB',
#  'countenance/NN',
#  'not/RB',
#  'easily/RB',
#  'be/VB',
#  'forget/VB',
#  'now/RB',
#  'mere/JJ',
#  'exaggeration/NN',
#  'prevailing/JJ',
#  'character/NN',
#  'feature/NN',
#  'expression/NN',
#  'be/VB',
#  'wont/JJ',
#  'convey/VB',
#  'lay/VB',
#  'so/RB',
#  'much/JJ',
#  'change/NN',
#  'doubt/VB',
#  'speak/VB',
#  'now/RB',
#  'ghastly/JJ',
#  'pallor/NN',
#  'skin/NN',
#  'now/RB',
#  'miraculous/JJ',
#  'lustre/NN',
#  'eye/NN',
#  'thing/NN',
#  'startle/VB',
#  'even/RB',
#  'awe/VB',
#  'silken/JJ',
#  'hair/NN',
#  'too/RB',
#  'have/VB',
#  'be/VB',
#  'suffer/VB',
#  'grow/VB',
#  'unheeded/JJ',
#  'wild/JJ',
#  'gossamer/NN',
#  'texture/NN',
#  'float/VB',
#  'rather/RB',
#  'fall/VB',
#  'face/NN',
#  'not/RB',
#  'even/RB',
#  'effort/NN',
#  'connect/VB',
#  'arabesque/NN',
#  ...]

# %%
#Can't get either version of the eda process w lemmatization transformation to run
#Next step - try to run each piece individually and see where the issue is?
#Also, may not lemmatize?
#Use another package's lemmatizer/stemmer?

# %%
output_v3_alt = eda(transform_txt_file_v3_alt)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-86-2e6a474552ca> in <module>()
# ----> 1 output_v3_alt = eda(transform_txt_file_v3_alt)
#
# <ipython-input-43-938afba4df7f> in eda(transform_txt_file, fileid_lst)
#       4     '''
#       5
# ----> 6     all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
#       7
#       8     book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
#
# <ipython-input-82-5f3449c8278b> in transform_txt_file_v3_alt(fname, root, stop_words, lemma)
#      16                 book_as_lst.extend([word for word in line.split()])
#      17
# ---> 18         book_as_lst = lemmatize(" ".join(book_as_lst))
#      19
#      20     else:
#
# /home/ubuntu/anaconda3/envs/python2/lib/python2.7/site-packages/gensim/utils.pyc in lemmatize(content, allowed_tags, light, stopwords, min_length, max_length)
#    1079     content = u(' ').join(tokenize(content, lower=True, errors='ignore'))
#    1080
# -> 1081     parsed = parse(content, lemmata=True, collapse=False)
#    1082     result = []
#    1083     for sentence in parsed:
#
# /home/ubuntu/anaconda3/envs/python2/lib/python2.7/site-packages/pattern/text/en/__init__.pyc in parse(s, *args, **kwargs)
#     154     """ Returns a tagged Unicode string.
#     155     """
# --> 156     return parser.parse(s, *args, **kwargs)
#     157
#     158 def parsetree(s, *args, **kwargs):
#
# /home/ubuntu/anaconda3/envs/python2/lib/python2.7/site-packages/pattern/text/__init__.pyc in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#     745             # Chunker.
#     746             if chunks or relations:
# --> 747                 s[i] = self.find_chunks(s[i], **kwargs)
#     748             # Labeler.
#     749             if relations:
#
# /home/ubuntu/anaconda3/envs/python2/lib/python2.7/site-packages/pattern/text/__init__.pyc in find_chunks(self, tokens, **kwargs)
#     698         return find_prepositions(
#     699                find_chunks(tokens,
# --> 700                    language = kwargs.get("language", self.language)))
#     701
#     702     def find_prepositions(self, tokens, **kwargs):
#
# /home/ubuntu/anaconda3/envs/python2/lib/python2.7/site-packages/pattern/text/__init__.pyc in find_chunks(tagged, language)
#    1130             # Number of preceding separators = number of preceding tokens.
#    1131             i = m.start()
# -> 1132             j = tags[:i].count(SEPARATOR)
#    1133             n = m.group(0).count(SEPARATOR)
#    1134             for k in range(j, j+n):
#
# KeyboardInterrupt:

# %%
#didn't run on ec2 after about 20mins
#look into batching (Lemmatizer I think)
#ask Joe

# %%
book_lengths3, avg_num_tokens3, dictionary3, dictionary_length3, \
    unique_toks_per_fileid3, avg_unique_toks3, corpus3 = output_v3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-1fe5cfb6565d> in <module>()
# ----> 1 book_lengths3, avg_num_tokens3, dictionary3, dictionary_length3,     unique_toks_per_fileid3, avg_unique_toks3, corpus3 = output_v3
#
# NameError: name 'output_v3' is not defined

# %%
print "Average number of tokens in a book: ", avg_num_tokens3
print "   "
print "Average unique tokens in a book: ", avg_unique_toks3
print "   "
print "Total number of words (dictionary length): ", dictionary_length3

# %%
book_lengths3

# %%
unique_toks_per_fileid3

# %%
save_stuff('lemmatized', dictionary3, corpus3)

# %% [markdown]
# ## EDA Step 4: + frequency filters

# %%
def eda_w_filter(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary.filter_extremes(no_below=1)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, model, outputs_dir=outputs_dir):
    '''
    Save the outputs of the most recent eda step
    '''
    if dictionary != None:
        dictionary.save(outputs_dir + distinguishing_str + '.dict')
        
    if corpus != None:
        corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)
    
    if model != None:
        pass

# %%
outputs4 = eda_w_filter(transform_txt_file_v2)

# %%
book_lengths4, avg_num_tokens4, dictionary4, dictionary_length4, \
    unique_toks_per_fileid4, avg_unique_toks4, corpus4 = outputs4

# %%
len(dictionary4)
# Out:
# 100000

# %%
print "Average number of tokens in a book: ", avg_num_tokens4, avg_num_tokens2
print "   "
print "Average unique tokens in a book: ", avg_unique_toks4, avg_unique_toks2
print "   "
print "Total number of words (dictionary length): ", dictionary_length4, dictionary_length2
# Out:
# Average number of tokens in a book:  66904 66904
#
# Average unique tokens in a book:  5461 8882
#
# Total number of words (dictionary length):  100000 194961

# %%
book_lengths4
# Out:
# [('10-clean.txt', 431250),
#  ('100-clean.txt', 481608),
#  ('105-clean.txt', 39320),
#  ('108-clean.txt', 54072),
#  ('1080-clean.txt', 1739),
#  ('11-clean.txt', 13616),
#  ('1112-clean.txt', 15468),
#  ('1184-clean.txt', 251348),
#  ('12-clean.txt', 15589),
#  ('120-clean.txt', 34581),
#  ('1232-clean.txt', 23021),
#  ('1260-clean.txt', 91946),
#  ('1322-clean.txt', 67400),
#  ('1342-clean.txt', 57307),
#  ('135-clean.txt', 288377),
#  ('1399-clean.txt', 173226),
#  ('140-clean.txt', 70693),
#  ('1400-clean.txt', 87450),
#  ('1404-clean.txt', 91284),
#  ('14264-clean.txt', 38978),
#  ('147-clean.txt', 10640),
#  ('1497-clean.txt', 98946),
#  ('15399-clean.txt', 38240),
#  ('158-clean.txt', 75454),
#  ('16-clean.txt', 23919),
#  ('160-clean.txt', 32962),
#  ('161-clean.txt', 56016),
#  ('16382-clean.txt', 71067),
#  ('1661-clean.txt', 49411),
#  ('1727-clean.txt', 59474),
#  ('174-clean.txt', 38744),
#  ('1952-yellow_wallpaper-clean.txt', 2978),
#  ('19942-clean.txt', 18535),
#  ('20-clean.txt', 47100),
#  ('20203-clean.txt', 37660),
#  ('203-clean.txt', 96324),
#  ('205-clean.txt', 54786),
#  ('21279-clean.txt', 1571),
#  ('2148-clean.txt', 46691),
#  ('2174-clean.txt', 23285),
#  ('219-clean.txt', 18469),
#  ('224-clean.txt', 66929),
#  ('23-clean.txt', 19473),
#  ('236-clean.txt', 26308),
#  ('2500-clean.txt', 19035),
#  ('25305-clean.txt', 38416),
#  ('2591-clean.txt', 45883),
#  ('2600-clean.txt', 296264),
#  ('2680-clean.txt', 34779),
#  ('2701-moby-clean.txt', 112067),
#  ('28054-clean.txt', 170412),
#  ('2814-clean.txt', 36937),
#  ('2852-clean.txt', 28211),
#  ('28520-clean.txt', 15768),
#  ('30360-clean.txt', 121187),
#  ('30601-clean.txt', 33035),
#  ('3207-clean.txt', 100707),
#  ('33-clean.txt', 42341),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 75049),
#  ('34901-clean.txt', 24055),
#  ('35-clean.txt', 15812),
#  ('36-clean.txt', 30839),
#  ('3600-clean.txt', 253407),
#  ('38427-clean.txt', 98400),
#  ('408-clean.txt', 36484),
#  ('41-clean.txt', 6235),
#  ('42-clean.txt', 12630),
#  ('4300-clean.txt', 155405),
#  ('4363-clean.txt', 31647),
#  ('45-clean.txt', 54620),
#  ('4517-clean.txt', 17305),
#  ('46-clean.txt', 14621),
#  ('514-clean.txt', 98108),
#  ('5200-clean.txt', 10380),
#  ('521-clean.txt', 51615),
#  ('526-clean.txt', 18687),
#  ('55-clean.txt', 19627),
#  ('55387-clean.txt', 10559),
#  ('55404-clean.txt', 49338),
#  ('6130-clean.txt', 112614),
#  ('730-clean.txt', 82789),
#  ('7370-clean.txt', 25684),
#  ('74-clean.txt', 38214),
#  ('76-clean.txt', 55732),
#  ('768-clean.txt', 57940),
#  ('829-clean.txt', 49050),
#  ('84-clean.txt', 35410),
#  ('844-clean.txt', 11846),
#  ('851-clean.txt', 9049),
#  ('863-clean.txt', 29746),
#  ('8800-clean.txt', 59373),
#  ('932-clean.txt', 3546),
#  ('98-clean.txt', 67493),
#  ('996-clean.txt', 194284)]

# %%
book_lengths2
# Out:
# [('10-clean.txt', 431250),
#  ('100-clean.txt', 481608),
#  ('105-clean.txt', 39320),
#  ('108-clean.txt', 54072),
#  ('1080-clean.txt', 1739),
#  ('11-clean.txt', 13616),
#  ('1112-clean.txt', 15468),
#  ('1184-clean.txt', 251348),
#  ('12-clean.txt', 15589),
#  ('120-clean.txt', 34581),
#  ('1232-clean.txt', 23021),
#  ('1260-clean.txt', 91946),
#  ('1322-clean.txt', 67400),
#  ('1342-clean.txt', 57307),
#  ('135-clean.txt', 288377),
#  ('1399-clean.txt', 173226),
#  ('140-clean.txt', 70693),
#  ('1400-clean.txt', 87450),
#  ('1404-clean.txt', 91284),
#  ('14264-clean.txt', 38978),
#  ('147-clean.txt', 10640),
#  ('1497-clean.txt', 98946),
#  ('15399-clean.txt', 38240),
#  ('158-clean.txt', 75454),
#  ('16-clean.txt', 23919),
#  ('160-clean.txt', 32962),
#  ('161-clean.txt', 56016),
#  ('16382-clean.txt', 71067),
#  ('1661-clean.txt', 49411),
#  ('1727-clean.txt', 59474),
#  ('174-clean.txt', 38744),
#  ('1952-yellow_wallpaper-clean.txt', 2978),
#  ('19942-clean.txt', 18535),
#  ('20-clean.txt', 47100),
#  ('20203-clean.txt', 37660),
#  ('203-clean.txt', 96324),
#  ('205-clean.txt', 54786),
#  ('21279-clean.txt', 1571),
#  ('2148-clean.txt', 46691),
#  ('2174-clean.txt', 23285),
#  ('219-clean.txt', 18469),
#  ('224-clean.txt', 66929),
#  ('23-clean.txt', 19473),
#  ('236-clean.txt', 26308),
#  ('2500-clean.txt', 19035),
#  ('25305-clean.txt', 38416),
#  ('2591-clean.txt', 45883),
#  ('2600-clean.txt', 296264),
#  ('2680-clean.txt', 34779),
#  ('2701-moby-clean.txt', 112067),
#  ('28054-clean.txt', 170412),
#  ('2814-clean.txt', 36937),
#  ('2852-clean.txt', 28211),
#  ('28520-clean.txt', 15768),
#  ('30360-clean.txt', 121187),
#  ('30601-clean.txt', 33035),
#  ('3207-clean.txt', 100707),
#  ('33-clean.txt', 42341),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 75049),
#  ('34901-clean.txt', 24055),
#  ('35-clean.txt', 15812),
#  ('36-clean.txt', 30839),
#  ('3600-clean.txt', 253407),
#  ('38427-clean.txt', 98400),
#  ('408-clean.txt', 36484),
#  ('41-clean.txt', 6235),
#  ('42-clean.txt', 12630),
#  ('4300-clean.txt', 155405),
#  ('4363-clean.txt', 31647),
#  ('45-clean.txt', 54620),
#  ('4517-clean.txt', 17305),
#  ('46-clean.txt', 14621),
#  ('514-clean.txt', 98108),
#  ('5200-clean.txt', 10380),
#  ('521-clean.txt', 51615),
#  ('526-clean.txt', 18687),
#  ('55-clean.txt', 19627),
#  ('55387-clean.txt', 10559),
#  ('55404-clean.txt', 49338),
#  ('6130-clean.txt', 112614),
#  ('730-clean.txt', 82789),
#  ('7370-clean.txt', 25684),
#  ('74-clean.txt', 38214),
#  ('76-clean.txt', 55732),
#  ('768-clean.txt', 57940),
#  ('829-clean.txt', 49050),
#  ('84-clean.txt', 35410),
#  ('844-clean.txt', 11846),
#  ('851-clean.txt', 9049),
#  ('863-clean.txt', 29746),
#  ('8800-clean.txt', 59373),
#  ('932-clean.txt', 3546),
#  ('98-clean.txt', 67493),
#  ('996-clean.txt', 194284)]

# %%
unique_toks_per_fileid4
# Out:
# [('10-clean.txt', 9158),
#  ('100-clean.txt', 20137),
#  ('105-clean.txt', 3102),
#  ('108-clean.txt', 5106),
#  ('1080-clean.txt', 357),
#  ('11-clean.txt', 1034),
#  ('1112-clean.txt', 2145),
#  ('1184-clean.txt', 16475),
#  ('12-clean.txt', 1210),
#  ('120-clean.txt', 3567),
#  ('1232-clean.txt', 2779),
#  ('1260-clean.txt', 10043),
#  ('1322-clean.txt', 10005),
#  ('1342-clean.txt', 3764),
#  ('135-clean.txt', 18618),
#  ('1399-clean.txt', 9753),
#  ('140-clean.txt', 7287),
#  ('1400-clean.txt', 7923),
#  ('1404-clean.txt', 6065),
#  ('14264-clean.txt', 3071),
#  ('147-clean.txt', 1709),
#  ('1497-clean.txt', 7402),
#  ('15399-clean.txt', 4184),
#  ('158-clean.txt', 5274),
#  ('16-clean.txt', 2528),
#  ('160-clean.txt', 4051),
#  ('161-clean.txt', 3979),
#  ('16382-clean.txt', 7184),
#  ('1661-clean.txt', 4971),
#  ('1727-clean.txt', 4713),
#  ('174-clean.txt', 4169),
#  ('1952-yellow_wallpaper-clean.txt', 372),
#  ('19942-clean.txt', 2695),
#  ('20-clean.txt', 6238),
#  ('20203-clean.txt', 5035),
#  ('203-clean.txt', 8870),
#  ('205-clean.txt', 7839),
#  ('21279-clean.txt', 278),
#  ('2148-clean.txt', 7391),
#  ('2174-clean.txt', 1393),
#  ('219-clean.txt', 3544),
#  ('224-clean.txt', 7533),
#  ('23-clean.txt', 2659),
#  ('236-clean.txt', 2568),
#  ('2500-clean.txt', 1518),
#  ('25305-clean.txt', 4886),
#  ('2591-clean.txt', 2459),
#  ('2600-clean.txt', 16502),
#  ('2680-clean.txt', 3610),
#  ('2701-moby-clean.txt', 14112),
#  ('28054-clean.txt', 9240),
#  ('2814-clean.txt', 5227),
#  ('2852-clean.txt', 2957),
#  ('28520-clean.txt', 1665),
#  ('30360-clean.txt', 6941),
#  ('30601-clean.txt', 3966),
#  ('3207-clean.txt', 6121),
#  ('33-clean.txt', 5930),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 6397),
#  ('34901-clean.txt', 3486),
#  ('35-clean.txt', 2385),
#  ('36-clean.txt', 4171),
#  ('3600-clean.txt', 17782),
#  ('38427-clean.txt', 6848),
#  ('408-clean.txt', 5675),
#  ('41-clean.txt', 1609),
#  ('42-clean.txt', 1913),
#  ('4300-clean.txt', 20622),
#  ('4363-clean.txt', 5494),
#  ('45-clean.txt', 4818),
#  ('4517-clean.txt', 2380),
#  ('46-clean.txt', 2134),
#  ('514-clean.txt', 7564),
#  ('5200-clean.txt', 888),
#  ('521-clean.txt', 3458),
#  ('526-clean.txt', 3554),
#  ('55-clean.txt', 1085),
#  ('55387-clean.txt', 1458),
#  ('55404-clean.txt', 5358),
#  ('6130-clean.txt', 9569),
#  ('730-clean.txt', 7384),
#  ('7370-clean.txt', 2648),
#  ('74-clean.txt', 4847),
#  ('76-clean.txt', 4136),
#  ('768-clean.txt', 6281),
#  ('829-clean.txt', 5063),
#  ('84-clean.txt', 4059),
#  ('844-clean.txt', 1065),
#  ('851-clean.txt', 907),
#  ('863-clean.txt', 2896),
#  ('8800-clean.txt', 7792),
#  ('932-clean.txt', 979),
#  ('98-clean.txt', 6828),
#  ('996-clean.txt', 11969)]

# %%
unique_toks_per_fileid2
# Out:
# [('10-clean.txt', 17208),
#  ('100-clean.txt', 28785),
#  ('105-clean.txt', 5922),
#  ('108-clean.txt', 8578),
#  ('1080-clean.txt', 994)]

# %%
save_stuff('frequency_filtered', dictionary4, corpus4, model=None)

# %% [markdown]
# ## EDA Step 5: + phrase modelling

# %%
#Do if time

# %% [markdown]
# # First LDA Model!!!

# %%
from gensim.models import ldamodel

# %%
lda = ldamodel.LdaModel(corpus=corpus2,alpha='auto', id2word=dictionary2, num_topics=10, update_every=0, passes=20)

# %%
name = 'first_lda.model'
lda.save(outputs_dir + name)

# %%
print lda
# Out:
# LdaModel(num_terms=194961, num_topics=10, decay=0.5, chunksize=2000)

# %% [markdown]
# See the topics and their most significant terms

# %%
lda.show_topics()
# Out:
# [(0,
#   u'0.027*"\n" + 0.007*"one" + 0.007*"would" + 0.005*"may" + 0.004*"man" + 0.004*"small" + 0.004*"said" + 0.004*"upon" + 0.004*"letter" + 0.003*"us"'),
#  (1,
#   u'0.036*"\n" + 0.010*"said" + 0.007*"would" + 0.007*"one" + 0.006*"could" + 0.005*"mr" + 0.004*"know" + 0.004*"time" + 0.004*"little" + 0.004*"see"'),
#  (2,
#   u'0.038*"\n" + 0.007*"one" + 0.006*"said" + 0.004*"would" + 0.004*"man" + 0.003*"us" + 0.003*"time" + 0.003*"like" + 0.003*"could" + 0.003*"much"'),
#  (3,
#   u'0.036*"\n" + 0.008*"man" + 0.007*"god" + 0.007*"men" + 0.007*"ich" + 0.006*"power" + 0.006*"one" + 0.005*"law" + 0.004*"also" + 0.004*"therefore"'),
#  (4,
#   u'0.055*"\n" + 0.022*"shall" + 0.020*"unto" + 0.017*"lord" + 0.013*"thou" + 0.011*"thy" + 0.010*"god" + 0.009*"thee" + 0.009*"ye" + 0.009*"said"'),
#  (5,
#   u'0.056*"\n" + 0.008*"said" + 0.007*"one" + 0.005*"man" + 0.004*"would" + 0.003*"upon" + 0.003*"like" + 0.003*"two" + 0.003*"could" + 0.003*"little"'),
#  (6,
#   u'0.038*"\n" + 0.019*"said" + 0.008*"one" + 0.006*"would" + 0.006*"went" + 0.006*"got" + 0.005*"could" + 0.005*"little" + 0.005*"see" + 0.005*"go"'),
#  (7,
#   u'0.017*"\n" + 0.009*"would" + 0.009*"one" + 0.007*"could" + 0.006*"upon" + 0.005*"time" + 0.005*"man" + 0.004*"came" + 0.004*"made" + 0.004*"men"'),
#  (8,
#   u'0.011*"things" + 0.011*"thou" + 0.008*"earth" + 0.007*"\n" + 0.005*"doth" + 0.005*"either" + 0.005*"nature" + 0.005*"unto" + 0.004*"thyself" + 0.004*"globe"'),
#  (9,
#   u'0.019*"\n" + 0.011*"thou" + 0.008*"thy" + 0.006*"thee" + 0.006*"shall" + 0.004*"good" + 0.004*"king" + 0.004*"lord" + 0.004*"one" + 0.004*"come"')]

# %% [markdown]
# For a given document (in bow format), see most relevant topics

# %%
lda.get_document_topics(dictionary2.doc2bow(transform_txt_file_v2('1080-clean.txt')))
# Out:
# [(0, 0.83551263725276792),
#  (1, 0.017758247818321121),
#  (4, 0.033966879261823679),
#  (7, 0.11079299655988328)]

# %%
lda.get_term_topics(100, minimum_probability=0.00001)
# Out:
# [(0, 0.00081795748432229377),
#  (1, 0.00046665540461913628),
#  (2, 0.00039821109443075416),
#  (3, 0.00089142134354498184),
#  (4, 0.00070689873255245941),
#  (5, 0.00075794148467451953),
#  (6, 0.00025252416712527251),
#  (7, 0.00044098219041034128),
#  (8, 0.00014582208768044617),
#  (9, 0.0016219715531712738)]

# %%
lda.get_topic_terms(1)
# Out:
# [(10364, 0.035504333182389526),
#  (8954, 0.0096323354543700022),
#  (12919, 0.0073228099915345771),
#  (1443, 0.006681396288898224),
#  (3530, 0.0063353405287126258),
#  (39835, 0.0052772699844260773),
#  (16982, 0.0042263928343234903),
#  (1031, 0.0036816693497437052),
#  (9837, 0.00359973572788477),
#  (2690, 0.0035094699408091535)]

# %%
for tup in lda.get_topic_terms(0):
    print dictionary2[tup[0]]
# Out:
# one
# would
# may
# man
# small
# said
# upon
# letter
# us

# %% [markdown]
# ## Word2Vec

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

# %%
usher1 = transform_txt_file_v1(usher)
usher1
# Out:
# [u'the',
#  u'fall',
#  u'of',
#  u'the',
#  u'house',
#  u'of',
#  u'usher',
#  u'son',
#  u'coeur',
#  u'est',
#  u'un',
#  u'luth',
#  u'suspendu',
#  u'sitot',
#  u"qu'on",
#  u'le',
#  u'touche',
#  u'il',
#  u'resonne',
#  u'de',
#  u'beranger',
#  u'during',
#  u'the',
#  u'whole',
#  u'of',
#  u'a',
#  u'dull',
#  u'dark',
#  u'and',
#  u'soundless',
#  u'day',
#  u'in',
#  u'the',
#  u'autumn',
#  u'of',
#  u'the',
#  u'year',
#  u'when',
#  u'the',
#  u'clouds',
#  u'hung',
#  u'oppressively',
#  u'low',
#  u'in',
#  u'the',
#  u'heavens',
#  u'i',
#  u'had',
#  u'been',
#  u'passing',
#  u'alone',
#  u'on',
#  u'horseback',
#  u'through',
#  u'a',
#  u'singularly',
#  u'dreary',
#  u'tract',
#  u'of',
#  u'country',
#  u'and',
#  u'at',
#  u'length',
#  u'found',
#  u'myself',
#  u'as',
#  u'the',
#  u'shades',
#  u'of',
#  u'the',
#  u'evening',
#  u'drew',
#  u'on',
#  u'within',
#  u'view',
#  u'of',
#  u'the',
#  u'melancholy',
#  u'house',
#  u'of',
#  u'usher',
#  u'i',
#  u'know',
#  u'not',
#  u'how',
#  u'it',
#  u'was--but',
#  u'with',
#  u'the',
#  u'first',
#  u'glimpse',
#  u'of',
#  u'the',
#  u'building',
#  u'a',
#  u'sense',
#  u'of',
#  u'insufferable',
#  u'gloom',
#  u'pervaded',
#  u'my',
#  u'spirit',
#  u'i',
#  u'say',
#  u'insufferable',
#  u'for',
#  u'the',
#  u'feeling',
#  u'was',
#  u'unrelieved',
#  u'by',
#  u'any',
#  u'of',
#  u'that',
#  u'half-pleasureable',
#  u'because',
#  u'poetic',
#  u'sentiment',
#  u'with',
#  u'which',
#  u'the',
#  u'mind',
#  u'usually',
#  u'receives',
#  u'even',
#  u'the',
#  u'sternest',
#  u'natural',
#  u'images',
#  u'of',
#  u'the',
#  u'desolate',
#  u'or',
#  u'terrible',
#  u'i',
#  u'looked',
#  u'upon',
#  u'the',
#  u'scene',
#  u'before',
#  u'me--upon',
#  u'the',
#  u'mere',
#  u'house',
#  u'and',
#  u'the',
#  u'simple',
#  u'landscape',
#  u'features',
#  u'of',
#  u'the',
#  u'domain--upon',
#  u'the',
#  u'bleak',
#  u'walls--upon',
#  u'the',
#  u'vacant',
#  u'eye-like',
#  u'windows--upon',
#  u'a',
#  u'few',
#  u'rank',
#  u'sedges--and',
#  u'upon',
#  u'a',
#  u'few',
#  u'white',
#  u'trunks',
#  u'of',
#  u'decayed',
#  u'trees--with',
#  u'an',
#  u'utter',
#  u'depression',
#  u'of',
#  u'soul',
#  u'which',
#  u'i',
#  u'can',
#  u'compare',
#  u'to',
#  u'no',
#  u'earthly',
#  u'sensation',
#  u'more',
#  u'properly',
#  u'than',
#  u'to',
#  u'the',
#  u'after-dream',
#  u'of',
#  u'the',
#  u'reveller',
#  u'upon',
#  u'opium--the',
#  u'bitter',
#  u'lapse',
#  u'into',
#  u'everyday',
#  u'life--the',
#  u'hideous',
#  u'dropping',
#  u'off',
#  u'of',
#  u'the',
#  u'veil',
#  u'there',
#  u'was',
#  u'an',
#  u'iciness',
#  u'a',
#  u'sinking',
#  u'a',
#  u'sickening',
#  u'of',
#  u'the',
#  u'heart--an',
#  u'unredeemed',
#  u'dreariness',
#  u'of',
#  u'thought',
#  u'which',
#  u'no',
#  u'goading',
#  u'of',
#  u'the',
#  u'imagination',
#  u'could',
#  u'torture',
#  u'into',
#  u'aught',
#  u'of',
#  u'the',
#  u'sublime',
#  u'what',
#  u'was',
#  u'it--i',
#  u'paused',
#  u'to',
#  u'think--what',
#  u'was',
#  u'it',
#  u'that',
#  u'so',
#  u'unnerved',
#  u'me',
#  u'in',
#  u'the',
#  u'contemplation',
#  u'of',
#  u'the',
#  u'house',
#  u'of',
#  u'usher',
#  u'it',
#  u'was',
#  u'a',
#  u'mystery',
#  u'all',
#  u'insoluble',
#  u'nor',
#  u'could',
#  u'i',
#  u'grapple',
#  u'with',
#  u'the',
#  u'shadowy',
#  u'fancies',
#  u'that',
#  u'crowded',
#  u'upon',
#  u'me',
#  u'as',
#  u'i',
#  u'pondered',
#  u'i',
#  u'was',
#  u'forced',
#  u'to',
#  u'fall',
#  u'back',
#  u'upon',
#  u'the',
#  u'unsatisfactory',
#  u'conclusion',
#  u'that',
#  u'while',
#  u'beyond',
#  u'doubt',
#  u'there',
#  u'are',
#  u'combinations',
#  u'of',
#  u'very',
#  u'simple',
#  u'natural',
#  u'objects',
#  u'which',
#  u'have',
#  u'the',
#  u'power',
#  u'of',
#  u'thus',
#  u'affecting',
#  u'us',
#  u'still',
#  u'the',
#  u'analysis',
#  u'of',
#  u'this',
#  u'power',
#  u'lies',
#  u'among',
#  u'considerations',
#  u'beyond',
#  u'our',
#  u'depth',
#  u'it',
#  u'was',
#  u'possible',
#  u'i',
#  u'reflected',
#  u'that',
#  u'a',
#  u'mere',
#  u'different',
#  u'arrangement',
#  u'of',
#  u'the',
#  u'particulars',
#  u'of',
#  u'the',
#  u'scene',
#  u'of',
#  u'the',
#  u'details',
#  u'of',
#  u'the',
#  u'picture',
#  u'would',
#  u'be',
#  u'sufficient',
#  u'to',
#  u'modify',
#  u'or',
#  u'perhaps',
#  u'to',
#  u'annihilate',
#  u'its',
#  u'capacity',
#  u'for',
#  u'sorrowful',
#  u'impression',
#  u'and',
#  u'acting',
#  u'upon',
#  u'this',
#  u'idea',
#  u'i',
#  u'reined',
#  u'my',
#  u'horse',
#  u'to',
#  u'the',
#  u'precipitous',
#  u'brink',
#  u'of',
#  u'a',
#  u'black',
#  u'and',
#  u'lurid',
#  u'tarn',
#  u'that',
#  u'lay',
#  u'in',
#  u'unruffled',
#  u'lustre',
#  u'by',
#  u'the',
#  u'dwelling',
#  u'and',
#  u'gazed',
#  u'down--but',
#  u'with',
#  u'a',
#  u'shudder',
#  u'even',
#  u'more',
#  u'thrilling',
#  u'than',
#  u'before--upon',
#  u'the',
#  u'remodelled',
#  u'and',
#  u'inverted',
#  u'images',
#  u'of',
#  u'the',
#  u'grey',
#  u'sedge',
#  u'and',
#  u'the',
#  u'ghastly',
#  u'tree-stems',
#  u'and',
#  u'the',
#  u'vacant',
#  u'and',
#  u'eye-like',
#  u'windows',
#  u'nevertheless',
#  u'in',
#  u'this',
#  u'mansion',
#  u'of',
#  u'gloom',
#  u'i',
#  u'now',
#  u'proposed',
#  u'to',
#  u'myself',
#  u'a',
#  u'sojourn',
#  u'of',
#  u'some',
#  u'weeks',
#  u'its',
#  u'proprietor',
#  u'roderick',
#  u'usher',
#  u'had',
#  u'been',
#  u'one',
#  u'of',
#  u'my',
#  u'boon',
#  u'companions',
#  u'in',
#  u'boyhood',
#  u'but',
#  u'many',
#  u'years',
#  u'had',
#  u'elapsed',
#  u'since',
#  u'our',
#  u'last',
#  u'meeting',
#  u'a',
#  u'letter',
#  u'however',
#  u'had',
#  u'lately',
#  u'reached',
#  u'me',
#  u'in',
#  u'a',
#  u'distant',
#  u'part',
#  u'of',
#  u'the',
#  u'country--a',
#  u'letter',
#  u'from',
#  u'him--which',
#  u'in',
#  u'its',
#  u'wildly',
#  u'importunate',
#  u'nature',
#  u'had',
#  u'admitted',
#  u'of',
#  u'no',
#  u'other',
#  u'than',
#  u'a',
#  u'personal',
#  u'reply',
#  u'the',
#  u'ms',
#  u'gave',
#  u'evidence',
#  u'of',
#  u'nervous',
#  u'agitation',
#  u'the',
#  u'writer',
#  u'spoke',
#  u'of',
#  u'acute',
#  u'bodily',
#  u'illness--of',
#  u'a',
#  u'mental',
#  u'disorder',
#  u'which',
#  u'oppressed',
#  u'him--and',
#  u'of',
#  u'an',
#  u'earnest',
#  u'desire',
#  u'to',
#  u'see',
#  u'me',
#  u'as',
#  u'his',
#  u'best',
#  u'and',
#  u'indeed',
#  u'his',
#  u'only',
#  u'personal',
#  u'friend',
#  u'with',
#  u'a',
#  u'view',
#  u'of',
#  u'attempting',
#  u'by',
#  u'the',
#  u'cheerfulness',
#  u'of',
#  u'my',
#  u'society',
#  u'some',
#  u'alleviation',
#  u'of',
#  u'his',
#  u'malady',
#  u'it',
#  u'was',
#  u'the',
#  u'manner',
#  u'in',
#  u'which',
#  u'all',
#  u'this',
#  u'and',
#  u'much',
#  u'more',
#  u'was',
#  u'said--it',
#  u'was',
#  u'the',
#  u'apparent',
#  u'heart',
#  u'that',
#  u'went',
#  u'with',
#  u'his',
#  u'request--which',
#  u'allowed',
#  u'me',
#  u'no',
#  u'room',
#  u'for',
#  u'hesitation',
#  u'and',
#  u'i',
#  u'accordingly',
#  u'obeyed',
#  u'forthwith',
#  u'what',
#  u'i',
#  u'still',
#  u'considered',
#  u'a',
#  u'very',
#  u'singular',
#  u'summons',
#  u'although',
#  u'as',
#  u'boys',
#  u'we',
#  u'had',
#  u'been',
#  u'even',
#  u'intimate',
#  u'associates',
#  u'yet',
#  u'i',
#  u'really',
#  u'knew',
#  u'little',
#  u'of',
#  u'my',
#  u'friend',
#  u'his',
#  u'reserve',
#  u'had',
#  u'been',
#  u'always',
#  u'excessive',
#  u'and',
#  u'habitual',
#  u'i',
#  u'was',
#  u'aware',
#  u'however',
#  u'that',
#  u'his',
#  u'very',
#  u'ancient',
#  u'family',
#  u'had',
#  u'been',
#  u'noted',
#  u'time',
#  u'out',
#  u'of',
#  u'mind',
#  u'for',
#  u'a',
#  u'peculiar',
#  u'sensibility',
#  u'of',
#  u'temperament',
#  u'displaying',
#  u'itself',
#  u'through',
#  u'long',
#  u'ages',
#  u'in',
#  u'many',
#  u'works',
#  u'of',
#  u'exalted',
#  u'art',
#  u'and',
#  u'manifested',
#  u'of',
#  u'late',
#  u'in',
#  u'repeated',
#  u'deeds',
#  u'of',
#  u'munificent',
#  u'yet',
#  u'unobtrusive',
#  u'charity',
#  u'as',
#  u'well',
#  u'as',
#  u'in',
#  u'a',
#  u'passionate',
#  u'devotion',
#  u'to',
#  u'the',
#  u'intricacies',
#  u'perhaps',
#  u'even',
#  u'more',
#  u'than',
#  u'to',
#  u'the',
#  u'orthodox',
#  u'and',
#  u'easily',
#  u'recognisable',
#  u'beauties',
#  u'of',
#  u'musical',
#  u'science',
#  u'i',
#  u'had',
#  u'learned',
#  u'too',
#  u'the',
#  u'very',
#  u'remarkable',
#  u'fact',
#  u'that',
#  u'the',
#  u'stem',
#  u'of',
#  u'the',
#  u'usher',
#  u'race',
#  u'all',
#  u'time-honoured',
#  u'as',
#  u'it',
#  u'was',
#  u'had',
#  u'put',
#  u'forth',
#  u'at',
#  u'no',
#  u'period',
#  u'any',
#  u'enduring',
#  u'branch',
#  u'in',
#  u'other',
#  u'words',
#  u'that',
#  u'the',
#  u'entire',
#  u'family',
#  u'lay',
#  u'in',
#  u'the',
#  u'direct',
#  u'line',
#  u'of',
#  u'descent',
#  u'and',
#  u'had',
#  u'always',
#  u'with',
#  u'very',
#  u'trifling',
#  u'and',
#  u'very',
#  u'temporary',
#  u'variation',
#  u'so',
#  u'lain',
#  u'it',
#  u'was',
#  u'this',
#  u'deficiency',
#  u'i',
#  u'considered',
#  u'while',
#  u'running',
#  u'over',
#  u'in',
#  u'thought',
#  u'the',
#  u'perfect',
#  u'keeping',
#  u'of',
#  u'the',
#  u'character',
#  u'of',
#  u'the',
#  u'premises',
#  u'with',
#  u'the',
#  u'accredited',
#  u'character',
#  u'of',
#  u'the',
#  u'people',
#  u'and',
#  u'while',
#  u'speculating',
#  u'upon',
#  u'the',
#  u'possible',
#  u'influence',
#  u'which',
#  u'the',
#  u'one',
#  u'in',
#  u'the',
#  u'long',
#  u'lapse',
#  u'of',
#  u'centuries',
#  u'might',
#  u'have',
#  u'exercised',
#  u'upon',
#  u'the',
#  u'other--it',
#  u'was',
#  u'this',
#  u'deficiency',
#  u'perhaps',
#  u'of',
#  u'collateral',
#  u'issue',
#  u'and',
#  u'the',
#  u'consequent',
#  u'undeviating',
#  u'transmission',
#  u'from',
#  u'sire',
#  u'to',
#  u'son',
#  u'of',
#  u'the',
#  u'patrimony',
#  u'with',
#  u'the',
#  u'name',
#  u'which',
#  u'had',
#  u'at',
#  u'length',
#  u'so',
#  u'identified',
#  u'the',
#  u'two',
#  u'as',
#  u'to',
#  u'merge',
#  u'the',
#  u'original',
#  u'title',
#  u'of',
#  u'the',
#  u'estate',
#  u'in',
#  u'the',
#  u'quaint',
#  u'and',
#  u'equivocal',
#  u'appellation',
#  u'of',
#  u'the',
#  u'house',
#  u'of',
#  u'usher"--an',
#  u'appellation',
#  u'which',
#  u'seemed',
#  u'to',
#  u'include',
#  u'in',
#  u'the',
#  u'minds',
#  u'of',
#  u'the',
#  u'peasantry',
#  u'who',
#  u'used',
#  u'it',
#  u'both',
#  u'the',
#  u'family',
#  u'and',
#  u'the',
#  u'family',
#  u'mansion',
#  u'i',
#  u'have',
#  u'said',
#  u'that',
#  u'the',
#  u'sole',
#  u'effect',
#  u'of',
#  u'my',
#  u'somewhat',
#  u'childish',
#  u'experiment--that',
#  u'of',
#  u'looking',
#  u'down',
#  u'within',
#  u'the',
#  u'tarn--had',
#  u'been',
#  u'to',
#  u'deepen',
#  u'the',
#  u'first',
#  u'singular',
#  u'impression',
#  u'there',
#  u'can',
#  u'be',
#  u'no',
#  u'doubt',
#  u'that',
#  u'the',
#  u'consciousness',
#  u'of',
#  u'the',
#  u'rapid',
#  u'increase',
#  u'of',
#  u'my',
#  u'superstition--for',
#  u'why',
#  u'should',
#  u'i',
#  u'not',
#  u'so',
#  u'term',
#  u'it?--served',
#  u'mainly',
#  u'to',
#  u'accelerate',
#  u'the',
#  u'increase',
#  u'itself',
#  u'such',
#  u'i',
#  u'have',
#  u'long',
#  u'known',
#  u'is',
#  u'the',
#  u'paradoxical',
#  u'law',
#  u'of',
#  u'all',
#  u'sentiments',
#  u'having',
#  u'terror',
#  u'as',
#  u'a',
#  u'basis',
#  u'and',
#  u'it',
#  u'might',
#  u'have',
#  u'been',
#  u'for',
#  u'this',
#  u'reason',
#  u'only',
#  u'that',
#  u'when',
#  u'i',
#  u'again',
#  u'uplifted',
#  u'my',
#  u'eyes',
#  u'to',
#  u'the',
#  u'house',
#  u'itself',
#  u'from',
#  u'its',
#  u'image',
#  u'in',
#  u'the',
#  u'pool',
#  u'there',
#  u'grew',
#  u'in',
#  u'my',
#  u'mind',
#  u'a',
#  u'strange',
#  u'fancy--a',
#  u'fancy',
#  u'so',
#  u'ridiculous',
#  u'indeed',
#  u'that',
#  u'i',
#  u'but',
#  u'mention',
#  u'it',
#  u'to',
#  u'show',
#  u'the',
#  u'vivid',
#  u'force',
#  u'of',
#  u'the',
#  u'sensations',
#  u'which',
#  u'oppressed',
#  u'me',
#  u'i',
#  u'had',
#  u'so',
#  u'worked',
#  u'upon',
#  u'my',
#  u'imagination',
#  u'as',
#  u'really',
#  u'to',
#  u'believe',
#  u'that',
#  u'about',
#  u'the',
#  u'whole',
#  u'mansion',
#  u'and',
#  u'domain',
#  u'there',
#  u'hung',
#  u'an',
#  u'atmosphere',
#  u'peculiar',
#  u'to',
#  u'themselves',
#  u'and',
#  u'their',
#  u'immediate',
#  u'vicinity--an',
#  u'atmosphere',
#  u'which',
#  u'had',
#  u'no',
#  u'affinity',
#  u'with',
#  ...]

# %%
sentences = LineSentence(source_dir + usher)
sentences

# %%
#this does nothing to prepare the text - this was just to get some data
#read in. Look here for iterator method: https://rare-technologies.com/word2vec-tutorial/

# %%
w2v_model = Word2Vec(sentences)

# %%
##Note: word2vec does word freq pruning

# %%
type(w2v_model)
# Out:
# gensim.models.word2vec.Word2Vec

# %%
w2v_model.corpus_count
# Out:
# 721

# %%
t = w2v_model.create_binary_tree()
t
#?? doesn't do anything

# %%
w2v_model.raw_vocab
# Out:
# defaultdict(int, {})

# %%
w2v_model.wv.index2word[0]
# Out:
# u'the'

# %%
[w2v_model.wv.index2word[n] for n in xrange(154)]
# Out:
# [u'the',
#  u'of',
#  u'and',
#  u'I',
#  u'a',
#  u'in',
#  u'to',
#  u'which',
#  u'his',
#  u'that',
#  u'had',
#  u'was',
#  u'with',
#  u'as',
#  u'my',
#  u'upon',
#  u'he',
#  u'not',
#  u'for',
#  u'at',
#  u'from',
#  u'an',
#  u'this',
#  u'The',
#  u'by',
#  u'its',
#  u'have',
#  u'no',
#  u'so',
#  u'all',
#  u'were',
#  u'or',
#  u'her',
#  u'me',
#  u'been',
#  u'it',
#  u'there',
#  u'be',
#  u'now',
#  u'more',
#  u'long',
#  u'but',
#  u'It',
#  u'yet',
#  u'some',
#  u'into',
#  u'over',
#  u'on',
#  u'could',
#  u'A',
#  u'His',
#  u'if',
#  u'one',
#  u'very',
#  u'about',
#  u'even',
#  u'however,',
#  u'certain',
#  u'through',
#  u'their',
#  u'portion',
#  u'before',
#  u'was,',
#  u'than',
#  u'many',
#  u'him',
#  u'within',
#  u'having',
#  u'our',
#  u'And',
#  u'wild',
#  u'still',
#  u'any',
#  u'In',
#  u'found',
#  u'what',
#  u'thus',
#  u'well',
#  u'we',
#  u'character',
#  u'these',
#  u'it,',
#  u'whole',
#  u'up',
#  u'me,',
#  u'mind',
#  u'shall',
#  u'door,',
#  u'air',
#  u'hung',
#  u'low',
#  u'did',
#  u'and,',
#  u'myself',
#  u'might',
#  u'much',
#  u'should',
#  u'she',
#  u'will',
#  u'me.',
#  u'would',
#  u'ghastly',
#  u'Usher',
#  u'is',
#  u'gave',
#  u'He',
#  u'when',
#  u'first',
#  u'only',
#  u'countenance',
#  u'without',
#  u'lady',
#  u'him,',
#  u'full',
#  u'family',
#  u'mental',
#  u'last',
#  u'length,',
#  u'influence',
#  u'heard',
#  u'singular',
#  u'out',
#  u'words',
#  u'thought',
#  u'mere',
#  u'made',
#  u'other',
#  u'indeed,',
#  u'(for',
#  u'never',
#  u'ordinary',
#  u'lay',
#  u'perhaps,',
#  u'peculiar',
#  u'dared',
#  u'came',
#  u'Usher,',
#  u'threw',
#  u'which,',
#  u'Usher.',
#  u'alone',
#  u'Madeline',
#  u'We',
#  u'unusual',
#  u'must',
#  u'you',
#  u'terrible',
#  u'most',
#  u'intense',
#  u'us',
#  u'once',
#  u'saw',
#  u'objects',
#  u'few']

# %%
w2v_model.wv['Usher']
# Out:
# array([  8.45681783e-03,  -4.39963164e-03,  -4.91341110e-03,
#          5.38371969e-03,   6.34652330e-04,   5.14846249e-03,
#         -3.66568426e-03,  -8.43488239e-03,   1.08329077e-05,
#         -8.17000493e-03,  -2.30804435e-03,  -7.82304816e-03,
#         -7.98802357e-03,   5.43261506e-03,  -2.34154589e-03,
#          1.23616206e-02,   1.67156872e-03,  -2.01779325e-03,
#          4.29236749e-03,  -4.66562016e-03,  -5.38349792e-04,
#          1.96097558e-03,   1.03308698e-02,   6.90320227e-03,
#         -6.02438522e-05,   3.74780095e-04,  -3.29784438e-04,
#         -2.37007462e-03,  -1.33334603e-02,   1.53001456e-03,
#         -1.39171313e-02,   1.34639088e-02,  -4.02349886e-03,
#         -7.04521826e-03,  -4.18594759e-03,   7.48682255e-03,
#         -6.18552440e-04,   3.92296817e-03,  -9.61316400e-04,
#         -5.97934355e-04,  -2.50450894e-03,   1.25131372e-03,
#         -5.60161285e-03,  -5.99381467e-03,  -2.64261430e-03,
#          1.49250822e-03,   3.71399103e-03,   1.07647404e-02,
#          4.66987398e-03,   1.05606383e-02,   4.28940775e-03,
#         -4.67997277e-03,  -7.30663398e-03,  -4.28740354e-03,
#          1.70315965e-03,   5.82096679e-03,  -4.27342660e-04,
#         -4.89179464e-03,  -7.73676578e-03,  -5.48595563e-03,
#          7.52760004e-03,   2.30079531e-04,  -3.73559352e-03,
#         -7.67297810e-03,   3.16443737e-03,   1.36193528e-03,
#          1.44906354e-03,   6.58345828e-03,   1.01829041e-02,
#         -3.82317184e-03,  -4.53551160e-03,  -7.49095459e-04,
#         -6.80984976e-03,  -1.36737028e-04,   3.73759493e-03,
#          3.67834629e-03,  -2.84396112e-03,   3.17040039e-03,
#          2.73388554e-03,   3.94690828e-03,  -1.16894515e-02,
#          1.04467515e-02,   5.60268015e-03,  -4.57096659e-03,
#          7.17692170e-03,  -7.34853791e-03,  -4.45857615e-04,
#         -3.83450650e-03,   1.09374505e-02,  -1.15839497e-03,
#         -1.28884204e-02,  -4.73323232e-03,  -2.21868337e-04,
#          2.45480449e-03,  -2.55957386e-03,  -6.15711231e-03,
#          9.36762430e-03,   5.26318210e-04,  -3.67057323e-03,
#         -5.70499152e-03], dtype=float32)

# %%
##lots of work to do to understand this model and how to use it for my pres

# %% [markdown]
# ## Doc2Vec

# %%
#dewey decimal system recreation??
#recreate gutenberg topics?

# %% [markdown]
# At the end - bar chart of changes?
