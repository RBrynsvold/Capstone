# %%
import os, codecs
import gensim
from gensim import corpora
from collections import defaultdict
import string
from string import punctuation
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
class IterFile(object):
    '''
    class object to do the iterating on individual book txt documents, including file i/o.
    '''
    
    def __init__(self, filepath):
        self.filepath = filepath
        
    def _open_file(self):
        self.file = codecs.open(self.filepath, 'r', encoding='utf_8')
        
    def _close_file(self):
        self.file.close()
    
    def __iter__(self):
        '''
        overwrite iteration to include file i/o
        '''
        self._open_file()
        
        for line in self.file:
            yield line
        
        self._close_file()

# %%
source_dir = '/Users/rachelbrynsvold/dsi/capstone_dir/top_100_dev_corp/books/clean/'

# %%
def transform_txt_file_v1(fname, root=source_dir):
    '''
    Initial pass at text transformation
    Reimplemented later (v2 etc) as a caller of various subfunctions to do all the transformation
    '''
    fp = root + fname

    book_as_lst = []
    for line in IterFile(fp):
        if line == "\n":
            pass
        else: 
            line_lst= [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
            book_as_lst.extend(line_lst)
            
    #add in stop word removal and frequency threshhold
    return book_as_lst

# %% [markdown]
# ## EDA Step 0: Test transform function with short book (Fall of the House of Usher)

# %%
usher = '932-clean.txt'
print transform_txt_file_v1(usher)
# Out:
# [u'the', u'fall', u'of', u'the', u'house', u'of', u'usher', u'son', u'coeur', u'est', u'un', u'luth', u'suspendu', u'sitot', u"qu'on", u'le', u'touche', u'il', u'resonne', u'de', u'beranger', u'during', u'the', u'whole', u'of', u'a', u'dull', u'dark', u'and', u'soundless', u'day', u'in', u'the', u'autumn', u'of', u'the', u'year', u'when', u'the', u'clouds', u'hung', u'oppressively', u'low', u'in', u'the', u'heavens', u'i', u'had', u'been', u'passing', u'alone', u'on', u'horseback', u'through', u'a', u'singularly', u'dreary', u'tract', u'of', u'country', u'and', u'at', u'length', u'found', u'myself', u'as', u'the', u'shades', u'of', u'the', u'evening', u'drew', u'on', u'within', u'view', u'of', u'the', u'melancholy', u'house', u'of', u'usher', u'i', u'know', u'not', u'how', u'it', u'was--but', u'with', u'the', u'first', u'glimpse', u'of', u'the', u'building', u'a', u'sense', u'of', u'insufferable', u'gloom', u'pervaded', u'my', u'spirit', u'i', u'say', u'insufferable', u'for', u'the', u'feeling', u'was', u'unrelieved', u'by', u'any', u'of', u'that', u'half-pleasureable', u'because', u'poetic', u'sentiment', u'with', u'which', u'the', u'mind', u'usually', u'receives', u'even', u'the', u'sternest', u'natural', u'images', u'of', u'the', u'desolate', u'or', u'terrible', u'i', u'looked', u'upon', u'the', u'scene', u'before', u'me--upon', u'the', u'mere', u'house', u'and', u'the', u'simple', u'landscape', u'features', u'of', u'the', u'domain--upon', u'the', u'bleak', u'walls--upon', u'the', u'vacant', u'eye-like', u'windows--upon', u'a', u'few', u'rank', u'sedges--and', u'upon', u'a', u'few', u'white', u'trunks', u'of', u'decayed', u'trees--with', u'an', u'utter', u'depression', u'of', u'soul', u'which', u'i', u'can', u'compare', u'to', u'no', u'earthly', u'sensation', u'more', u'properly', u'than', u'to', u'the', u'after-dream', u'of', u'the', u'reveller', u'upon', u'opium--the',
#  '174-clean.txt',
#  '1952-yellow_wallpaper-clean.txt',
#  '19942-clean.txt',
#  '20-clean.txt',
#  '20203-clean.txt',
#  '203-clean.txt',
#  '205-clean.txt',
#  '21279-clean.txt',
#  '2148-clean.txt',
#  '2174-clean.txt',
#  '219-clean.txt',
#  '224-clean.txt',
#  '23-clean.txt',
#  '236-clean.txt',
#  '2500-clean.txt',
#  '25305-clean.txt',
#  '2591-clean.txt',
#  '2600-clean.txt',
#  '2680-clean.txt',
#  '2701-moby-clean.txt',
#  '28054-clean.txt',
#  '2814-clean.txt',
#  '2852-clean.txt',
#  '28520-clean.txt',
#  '30360-clean.txt',
#  '30601-clean.txt',
#  '3207-clean.txt',
#  '33-clean.txt',
#  '33283-clean.txt',
#  '345-clean.txt',
#  '34901-clean.txt',
#  '35-clean.txt',
#  '36-clean.txt',
#  '3600-clean.txt',
#  '38427-clean.txt',
#  '408-clean.txt',
#  '41-clean.txt',
#  '42-clean.txt',
#  '4300-clean.txt',
#  '4363-clean.txt',
#  '45-clean.txt',
#  '4517-clean.txt',
#  '46-clean.txt',
#  '514-clean.txt',
#  '5200-clean.txt',
#  '521-clean.txt',
#  '526-clean.txt',
#  '55-clean.txt',
#  '55387-clean.txt',
#  '55404-clean.txt',
#  '6130-clean.txt',
#  '730-clean.txt',
#  '7370-clean.txt',
#  '74-clean.txt',
#  '76-clean.txt',
#  '768-clean.txt',
#  '829-clean.txt',
#  '84-clean.txt',
#  '844-clean.txt',
#  '851-clean.txt',
#  '863-clean.txt',
#  '8800-clean.txt',
#  '932-clean.txt',
#  '98-clean.txt',
#  '996-clean.txt']

# %% [markdown]
# ## EDA Step 1: Most basic transformation (tokenization only)

# %% [markdown]
# Apply transformation function to all books

# %%
all_transf_books_lst = []
for f in fileid_lst:
    all_transf_books_lst.append(transform_txt_file_v1(f))

all_transf_books_lst[5]
# Out:
# [u"alice's",
#  u'adventures',
#  u'in',
#  u'wonderland',
#  u'lewis',
#  u'carroll',
#  u'the',
#  u'millennium',
#  u'fulcrum',
#  u'edition',
#  u'3.0',
#  u'chapter',
#  u'i',
#  u'down',
#  u'the',
#  u'rabbit-hole',
#  u'alice',
#  u'was',
#  u'beginning',
#  u'to',
#  u'get',
#  u'very',
#  u'tired',
#  u'of',
#  u'sitting',
#  u'by',
#  u'her',
#  u'sister',
#  u'on',
#  u'the',
#  u'bank',
#  u'and',
#  u'of',
#  u'having',
#  u'nothing',
#  u'to',
#  u'do',
#  u'once',
#  u'or',
#  u'twice',
#  u'she',
#  u'had',
#  u'peeped',
#  u'into',
#  u'the',
#  u'book',
#  u'her',
#  u'sister',
#  u'was',
#  u'reading',
#  u'but',
#  u'it',
#  u'had',
#  u'no',
#  u'pictures',
#  u'or',
#  u'conversations',
#  u'in',
#  u'it',
#  u'and',
#  u'what',
#  u'is',
#  u'the',
#  u'use',
#  u'of',
#  u'a',
#  u'book',
#  u'thought',
#  u'alice',
#  u'without',
#  u'pictures',
#  u'or',
#  u'conversations',
#  u'so',
#  u'she',
#  u'was',
#  u'considering',
#  u'in',
#  u'her',
#  u'own',
#  u'mind',
#  u'as',
#  u'well',
#  u'as',
#  u'she',
#  u'could',
#  u'for',
#  u'the',
#  u'hot',
#  u'day',
#  u'made',
#  u'her',
#  u'feel',
#  u'very',
#  u'sleepy',
#  u'and',
#  u'stupid',
#  u'whether',
#  u'the',
#  u'pleasure',
#  u'of',
#  u'making',
#  u'a',
#  u'daisy-chain',
#  u'would',
#  u'be',
#  u'worth',
#  u'the',
#  u'trouble',
#  u'of',
#  u'getting',
#  u'up',
#  u'and',
#  u'picking',
#  u'the',
#  u'daisies',
#  u'when',
#  u'suddenly',
#  u'a',
#  u'white',
#  u'rabbit',
#  u'with',
#  u'pink',
#  u'eyes',
#  u'ran',
#  u'close',
#  u'by',
#  u'her',
#  u'there',
#  u'was',
#  u'nothing',
#  u'so',
#  u'very',
#  u'remarkable',
#  u'in',
#  u'that',
#  u'nor',
#  u'did',
#  u'alice',
#  u'think',
#  u'it',
#  u'so',
#  u'very',
#  u'much',
#  u'out',
#  u'of',
#  u'the',
#  u'way',
#  u'to',
#  u'hear',
#  u'the',
#  u'rabbit',
#  u'say',
#  u'to',
#  u'itself',
#  u'oh',
#  u'dear',
#  u'oh',
#  u'dear',
#  u'i',
#  u'shall',
#  u'be',
#  u'late',
#  u'when',
#  u'she',
#  u'thought',
#  u'it',
#  u'over',
#  u'afterwards',
#  u'it',
#  u'occurred',
#  u'to',
#  u'her',
#  u'that',
#  u'she',
#  u'ought',
#  u'to',
#  u'have',
#  u'wondered',
#  u'at',
#  u'this',
#  u'but',
#  u'at',
#  u'the',
#  u'time',
#  u'it',
#  u'all',
#  u'seemed',
#  u'quite',
#  u'natural',
#  u'but',
#  u'when',
#  u'the',
#  u'rabbit',
#  u'actually',
#  u'took',
#  u'a',
#  u'watch',
#  u'out',
#  u'of',
#  u'its',
#  u'waistcoat-pocket',
#  u'and',
#  u'looked',
#  u'at',
#  u'it',
#  u'and',
#  u'then',
#  u'hurried',
#  u'on',
#  u'alice',
#  u'started',
#  u'to',
#  u'her',
#  u'feet',
#  u'for',
#  u'it',
#  u'flashed',
#  u'across',
#  u'her',
#  u'mind',
#  u'that',
#  u'she',
#  u'had',
#  u'never',
#  u'before',
#  u'seen',
#  u'a',
#  u'rabbit',
#  u'with',
#  u'either',
#  u'a',
#  u'waistcoat-pocket',
#  u'or',
#  u'a',
#  u'watch',
#  u'to',
#  u'take',
#  u'out',
#  u'of',
#  u'it',
#  u'and',
#  u'burning',
#  u'with',
#  u'curiosity',
#  u'she',
#  u'ran',
#  u'across',
#  u'the',
#  u'field',
#  u'after',
#  u'it',
#  u'and',
#  u'fortunately',
#  u'was',
#  u'just',
#  u'in',
#  u'time',
#  u'to',
#  u'see',
#  u'it',
#  u'pop',
#  u'down',
#  u'a',
#  u'large',
#  u'rabbit-hole',
#  u'under',
#  u'the',
#  u'hedge',
#  u'in',
#  u'another',
#  u'moment',
#  u'down',
#  u'went',
#  u'alice',
#  u'after',
#  u'it',
#  u'never',
#  u'once',
#  u'considering',
#  u'how',
#  u'in',
#  u'the',
#  u'world',
#  u'she',
#  u'was',
#  u'to',
#  u'get',
#  u'out',
#  u'again',
#  u'the',
#  u'rabbit-hole',
#  u'went',
#  u'straight',
#  u'on',
#  u'like',
#  u'a',
#  u'tunnel',
#  u'for',
#  u'some',
#  u'way',
#  u'and',
#  u'then',
#  u'dipped',
#  u'suddenly',
#  u'down',
#  u'so',
#  u'suddenly',
#  u'that',
#  u'alice',
#  u'had',
#  u'not',
#  u'a',
#  u'moment',
#  u'to',
#  u'think',
#  u'about',
#  u'stopping',
#  u'herself',
#  u'before',
#  u'she',
#  u'found',
#  u'herself',
#  u'falling',
#  u'down',
#  u'a',
#  u'very',
#  u'deep',
#  u'well',
#  u'either',
#  u'the',
#  u'well',
#  u'was',
#  u'very',
#  u'deep',
#  u'or',
#  u'she',
#  u'fell',
#  u'very',
#  u'slowly',
#  u'for',
#  u'she',
#  u'had',
#  u'plenty',
#  u'of',
#  u'time',
#  u'as',
#  u'she',
#  u'went',
#  u'down',
#  u'to',
#  u'look',
#  u'about',
#  u'her',
#  u'and',
#  u'to',
#  u'wonder',
#  u'what',
#  u'was',
#  u'going',
#  u'to',
#  u'happen',
#  u'next',
#  u'first',
#  u'she',
#  u'tried',
#  u'to',
#  u'look',
#  u'down',
#  u'and',
#  u'make',
#  u'out',
#  u'what',
#  u'she',
#  u'was',
#  u'coming',
#  u'to',
#  u'but',
#  u'it',
#  u'was',
#  u'too',
#  u'dark',
#  u'to',
#  u'see',
#  u'anything',
#  u'then',
#  u'she',
#  u'looked',
#  u'at',
#  u'the',
#  u'sides',
#  u'of',
#  u'the',
#  u'well',
#  u'and',
#  u'noticed',
#  u'that',
#  u'they',
#  u'were',
#  u'filled',
#  u'with',
#  u'cupboards',
#  u'and',
#  u'book-shelves',
#  u'here',
#  u'and',
#  u'there',
#  u'she',
#  u'saw',
#  u'maps',
#  u'and',
#  u'pictures',
#  u'hung',
#  u'upon',
#  u'pegs',
#  u'she',
#  u'took',
#  u'down',
#  u'a',
#  u'jar',
#  u'from',
#  u'one',
#  u'of',
#  u'the',
#  u'shelves',
#  u'as',
#  u'she',
#  u'passed',
#  u'it',
#  u'was',
#  u'labelled',
#  u'orange',
#  u'marmalade',
#  u'but',
#  u'to',
#  u'her',
#  u'great',
#  u'disappointment',
#  u'it',
#  u'was',
#  u'empty',
#  u'she',
#  u'did',
#  u'not',
#  u'like',
#  u'to',
#  u'drop',
#  u'the',
#  u'jar',
#  u'for',
#  u'fear',
#  u'of',
#  u'killing',
#  u'somebody',
#  u'so',
#  u'managed',
#  u'to',
#  u'put',
#  u'it',
#  u'into',
#  u'one',
#  u'of',
#  u'the',
#  u'cupboards',
#  u'as',
#  u'she',
#  u'fell',
#  u'past',
#  u'it',
#  u'well',
#  u'thought',
#  u'alice',
#  u'to',
#  u'herself',
#  u'after',
#  u'such',
#  u'a',
#  u'fall',
#  u'as',
#  u'this',
#  u'i',
#  u'shall',
#  u'think',
#  u'nothing',
#  u'of',
#  u'tumbling',
#  u'down',
#  u'stairs',
#  u'how',
#  u'brave',
#  u"they'll",
#  u'all',
#  u'think',
#  u'me',
#  u'at',
#  u'home',
#  u'why',
#  u'i',
#  u"wouldn't",
#  u'say',
#  u'anything',
#  u'about',
#  u'it',
#  u'even',
#  u'if',
#  u'i',
#  u'fell',
#  u'off',
#  u'the',
#  u'top',
#  u'of',
#  u'the',
#  u'house',
#  u'which',
#  u'was',
#  u'very',
#  u'likely',
#  u'true',
#  u'down',
#  u'down',
#  u'down',
#  u'would',
#  u'the',
#  u'fall',
#  u'never',
#  u'come',
#  u'to',
#  u'an',
#  u'end',
#  u'i',
#  u'wonder',
#  u'how',
#  u'many',
#  u'miles',
#  u"i've",
#  u'fallen',
#  u'by',
#  u'this',
#  u'time',
#  u'she',
#  u'said',
#  u'aloud',
#  u'i',
#  u'must',
#  u'be',
#  u'getting',
#  u'somewhere',
#  u'near',
#  u'the',
#  u'centre',
#  u'of',
#  u'the',
#  u'earth',
#  u'let',
#  u'me',
#  u'see',
#  u'that',
#  u'would',
#  u'be',
#  u'four',
#  u'thousand',
#  u'miles',
#  u'down',
#  u'i',
#  u'think',
#  u'for',
#  u'you',
#  u'see',
#  u'alice',
#  u'had',
#  u'learnt',
#  u'several',
#  u'things',
#  u'of',
#  u'this',
#  u'sort',
#  u'in',
#  u'her',
#  u'lessons',
#  u'in',
#  u'the',
#  u'schoolroom',
#  u'and',
#  u'though',
#  u'this',
#  u'was',
#  u'not',
#  u'a',
#  u'very',
#  u'good',
#  u'opportunity',
#  u'for',
#  u'showing',
#  u'off',
#  u'her',
#  u'knowledge',
#  u'as',
#  u'there',
#  u'was',
#  u'no',
#  u'one',
#  u'to',
#  u'listen',
#  u'to',
#  u'her',
#  u'still',
#  u'it',
#  u'was',
#  u'good',
#  u'practice',
#  u'to',
#  u'say',
#  u'it',
#  u'over',
#  u'yes',
#  u"that's",
#  u'about',
#  u'the',
#  u'right',
#  u'distance--but',
#  u'then',
#  u'i',
#  u'wonder',
#  u'what',
#  u'latitude',
#  u'or',
#  u'longitude',
#  u"i've",
#  u'got',
#  u'to',
#  u'alice',
#  u'had',
#  u'no',
#  u'idea',
#  u'what',
#  u'latitude',
#  u'was',
#  u'or',
#  u'longitude',
#  u'either',
#  u'but',
#  u'thought',
#  u'they',
#  u'were',
#  u'nice',
#  u'grand',
#  u'words',
#  u'to',
#  u'say',
#  u'presently',
#  u'she',
#  u'began',
#  u'again',
#  u'i',
#  u'wonder',
#  u'if',
#  u'i',
#  u'shall',
#  u'fall',
#  u'right',
#  u'through',
#  u'the',
#  u'earth',
#  u'how',
#  u'funny',
#  u"it'll",
#  u'seem',
#  u'to',
#  u'come',
#  u'out',
#  u'among',
#  u'the',
#  u'people',
#  u'that',
#  u'walk',
#  u'with',
#  u'their',
#  u'heads',
#  u'downward',
#  u'the',
#  u'antipathies',
#  u'i',
#  u'think',
#  u'she',
#  u'was',
#  u'rather',
#  u'glad',
#  u'there',
#  u'was',
#  u'no',
#  u'one',
#  u'listening',
#  u'this',
#  u'time',
#  u'as',
#  u'it',
#  u"didn't",
#  u'sound',
#  u'at',
#  u'all',
#  u'the',
#  u'right',
#  u'word',
#  u'but',
#  u'i',
#  u'shall',
#  u'have',
#  u'to',
#  u'ask',
#  u'them',
#  u'what',
#  u'the',
#  u'name',
#  u'of',
#  u'the',
#  u'country',
#  u'is',
#  u'you',
#  u'know',
#  u'please',
#  u"ma'am",
#  u'is',
#  u'this',
#  u'new',
#  u'zealand',
#  u'or',
#  u'australia',
#  u'and',
#  u'she',
#  u'tried',
#  u'to',
#  u'curtsey',
#  u'as',
#  u'she',
#  u'spoke--fancy',
#  u'curtseying',
#  u'as',
#  u"you're",
#  u'falling',
#  u'through',
#  u'the',
#  u'air',
#  u'do',
#  u'you',
#  u'think',
#  u'you',
#  u'could',
#  u'manage',
#  u'it',
#  u'and',
#  u'what',
#  u'an',
#  u'ignorant',
#  u'little',
#  u'girl',
#  u"she'll",
#  u'think',
#  u'me',
#  u'for',
#  u'asking',
#  u'no',
#  u"it'll",
#  u'never',
#  u'do',
#  u'to',
#  u'ask',
#  u'perhaps',
#  u'i',
#  u'shall',
#  u'see',
#  u'it',
#  u'written',
#  u'up',
#  u'somewhere',
#  u'down',
#  u'down',
#  u'down',
#  u'there',
#  u'was',
#  u'nothing',
#  u'else',
#  u'to',
#  u'do',
#  u'so',
#  u'alice',
#  u'soon',
#  u'began',
#  u'talking',
#  u'again',
#  u"dinah'll",
#  u'miss',
#  u'me',
#  u'very',
#  u'much',
#  u'to-night',
#  u'i',
#  u'should',
#  u'think',
#  u'dinah',
#  u'was',
#  u'the',
#  u'cat',
#  u'i',
#  u'hope',
#  u"they'll",
#  u'remember',
#  u'her',
#  u'saucer',
#  u'of',
#  u'milk',
#  u'at',
#  u'tea-time',
#  u'dinah',
#  u'my',
#  u'dear',
#  u'i',
#  u'wish',
#  u'you',
#  u'were',
#  u'down',
#  u'here',
#  u'with',
#  u'me',
#  u'there',
#  u'are',
#  u'no',
#  u'mice',
#  u'in',
#  u'the',
#  u'air',
#  u"i'm",
#  u'afraid',
#  u'but',
#  u'you',
#  u'might',
#  u'catch',
#  u'a',
#  u'bat',
#  u'and',
#  u"that's",
#  u'very',
#  u'like',
#  u'a',
#  u'mouse',
#  u'you',
#  u'know',
#  u'but',
#  u'do',
#  u'cats',
#  u'eat',
#  u'bats',
#  u'i',
#  u'wonder',
#  u'and',
#  u'here',
#  u'alice',
#  u'began',
#  u'to',
#  u'get',
#  u'rather',
#  u'sleepy',
#  u'and',
#  u'went',
#  u'on',
#  u'saying',
#  u'to',
#  u'herself',
#  u'in',
#  u'a',
#  u'dreamy',
#  u'sort',
#  u'of',
#  u'way',
#  u'do',
#  u'cats',
#  u'eat',
#  u'bats',
#  u'do',
#  u'cats',
#  u'eat',
#  u'bats',
#  u'and',
#  u'sometimes',
#  u'do',
#  u'bats',
#  u'eat',
#  u'cats',
#  u'for',
#  u'you',
#  u'see',
#  u'as',
#  u'she',
#  u"couldn't",
#  u'answer',
#  u'either',
#  u'question',
#  u'it',
#  u"didn't",
#  u'much',
#  u'matter',
#  u'which',
#  u'way',
#  u'she',
#  u'put',
#  u'it',
#  u'she',
#  u'felt',
#  u'that',
#  u'she',
#  u'was',
#  u'dozing',
#  u'off',
#  u'and',
#  u'had',
#  u'just',
#  u'begun',
#  u'to',
#  u'dream',
#  u'that',
#  u'she',
#  u'was',
#  u'walking',
#  u'hand',
#  u'in',
#  u'hand',
#  u'with',
#  u'dinah',
#  u'and',
#  u'saying',
#  u'to',
#  u'her',
#  u'very',
#  u'earnestly',
#  u'now',
#  u'dinah',
#  u'tell',
#  u'me',
#  u'the',
#  u'truth',
#  u'did',
#  u'you',
#  u'ever',
#  u'eat',
#  u'a',
#  u'bat',
#  u'when',
#  u'suddenly',
#  u'thump',
#  u'thump',
#  u'down',
#  u'she',
#  u'came',
#  u'upon',
#  u'a',
#  u'heap',
#  u'of',
#  u'sticks',
#  u'and',
#  u'dry',
#  u'leaves',
#  u'and',
#  u'the',
#  u'fall',
#  u'was',
#  u'over',
#  u'alice',
#  u'was',
#  u'not',
#  u'a',
#  u'bit',
#  u'hurt',
#  u'and',
#  u'she',
#  u'jumped',
#  u'up',
#  u'on',
#  u'to',
#  u'her',
#  u'feet',
#  u'in',
#  u'a',
#  u'moment',
#  u'she',
#  u'looked',
#  u'up',
#  u'but',
#  u'it',
#  u'was',
#  u'all',
#  u'dark',
#  u'overhead',
#  u'before',
#  u'her',
#  u'was',
#  u'another',
#  u'long',
#  u'passage',
#  u'and',
#  u'the',
#  u'white',
#  ...]

# %% [markdown]
# Cool - looks like I've got all the books in there

# %%
len(all_transf_books_lst)
# Out:
# 95

# %% [markdown]
# ## EDA Step 1.5: Write code snippets to do all the calculations, print-outs, and obj creation that I'll use for the rest of the EDA

# %% [markdown]
# How long is each book (hom many totoal words?)

# %%
book_lengths = []

for tup in zip(fileid_lst, all_transf_books_lst):
    book_lengths.append((tup[0], len(tup[1])))
    
book_lengths
# Out:
# [('10-clean.txt', 821133),
#  ('100-clean.txt', 883320),
#  ('105-clean.txt', 83286),
#  ('108-clean.txt', 112139),
#  ('1080-clean.txt', 3410),
#  ('11-clean.txt', 26449),
#  ('1112-clean.txt', 25898),
#  ('1184-clean.txt', 461184),
#  ('12-clean.txt', 29293),
#  ('120-clean.txt', 68589),
#  ('1232-clean.txt', 49612),
#  ('1260-clean.txt', 185468),
#  ('1322-clean.txt', 121712),
#  ('1342-clean.txt', 121567),
#  ('135-clean.txt', 565761),
#  ('1399-clean.txt', 349978),
#  ('140-clean.txt', 149124),
#  ('1400-clean.txt', 184403),
#  ('1404-clean.txt', 192349),
#  ('14264-clean.txt', 76656),
#  ('147-clean.txt', 21997),
#  ('1497-clean.txt', 216243),
#  ('15399-clean.txt', 82564),
#  ('158-clean.txt', 157441),
#  ('16-clean.txt', 47439),
#  ('160-clean.txt', 63992),
#  ('161-clean.txt', 118580),
#  ('16382-clean.txt', 135922),
#  ('1661-clean.txt', 104493),
#  ('1727-clean.txt', 129410),
#  ('174-clean.txt', 78934),
#  ('1952-yellow_wallpaper-clean.txt', 6067),
#  ('19942-clean.txt', 35861),
#  ('20-clean.txt', 80059),
#  ('20203-clean.txt', 76167),
#  ('203-clean.txt', 180605),
#  ('205-clean.txt', 115797),
#  ('21279-clean.txt', 2591),
#  ('2148-clean.txt', 95057),
#  ('2174-clean.txt', 23416),
#  ('219-clean.txt', 37908),
#  ('224-clean.txt', 130250),
#  ('23-clean.txt', 40747),
#  ('236-clean.txt', 50836),
#  ('2500-clean.txt', 39140),
#  ('25305-clean.txt', 84605),
#  ('2591-clean.txt', 101109),
#  ('2600-clean.txt', 563288),
#  ('2680-clean.txt', 72026),
#  ('2701-moby-clean.txt', 212103),
#  ('28054-clean.txt', 350856),
#  ('2814-clean.txt', 67560),
#  ('2852-clean.txt', 59122),
#  ('28520-clean.txt', 32090),
#  ('30360-clean.txt', 260892),
#  ('30601-clean.txt', 60458),
#  ('3207-clean.txt', 213339),
#  ('33-clean.txt', 83620),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 161380),
#  ('34901-clean.txt', 52040),
#  ('35-clean.txt', 32306),
#  ('36-clean.txt', 59973),
#  ('3600-clean.txt', 525860),
#  ('38427-clean.txt', 200563),
#  ('408-clean.txt', 68689),
#  ('41-clean.txt', 12214),
#  ('42-clean.txt', 25740),
#  ('4300-clean.txt', 264936),
#  ('4363-clean.txt', 62655),
#  ('45-clean.txt', 102520),
#  ('4517-clean.txt', 34712),
#  ('46-clean.txt', 28541),
#  ('514-clean.txt', 186061),
#  ('5200-clean.txt', 22099),
#  ('521-clean.txt', 120826),
#  ('526-clean.txt', 38122),
#  ('55-clean.txt', 39588),
#  ('55387-clean.txt', 21463),
#  ('55404-clean.txt', 91629),
#  ('6130-clean.txt', 189451),
#  ('730-clean.txt', 157981),
#  ('7370-clean.txt', 56563),
#  ('74-clean.txt', 70801),
#  ('76-clean.txt', 111217),
#  ('768-clean.txt', 115911),
#  ('829-clean.txt', 104294),
#  ('84-clean.txt', 74960),
#  ('844-clean.txt', 20733),
#  ('851-clean.txt', 20204),
#  ('863-clean.txt', 56543),
#  ('8800-clean.txt', 108517),
#  ('932-clean.txt', 7065),
#  ('98-clean.txt', 135842),
#  ('996-clean.txt', 425901)]

# %% [markdown]
# Average number of tokens per book

# %%
int(np.mean([len(book) for book in all_transf_books_lst]))
# Out:
# 132124

# %% [markdown]
# Make a dictionary - a count of the number of times each word appears in each book

# %%
dictionary = corpora.Dictionary(all_transf_books_lst)

# %% [markdown]
# Confirm: yup, it's got words in it

# %%
dictionary[0], dictionary[10], dictionary[1000], dictionary[100000]
# Out:
# (u'', u'mozah', u'tookest', u'shastras')

# %%
type(dictionary)
# Out:
# gensim.corpora.dictionary.Dictionary

# %% [markdown]
# I'd be interested to see this as pandas dataframe - but this doesn't work

# %%
#df = pd.DataFrame(dictionary)
#df.head()

# %% [markdown]
# How many words in this dictionary?

# %%
len(dictionary)
# Out:
# 195104

# %% [markdown]
# Do the contents look right?

# %%
print(dictionary)
# Out:
# Dictionary(195104 unique tokens: [u'', u'biennials', u'lenitives', u'unsupportable', u'nunnery']...)

# %% [markdown]
# Save out the dictionary

# %%
outputs_dir = '/Users/rachelbrynsvold/dsi/capstone_dir/top_100_dev_corp/outputs/'

# %%
filename = 'tokenized.dict'

dictionary.save(outputs_dir + filename)

# %%
zip(fileid_lst, [len(dictionary.doc2bow(book)) for book in all_transf_books_lst])
# Out:
# [('10-clean.txt', 17331),
#  ('100-clean.txt', 28919),
#  ('105-clean.txt', 6046),
#  ('108-clean.txt', 8707),
#  ('1080-clean.txt', 1087),
#  ('11-clean.txt', 2780),
#  ('1112-clean.txt', 3821),
#  ('1184-clean.txt', 26118),
#  ('12-clean.txt', 3097),
#  ('120-clean.txt', 6603),
#  ('1232-clean.txt', 5284),
#  ('1260-clean.txt', 14991),
#  ('1322-clean.txt', 14721),
#  ('1342-clean.txt', 6842),
#  ('135-clean.txt', 26112),
#  ('1399-clean.txt', 14473),
#  ('140-clean.txt', 11656),
#  ('1400-clean.txt', 12334),
#  ('1404-clean.txt', 8954),
#  ('14264-clean.txt', 5571),
#  ('147-clean.txt', 3595),
#  ('1497-clean.txt', 11362),
#  ('15399-clean.txt', 7436),
#  ('158-clean.txt', 10057),
#  ('16-clean.txt', 5026),
#  ('160-clean.txt', 7204),
#  ('161-clean.txt', 7509),
#  ('16382-clean.txt', 11299),
#  ('1661-clean.txt', 8459),
#  ('1727-clean.txt', 8066),
#  ('174-clean.txt', 7324),
#  ('1952-yellow_wallpaper-clean.txt', 1270),
#  ('19942-clean.txt', 5207),
#  ('20-clean.txt', 10237),
#  ('20203-clean.txt', 8300),
#  ('203-clean.txt', 13909),
#  ('205-clean.txt', 11930),
#  ('21279-clean.txt', 839),
#  ('2148-clean.txt', 11743),
#  ('2174-clean.txt', 3685),
#  ('219-clean.txt', 6024),
#  ('224-clean.txt', 11724),
#  ('23-clean.txt', 5394),
#  ('236-clean.txt', 5125),
#  ('2500-clean.txt', 3666),
#  ('25305-clean.txt', 8226),
#  ('2591-clean.txt', 5054),
#  ('2600-clean.txt', 25635),
#  ('2680-clean.txt', 6370),
#  ('2701-moby-clean.txt', 20244),
#  ('28054-clean.txt', 13684),
#  ('2814-clean.txt', 8688),
#  ('2852-clean.txt', 5838),
#  ('28520-clean.txt', 3631),
#  ('30360-clean.txt', 12374),
#  ('30601-clean.txt', 6910),
#  ('3207-clean.txt', 10055),
#  ('33-clean.txt', 9687),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10633),
#  ('34901-clean.txt', 5886),
#  ('35-clean.txt', 4814),
#  ('36-clean.txt', 7153),
#  ('3600-clean.txt', 27588),
#  ('38427-clean.txt', 10638),
#  ('408-clean.txt', 9327),
#  ('41-clean.txt', 3234),
#  ('42-clean.txt', 4176),
#  ('4300-clean.txt', 30767),
#  ('4363-clean.txt', 9280),
#  ('45-clean.txt', 8278),
#  ('4517-clean.txt', 4755),
#  ('46-clean.txt', 4459),
#  ('514-clean.txt', 11344),
#  ('5200-clean.txt', 2631),
#  ('521-clean.txt', 6553),
#  ('526-clean.txt', 6038),
#  ('55-clean.txt', 2996),
#  ('55387-clean.txt', 3164),
#  ('55404-clean.txt', 9243),
#  ('6130-clean.txt', 14263),
#  ('730-clean.txt', 11424),
#  ('7370-clean.txt', 4753),
#  ('74-clean.txt', 8378),
#  ('76-clean.txt', 7584),
#  ('768-clean.txt', 10220),
#  ('829-clean.txt', 8411),
#  ('84-clean.txt', 7203),
#  ('844-clean.txt', 2699),
#  ('851-clean.txt', 2355),
#  ('863-clean.txt', 5774),
#  ('8800-clean.txt', 11335),
#  ('932-clean.txt', 2124),
#  ('98-clean.txt', 10803),
#  ('996-clean.txt', 16872)]

# %% [markdown]
# Make a corpus!

# %%
corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]

# %% [markdown]
# Check that it has all the books

# %%
len(corpus)
# Out:
# 95

# %% [markdown]
# View it as a dataframe

# %%
df = pd.DataFrame(corpus)
df.head()
# Out:
#       0        1         2         3         4          5         6      \
# 0    (0, 3)   (1, 4)    (2, 1)    (3, 1)    (4, 1)     (5, 1)    (6, 1)
# 1  (0, 324)  (8, 28)  (9, 148)  (13, 38)  (15, 28)   (18, 28)  (21, 29)
# 2    (0, 1)  (9, 14)   (13, 3)   (18, 5)   (21, 2)    (23, 9)   (32, 1)
# 3   (0, 22)   (8, 7)   (9, 15)   (13, 7)   (21, 3)   (23, 41)   (44, 3)
# 4    (9, 5)  (23, 1)   (57, 2)   (98, 4)  (132, 1)  (154, 10)  (155, 1)
#
#         7         8         9      ...  30757 30758 30759 30760 30761 30762  \
# 0      (7, 1)    (8, 4)  (9, 328)  ...   None  None  None  None  None  None
# 1  (23, 3059)   (25, 3)   (26, 1)  ...   None  None  None  None  None  None
# 2    (44, 12)   (48, 2)   (57, 3)  ...   None  None  None  None  None  None
# 3     (47, 1)   (48, 2)   (55, 4)  ...   None  None  None  None  None  None
# 4    (205, 5)  (213, 1)  (215, 4)  ...   None  None  None  None  None  None
#
#   30763 30764 30765 30766
# 0  None  None  None  None
# 1  None  None  None  None
# 2  None  None  None  None
# 3  None  None  None  None
# 4  None  None  None  None
#
# [5 rows x 30767 columns]

# %% [markdown]
# Why doesn't it have the same number of cols as the lenght of the dictionary...

# %%
#check same process with 1 book - see how dict/corp/df size differ

# %% [markdown]
# Number of unique words in each book

# %%
unique_toks_num_lst = [len(book) for book in corpus]
unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)

unique_toks_per_fileid
# Out:
# [('10-clean.txt', 17331),
#  ('100-clean.txt', 28919),
#  ('105-clean.txt', 6046),
#  ('108-clean.txt', 8707),
#  ('1080-clean.txt', 1087),
#  ('11-clean.txt', 2780),
#  ('1112-clean.txt', 3821),
#  ('1184-clean.txt', 26118),
#  ('12-clean.txt', 3097),
#  ('120-clean.txt', 6603),
#  ('1232-clean.txt', 5284),
#  ('1260-clean.txt', 14991),
#  ('1322-clean.txt', 14721),
#  ('1342-clean.txt', 6842),
#  ('135-clean.txt', 26112),
#  ('1399-clean.txt', 14473),
#  ('140-clean.txt', 11656),
#  ('1400-clean.txt', 12334),
#  ('1404-clean.txt', 8954),
#  ('14264-clean.txt', 5571),
#  ('147-clean.txt', 3595),
#  ('1497-clean.txt', 11362),
#  ('15399-clean.txt', 7436),
#  ('158-clean.txt', 10057),
#  ('16-clean.txt', 5026),
#  ('160-clean.txt', 7204),
#  ('161-clean.txt', 7509),
#  ('16382-clean.txt', 11299),
#  ('1661-clean.txt', 8459),
#  ('1727-clean.txt', 8066),
#  ('174-clean.txt', 7324),
#  ('1952-yellow_wallpaper-clean.txt', 1270),
#  ('19942-clean.txt', 5207),
#  ('20-clean.txt', 10237),
#  ('20203-clean.txt', 8300),
#  ('203-clean.txt', 13909),
#  ('205-clean.txt', 11930),
#  ('21279-clean.txt', 839),
#  ('2148-clean.txt', 11743),
#  ('2174-clean.txt', 3685),
#  ('219-clean.txt', 6024),
#  ('224-clean.txt', 11724),
#  ('23-clean.txt', 5394),
#  ('236-clean.txt', 5125),
#  ('2500-clean.txt', 3666),
#  ('25305-clean.txt', 8226),
#  ('2591-clean.txt', 5054),
#  ('2600-clean.txt', 25635),
#  ('2680-clean.txt', 6370),
#  ('2701-moby-clean.txt', 20244),
#  ('28054-clean.txt', 13684),
#  ('2814-clean.txt', 8688),
#  ('2852-clean.txt', 5838),
#  ('28520-clean.txt', 3631),
#  ('30360-clean.txt', 12374),
#  ('30601-clean.txt', 6910),
#  ('3207-clean.txt', 10055),
#  ('33-clean.txt', 9687),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10633),
#  ('34901-clean.txt', 5886),
#  ('35-clean.txt', 4814),
#  ('36-clean.txt', 7153),
#  ('3600-clean.txt', 27588),
#  ('38427-clean.txt', 10638),
#  ('408-clean.txt', 9327),
#  ('41-clean.txt', 3234),
#  ('42-clean.txt', 4176),
#  ('4300-clean.txt', 30767),
#  ('4363-clean.txt', 9280),
#  ('45-clean.txt', 8278),
#  ('4517-clean.txt', 4755),
#  ('46-clean.txt', 4459),
#  ('514-clean.txt', 11344),
#  ('5200-clean.txt', 2631),
#  ('521-clean.txt', 6553),
#  ('526-clean.txt', 6038),
#  ('55-clean.txt', 2996),
#  ('55387-clean.txt', 3164),
#  ('55404-clean.txt', 9243),
#  ('6130-clean.txt', 14263),
#  ('730-clean.txt', 11424),
#  ('7370-clean.txt', 4753),
#  ('74-clean.txt', 8378),
#  ('76-clean.txt', 7584),
#  ('768-clean.txt', 10220),
#  ('829-clean.txt', 8411),
#  ('84-clean.txt', 7203),
#  ('844-clean.txt', 2699),
#  ('851-clean.txt', 2355),
#  ('863-clean.txt', 5774),
#  ('8800-clean.txt', 11335),
#  ('932-clean.txt', 2124),
#  ('98-clean.txt', 10803),
#  ('996-clean.txt', 16872)]

# %% [markdown]
# Average unique words per book

# %%
avg_unique_toks = int(np.mean(unique_toks_num_lst))
avg_unique_toks
# Out:
# 9004

# %% [markdown]
# Save out the corpus

# %%
filename = 'tokenized_corpus.mm'

corpora.MmCorpus.serialize(outputs_dir + filename, corpus)

# %% [markdown]
# ## EDA and Saving helper funtions
#
# To automate next few EDA rounds

# %%
def eda(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, outputs_dir='/Users/rachelbrynsvold/dsi/capstone_dir/top_100_dev_corp/outputs/'):
    '''
    Save the outputs of the most recent eda step
    '''
    dictionary.save(outputs_dir + distinguishing_str + '.dict')
    corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)

# %% [markdown]
# ### EDA items
# * List of book lengths (total num of tokens for each book)
# * Average number of tokens per book
# * Number of words in corpus (dictionary length)
#     * Dictionary (not viewed)
# * Unique tokens per book
# * Average number of unique tokens per book
#     * Corpus (not viewe)
#
# Save everything after eda step

# %% [markdown]
# ### To summarize the 'simple tokenization' EDA step (#1):

# %%
output_v1 = eda(transform_txt_file_v1)

# %%
book_lengths1, avg_num_tokens1, dictionary1, dictionary_length1, unique_toks_per_fileid1, \
    avg_unique_toks1, corpus1 = output_v1

# %%
print "Average number of tokens in a book: ", avg_num_tokens1
print "   "
print "Average unique tokens in a book: ", avg_unique_toks1
print "   "1
print "Total number of words (dictionary length): ", dictionary_length
# Out:
# Average number of tokens in a book:  132124
#
# Average unique tokens in a book:  9004
#
# Total number of words (dictionary length):  195104

# %%
##for pres, note the sparcity problem - 9000 vs. 195k == 186k empty

# %%
book_lengths1
# Out:
# [('10-clean.txt', 821133),
#  ('100-clean.txt', 883320),
#  ('105-clean.txt', 83286),
#  ('108-clean.txt', 112139),
#  ('1080-clean.txt', 3410),
#  ('11-clean.txt', 26449),
#  ('1112-clean.txt', 25898),
#  ('1184-clean.txt', 461184),
#  ('12-clean.txt', 29293),
#  ('120-clean.txt', 68589),
#  ('1232-clean.txt', 49612),
#  ('1260-clean.txt', 185468),
#  ('1322-clean.txt', 121712),
#  ('1342-clean.txt', 121567),
#  ('135-clean.txt', 565761),
#  ('1399-clean.txt', 349978),
#  ('140-clean.txt', 149124),
#  ('1400-clean.txt', 184403),
#  ('1404-clean.txt', 192349),
#  ('14264-clean.txt', 76656),
#  ('147-clean.txt', 21997),
#  ('1497-clean.txt', 216243),
#  ('15399-clean.txt', 82564),
#  ('158-clean.txt', 157441),
#  ('16-clean.txt', 47439),
#  ('160-clean.txt', 63992),
#  ('161-clean.txt', 118580),
#  ('16382-clean.txt', 135922),
#  ('1661-clean.txt', 104493),
#  ('1727-clean.txt', 129410),
#  ('174-clean.txt', 78934),
#  ('1952-yellow_wallpaper-clean.txt', 6067),
#  ('19942-clean.txt', 35861),
#  ('20-clean.txt', 80059),
#  ('20203-clean.txt', 76167),
u'down', u'mightn', u'wasn', u'your', u'from', u'her', u'their', u'aren', u'there', u'been', u'whom', u'too', u'wouldn', u'themselves', u'weren', u'was', u'until', u'more', u'himself', u'that', u'but', u'don', u'with', u'than', u'those', u'he', u'me', u'myself', u'ma', u'these', u'up', u'will', u'below', u'ain', u'can', u'theirs', u'my', u'and', u've', u'then', u'is', u'am', u'it', u'doesn', u'an', u'as', u'itself', u'at', u'have', u'in', u'any', u'if', u'again', u'no', u'when', u'same', u'how', u'other', u'which', u'you', u'shan', u'needn', u'haven', u'after', u'most', u'such', u'why', u'a', u'off', u'i', u'm', u'yours', u'so', u'y', u'the', u'having', u'once'])

# %%
def transform_txt_file_v2(fname, root=source_dir, stop_words=stop):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Assumes you want to remove empty lines and tokenize (because you do)
    '''
    fp = root + fname
    book_as_lst = []
    for line in IterFile(fp):
        
        if empty_line_check(line) == False:
            line = basic_tokenize(line)
            
            if stop_words !=None:
                line = remove_stop_words(line, stop_words)
        
        book_as_lst.extend(line)
        
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty
    
def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]    
            
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
output_v2 = eda(transform_txt_file_v2)

# %%
book_lengths2, avg_num_tokens2, dictionary2, dictionary_length2, \
    unique_toks_per_fileid2, avg_unique_toks2, corpus2 = output_v2

# %%
print "Average number of tokens in a book: ", avg_num_tokens2
print "   "
print "Average unique tokens in a book: ", avg_unique_toks2
print "   "
print "Total number of words (dictionary length): ", dictionary_length2
# Out:
# Average number of tokens in a book:  66904
#
# Average unique tokens in a book:  8882
#
# Total number of words (dictionary length):  194961

# %%
#make graph of reduction

# %%
book_lengths2
# Out:
# [('10-clean.txt', 431250),
#  ('100-clean.txt', 481608),
#  ('105-clean.txt', 39320),
#  ('108-clean.txt', 54072),
#  ('1080-clean.txt', 1739),
#  ('11-clean.txt', 13616),
#  ('1112-clean.txt', 15468),
#  ('1184-clean.txt', 251348),
#  ('12-clean.txt', 15589),
#  ('120-clean.txt', 34581),
#  ('1232-clean.txt', 23021),
#  ('1260-clean.txt', 91946),
#  ('1322-clean.txt', 67400),
#  ('1342-clean.txt', 57307),
#  ('135-clean.txt', 288377),
#  ('1399-clean.txt', 173226),
#  ('140-clean.txt', 70693),
#  ('1400-clean.txt', 87450),
#  ('1404-clean.txt', 91284),
#  ('14264-clean.txt', 38978),
#  ('147-clean.txt', 10640),
#  ('1497-clean.txt', 98946),
#  ('15399-clean.txt', 38240),
#  ('158-clean.txt', 75454),
#  ('16-clean.txt', 23919),
#  ('160-clean.txt', 32962),
#  ('161-clean.txt', 56016),
#  ('16382-clean.txt', 71067),
#  ('1661-clean.txt', 49411),
#  ('1727-clean.txt', 59474),
#  ('174-clean.txt', 38744),
#  ('158-clean.txt', 9933),
#  ('16-clean.txt', 4902),
#  ('160-clean.txt', 7080),
#  ('161-clean.txt', 7387),
#  ('16382-clean.txt', 11174),
#  ('1661-clean.txt', 8332),
#  ('1727-clean.txt', 7939),
#  ('174-clean.txt', 7202),
#  ('1952-yellow_wallpaper-clean.txt', 1164),
#  ('19942-clean.txt', 5078),
#  ('20-clean.txt', 10120),
#  ('20203-clean.txt', 8169),
#  ('203-clean.txt', 13780),
#  ('205-clean.txt', 11802),
#  ('21279-clean.txt', 746),
#  ('2148-clean.txt', 11617),
#  ('2174-clean.txt', 3674),
#  ('219-clean.txt', 5903),
#  ('224-clean.txt', 11595),
#  ('23-clean.txt', 5273),
#  ('236-clean.txt', 5004),
#  ('2500-clean.txt', 3546),
#  ('25305-clean.txt', 8100),
#  ('2591-clean.txt', 4932),
#  ('2600-clean.txt', 25501),
#  ('2680-clean.txt', 6243),
#  ('2701-moby-clean.txt', 20117),
#  ('28054-clean.txt', 13556),
#  ('2814-clean.txt', 8562),
#  ('2852-clean.txt', 5714),
#  ('28520-clean.txt', 3507),
#  ('30360-clean.txt', 12243),
#  ('30601-clean.txt', 6784),
#  ('3207-clean.txt', 9933),
#  ('33-clean.txt', 9561),
#  ('33283-clean.txt', 0),
#  ('345-clean.txt', 10503),
#  ('34901-clean.txt', 5767),
#  ('35-clean.txt', 4693),
#  ('36-clean.txt', 7032),
#  ('3600-clean.txt', 27455),
#  ('38427-clean.txt', 10513),
#  ('408-clean.txt', 9202),
#  ('41-clean.txt', 3120),
#  ('42-clean.txt', 4053),
#  ('4300-clean.txt', 30633),
#  ('4363-clean.txt', 9158),
#  ('45-clean.txt', 8152),
#  ('4517-clean.txt', 4634),
#  ('46-clean.txt', 4340),
#  ('514-clean.txt', 11214),
#  ('5200-clean.txt', 2514),
#  ('521-clean.txt', 6430),
#  ('526-clean.txt', 5917),
#  ('55-clean.txt', 2877),
#  ('55387-clean.txt', 3037),
#  ('55404-clean.txt', 9117),
#  ('6130-clean.txt', 14134),
#  ('730-clean.txt', 11299),
#  ('7370-clean.txt', 4634),
#  ('74-clean.txt', 8250),
#  ('76-clean.txt', 7448),
#  ('768-clean.txt', 10092),
#  ('829-clean.txt', 8286),
#  ('84-clean.txt', 7077),
#  ('844-clean.txt', 2581),
#  ('851-clean.txt', 2238),
#  ('863-clean.txt', 5646),
#  ('8800-clean.txt', 11206),
#  ('932-clean.txt', 2013),
#  ('98-clean.txt', 10675),
#  ('996-clean.txt', 16742)]

# %%
save_stuff('no_stopwords')

# %% [markdown]
# ## EDA Step 3: + lemmatization

# %%
from gensim.utils import lemmatize

# %%
def transform_txt_file_v3(fname, root=source_dir, stop_words=stop, \
                         lemma = True):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Assumes you want to remove empty lines and tokenize (because you do)
    '''
    fp = root + fname
    book_as_lst = []
    for line in IterFile(fp):
        
        if empty_line_check(line) == False:
            
            
            if lemma == True:
                line = lemmatize(line)
            
            else:
                line = basic_tokenize(line)
                
                if stop_words !=None:
                    line = remove_stop_words(line, stop_words)
        
            book_as_lst.extend(line)
    
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty

def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
           
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
transform_txt_file_v3(usher)
# Out:
# ['fall/NN',
#  'house/NN',
#  'usher/NN',
#  'son/NN',
#  'coeur/NN',
#  'luth/NN',
#  'suspendu/NN',
#  'sitot/NN',
#  'qu/NN',
#  'le/NN',
#  'touche/NN',
#  'il/NN',
#  'resonne/NN',
#  'beranger/JJ',
#  'whole/NN',
#  'dull/JJ',
#  'dark/NN',
#  'soundless/NN',
#  'day/NN',
#  'autumn/NN',
#  'year/NN',
#  'cloud/NN',
#  'hung/JJ',
#  'oppressively/RB',
#  'low/JJ',
#  'heaven/NN',
#  'have/VB',
#  'be/VB',
#  'pass/VB',
#  'alone/RB',
#  'horseback/NN',
#  'singularly/RB',
#  'dreary/JJ',
#  'tract/NN',
#  'country/NN',
#  'length/NN',
#  'find/VB',
#  'shade/NN',
#  'evening/NN',
#  'draw/VB',
#  'view/NN',
#  'melancholy/NN',
#  'house/NN',
#  'usher/NN',
#  'know/VB',
#  'not/RB',
#  'be/VB',
#  'first/JJ',
#  'glimpse/NN',
#  'build/VB',
#  'sense/NN',
#  'insufferable/JJ',
#  'gloom/NN',
#  'pervade/VB',
#  'spirit/NN',
#  'say/VB',
#  'insufferable/JJ',
#  'feeling/NN',
#  'be/VB',
#  'unrelieved/JJ',
#  'half/NN',
#  'pleasureable/NN',
#  'poetic/JJ',
#  'sentiment/NN',
#  'mind/NN',
#  'usually/RB',
#  'receive/VB',
#  'even/RB',
#  'sternest/NN',
#  'natural/JJ',
#  'image/NN',
#  'desolate/JJ',
#  'terrible/JJ',
#  'look/VB',
#  'scene/NN',
#  'mere/JJ',
#  'house/NN',
#  'simple/JJ',
#  'landscape/NN',
#  'feature/NN',
#  'domain/NN',
#  'bleak/JJ',
#  'wall/NN',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'few/JJ',
#  'rank/NN',
#  'sedge/NN',
#  'few/JJ',
#  'white/NN',
#  'trunk/NN',
#  'decayed/JJ',
#  'tree/NN',
#  'utter/JJ',
#  'depression/NN',
#  'soul/NN',
#  'compare/VB',
#  'earthly/JJ',
#  'sensation/NN',
#  'more/RB',
#  'properly/RB',
#  'dream/NN',
#  'reveller/JJ',
#  'opium/NN',
#  'bitter/JJ',
#  'lapse/NN',
#  'everyday/JJ',
#  'life/NN',
#  'hideous/JJ',
#  'drop/VB',
#  'veil/NN',
#  'be/VB',
#  'iciness/NN',
#  'sink/VB',
#  'sickening/JJ',
#  'heart/NN',
#  'unredeemed/JJ',
#  'dreariness/NN',
#  'thought/NN',
#  'goading/NN',
#  'imagination/NN',
#  'torture/NN',
#  'aught/NN',
#  'sublime/JJ',
#  'be/VB',
#  'pause/VB',
#  'think/VB',
#  'be/VB',
#  'so/RB',
#  'unnerved/JJ',
#  'contemplation/NN',
#  'house/NN',
#  'usher/NN',
#  'be/VB',
#  'mystery/NN',
#  'insoluble/JJ',
#  'grapple/VB',
#  'shadowy/JJ',
#  'fancy/VB',
#  'crowd/VB',
#  'ponder/VB',
#  'be/VB',
#  'force/VB',
#  'fall/VB',
#  'back/RB',
#  'unsatisfactory/JJ',
#  'conclusion/NN',
#  'doubt/NN',
#  'be/VB',
#  'combination/NN',
#  'very/RB',
#  'simple/JJ',
#  'natural/JJ',
#  'object/NN',
#  'have/VB',
#  'power/NN',
#  'thus/RB',
#  'affect/VB',
#  'still/RB',
#  'analysis/NN',
#  'power/NN',
#  'lie/VB',
#  'consideration/NN',
#  'depth/NN',
#  'be/VB',
#  'possible/JJ',
#  'reflect/VB',
#  'mere/JJ',
#  'different/JJ',
#  'arrangement/NN',
#  'particular/NN',
#  'scene/NN',
#  'detail/NN',
#  'picture/NN',
#  'be/VB',
#  'sufficient/JJ',
#  'modify/VB',
#  'perhaps/RB',
#  'annihilate/VB',
#  'capacity/NN',
#  'sorrowful/JJ',
#  'impression/NN',
#  'act/VB',
#  'idea/NN',
#  'rein/VB',
#  'horse/NN',
#  'precipitous/JJ',
#  'brink/NN',
#  'black/JJ',
#  'lurid/JJ',
#  'tarn/NN',
#  'lay/VB',
#  'unruffled/JJ',
#  'lustre/NN',
#  'dwelling/NN',
#  'gaze/VB',
#  'down/RB',
#  'shudder/VB',
#  'even/RB',
#  'more/RB',
#  'thrilling/JJ',
#  'before/RB',
#  'remodelled/JJ',
#  'inverted/JJ',
#  'image/NN',
#  'grey/JJ',
#  'sedge/NN',
#  'ghastly/JJ',
#  'tree/NN',
#  'stem/VB',
#  'vacant/JJ',
#  'eye/NN',
#  'window/NN',
#  'nevertheless/RB',
#  'mansion/NN',
#  'gloom/NN',
#  'now/RB',
#  'propose/VB',
#  'sojourn/NN',
#  'week/NN',
#  'proprietor/NN',
#  'roderick/NN',
#  'usher/NN',
#  'have/VB',
#  'be/VB',
#  'boon/NN',
#  'companion/NN',
#  'boyhood/NN',
#  'many/JJ',
#  'year/NN',
#  'have/VB',
#  'elapse/VB',
#  'last/JJ',
#  'meeting/NN',
#  'letter/NN',
#  'however/RB',
#  'have/VB',
#  'lately/RB',
#  'reach/VB',
#  'distant/JJ',
#  'part/NN',
#  'country/NN',
#  'letter/NN',
#  'wildly/RB',
#  'importunate/JJ',
#  'nature/NN',
#  'have/VB',
#  'admit/VB',
#  'other/JJ',
#  'personal/JJ',
#  'reply/NN',
#  'ms/NN',
#  'give/VB',
#  'evidence/NN',
#  'nervous/JJ',
#  'agitation/NN',
#  'writer/NN',
#  'speak/VB',
#  'acute/JJ',
#  'bodily/JJ',
#  'illness/NN',
#  'mental/JJ',
#  'disorder/NN',
#  'oppressed/JJ',
#  'earnest/JJ',
#  'desire/NN',
#  'see/VB',
#  'best/NN',
#  'indeed/RB',
#  'only/JJ',
#  'personal/JJ',
#  'friend/NN',
#  'view/NN',
#  'attempt/VB',
#  'cheerfulness/NN',
#  'society/NN',
#  'alleviation/NN',
#  'malady/NN',
#  'be/VB',
#  'manner/NN',
#  'much/JJ',
#  'more/RB',
#  'be/VB',
#  'say/VB',
#  'be/VB',
#  'apparent/JJ',
#  'heart/NN',
#  'go/VB',
#  'request/NN',
#  'allow/VB',
#  'room/NN',
#  'hesitation/NN',
#  'accordingly/RB',
#  'obey/VB',
#  'forthwith/RB',
#  'still/RB',
#  'consider/VB',
#  'very/RB',
#  'singular/JJ',
#  'summons/NN',
#  'boy/NN',
#  'have/VB',
#  'be/VB',
#  'even/RB',
#  'intimate/JJ',
#  'associate/NN',
#  'yet/RB',
#  'really/RB',
#  'know/VB',
#  'little/JJ',
#  'friend/NN',
#  'reserve/NN',
#  'have/VB',
#  'be/VB',
#  'always/RB',
#  'excessive/JJ',
#  'habitual/JJ',
#  'be/VB',
#  'aware/JJ',
#  'however/RB',
#  'very/RB',
#  'ancient/JJ',
#  'family/NN',
#  'have/VB',
#  'be/VB',
#  'note/VB',
#  'time/NN',
#  'mind/NN',
#  'peculiar/JJ',
#  'sensibility/NN',
#  'temperament/NN',
#  'display/VB',
#  'long/JJ',
#  'age/NN',
#  'many/JJ',
#  'work/NN',
#  'exalted/JJ',
#  'art/NN',
#  'manifest/VB',
#  'late/JJ',
#  'repeated/JJ',
#  'deed/NN',
#  'munificent/NN',
#  'yet/RB',
#  'unobtrusive/JJ',
#  'charity/NN',
#  'as/RB',
#  'well/RB',
#  'passionate/JJ',
#  'devotion/NN',
#  'intricacy/NN',
#  'perhaps/RB',
#  'even/RB',
#  'more/RB',
#  'orthodox/JJ',
#  'easily/RB',
#  'recognisable/JJ',
#  'beauty/NN',
#  'musical/JJ',
#  'science/NN',
#  'have/VB',
#  'learn/VB',
#  'too/RB',
#  'very/RB',
#  'remarkable/JJ',
#  'fact/NN',
#  'stem/NN',
#  'usher/NN',
#  'race/NN',
#  'time/NN',
#  'honour/VB',
#  'be/VB',
#  'have/VB',
#  'put/VB',
#  'forth/RB',
#  'period/NN',
#  'enduring/JJ',
#  'branch/NN',
#  'other/JJ',
#  'word/NN',
#  'entire/JJ',
#  'family/NN',
#  'lay/VB',
#  'direct/JJ',
#  'line/NN',
#  'descent/NN',
#  'have/VB',
#  'always/RB',
#  'very/RB',
#  'trifling/JJ',
#  'very/RB',
#  'temporary/JJ',
#  'variation/NN',
#  'so/RB',
#  'lain/VB',
#  'be/VB',
#  'deficiency/NN',
#  'consider/VB',
#  'run/VB',
#  'think/VB',
#  'perfect/JJ',
#  'keep/VB',
#  'character/NN',
#  'premise/NN',
#  'accredit/VB',
#  'character/NN',
#  'person/NN',
#  'speculate/VB',
#  'possible/JJ',
#  'influence/NN',
#  'long/JJ',
#  'lapse/NN',
#  'century/NN',
#  'have/VB',
#  'exercise/VB',
#  'other/JJ',
#  'be/VB',
#  'deficiency/NN',
#  'perhaps/RB',
#  'collateral/NN',
#  'issue/NN',
#  'consequent/JJ',
#  'undeviat/VB',
#  'transmission/NN',
#  'sire/NN',
#  'son/NN',
#  'patrimony/NN',
#  'name/NN',
#  'have/VB',
#  'length/NN',
#  'so/VB',
#  'identify/VB',
#  'merge/VB',
#  'original/JJ',
#  'title/NN',
#  'estate/NN',
#  'quaint/JJ',
#  'equivocal/JJ',
#  'appellation/NN',
#  'house/NN',
#  'usher/NN',
#  'appellation/NN',
#  'seem/VB',
#  'include/VB',
#  'mind/NN',
#  'peasantry/NN',
#  'used/VB',
#  'family/NN',
#  'family/NN',
#  'mansion/NN',
#  'have/VB',
#  'say/VB',
#  'sole/JJ',
#  'effect/NN',
#  'somewhat/RB',
#  'childish/JJ',
#  'experiment/NN',
#  'look/VB',
#  'tarn/NN',
#  'have/VB',
#  'be/VB',
#  'deepen/VB',
#  'first/JJ',
#  'singular/JJ',
#  'impression/NN',
#  'be/VB',
#  'doubt/NN',
#  'consciousness/NN',
#  'rapid/JJ',
#  'increase/NN',
#  'superstition/NN',
#  'not/RB',
#  'term/NN',
#  'serve/VB',
#  'mainly/RB',
#  'accelerate/VB',
#  'increase/VB',
#  'such/JJ',
#  'have/VB',
#  'long/RB',
#  'know/VB',
#  'be/VB',
#  'paradoxical/JJ',
#  'law/NN',
#  'sentiment/NN',
#  'have/VB',
#  'terror/NN',
#  'basis/NN',
#  'have/VB',
#  'be/VB',
#  'reason/NN',
#  'only/RB',
#  'again/RB',
#  'uplift/VB',
#  'eye/NN',
#  'house/NN',
#  'image/NN',
#  'pool/NN',
#  'grow/VB',
#  'mind/VB',
#  'strange/JJ',
#  'fancy/NN',
#  'fancy/NN',
#  'so/RB',
#  'ridiculous/JJ',
#  'indeed/RB',
#  'mention/NN',
#  'show/VB',
#  'vivid/JJ',
#  'force/NN',
#  'sensation/NN',
#  'oppressed/JJ',
#  'have/VB',
#  'so/RB',
#  'work/VB',
#  'imagination/NN',
#  'really/RB',
#  'believe/VB',
#  'whole/JJ',
#  'mansion/NN',
#  'domain/NN',
#  'there/RB',
#  'hang/VB',
#  'atmosphere/NN',
#  'peculiar/JJ',
#  'immediate/JJ',
#  'vicinity/NN',
#  'atmosphere/NN',
#  'have/VB',
#  'affinity/NN',
#  'air/NN',
#  'heaven/NN',
#  'have/VB',
#  'reek/VB',
#  'decayed/JJ',
#  'tree/NN',
#  'grey/JJ',
#  'wall/NN',
#  'silent/JJ',
#  'tarn/NN',
#  'pestilent/JJ',
#  'mystic/JJ',
#  'vapour/NN',
#  'dull/JJ',
#  'sluggish/JJ',
#  'faintly/RB',
#  'discernible/JJ',
#  'leaden/JJ',
#  'hued/NN',
#  'shake/VB',
#  'spirit/NN',
#  'have/VB',
#  'be/VB',
#  'dream/NN',
#  'scan/VB',
#  'more/RB',
#  'narrowly/RB',
#  'real/JJ',
#  'aspect/NN',
#  'build/VB',
#  'principal/JJ',
#  'feature/NN',
#  'seem/VB',
#  'be/VB',
#  'excessive/JJ',
#  'antiquity/NN',
#  'discoloration/NN',
#  'age/NN',
#  'have/VB',
#  'be/VB',
#  'great/JJ',
#  'minute/NN',
#  'fungi/NN',
#  'overspread/VB',
#  'whole/JJ',
#  'exterior/JJ',
#  'hanging/NN',
#  'fine/NN',
#  'tangled/JJ',
#  'web/NN',
#  'work/NN',
#  'eave/NN',
#  'yet/RB',
#  'be/VB',
#  'apart/RB',
#  'extraordinary/JJ',
#  'dilapidation/NN',
#  'portion/NN',
#  'masonry/NN',
#  'have/VB',
#  'fall/VB',
#  'there/RB',
#  'appear/VB',
#  'be/VB',
#  'wild/JJ',
#  'inconsistency/NN',
#  'still/RB',
#  'perfect/JJ',
#  'adaptation/NN',
#  'part/NN',
#  'crumble/VB',
#  'condition/NN',
#  'individual/JJ',
#  'stone/NN',
#  'be/VB',
#  'much/JJ',
#  'remind/VB',
#  'specious/JJ',
#  'totality/NN',
#  'old/JJ',
#  'wood/NN',
#  'work/NN',
#  'have/VB',
#  'rot/VB',
#  'long/JJ',
#  'year/NN',
#  'neglected/JJ',
#  'vault/NN',
#  'disturbance/NN',
#  'breath/NN',
#  'external/JJ',
#  'air/NN',
#  'indication/NN',
#  'extensive/JJ',
#  'decay/NN',
#  'however/RB',
#  'fabric/NN',
#  'give/VB',
#  'little/JJ',
#  'token/JJ',
#  'instability/NN',
#  'perhaps/RB',
#  'eye/NN',
#  'scrutinize/VB',
#  'observer/NN',
#  'have/VB',
#  'discover/VB',
#  'barely/RB',
#  'perceptible/JJ',
#  'fissure/NN',
#  'extend/VB',
#  'roof/NN',
#  'building/NN',
#  'front/JJ',
#  'make/VB',
#  'way/NN',
#  'wall/NN',
#  'zigzag/NN',
#  'direction/NN',
#  'become/VB',
#  'lose/VB',
#  'sullen/JJ',
#  'water/NN',
#  'tarn/NN',
#  'notice/VB',
#  'thing/NN',
#  'ride/VB',
#  'short/JJ',
#  'causeway/NN',
#  'house/NN',
#  'servant/NN',
#  'wait/VB',
#  'take/VB',
#  'horse/NN',
#  'enter/VB',
#  'gothic/JJ',
#  'archway/NN',
#  'hall/NN',
#  'valet/NN',
#  'stealthy/JJ',
#  'step/NN',
#  'thence/RB',
#  'conduct/VB',
#  'silence/NN',
#  'many/JJ',
#  'dark/NN',
#  'intricate/JJ',
#  'passage/NN',
#  'progress/NN',
#  'studio/NN',
#  'master/NN',
#  'much/JJ',
#  'encounter/VB',
#  'way/NN',
#  'contribute/VB',
#  'know/VB',
#  'not/RB',
#  'heighten/VB',
#  'vague/JJ',
#  'sentiment/NN',
#  'have/VB',
#  'already/RB',
#  'speak/VB',
#  'object/NN',
#  'carving/NN',
#  'ceiling/NN',
#  'sombre/JJ',
#  'tapestry/NN',
#  'wall/NN',
#  'ebon/NN',
#  'blackness/NN',
#  'floor/NN',
#  'phantasmagoric/NN',
#  'armorial/JJ',
#  'trophy/NN',
#  'rattle/VB',
#  'stride/VB',
#  'be/VB',
#  'matter/NN',
#  'such/JJ',
#  'have/VB',
#  'be/VB',
#  'accustom/VB',
#  'infancy/NN',
#  'hesitate/VB',
#  'not/RB',
#  'acknowledge/VB',
#  'familiar/JJ',
#  'be/VB',
#  'still/RB',
#  'wonder/VB',
#  'find/VB',
#  'unfamiliar/JJ',
#  'be/VB',
#  'fancy/VB',
#  'ordinary/JJ',
#  'image/NN',
#  'be/VB',
#  'stir/VB',
#  'staircase/NN',
#  'meet/VB',
#  'physician/NN',
#  'family/NN',
#  'countenance/NN',
#  'thought/NN',
#  'wear/VB',
#  'mingle/VB',
#  'expression/NN',
#  'low/JJ',
#  'cunning/JJ',
#  'perplexity/NN',
#  'accost/VB',
#  'trepidation/NN',
#  'pass/VB',
#  'valet/NN',
#  'now/RB',
#  'throw/VB',
#  'open/JJ',
#  'door/NN',
#  'usher/VB',
#  'presence/NN',
#  'master/NN',
#  'room/NN',
#  'find/VB',
#  'be/VB',
#  'very/RB',
#  'large/JJ',
#  'lofty/JJ',
#  'window/NN',
#  'be/VB',
#  'long/RB',
#  'narrow/JJ',
#  'pointed/JJ',
#  'so/RB',
#  'vast/JJ',
#  'distance/NN',
#  'black/JJ',
#  'oaken/JJ',
#  'floor/NN',
#  'be/VB',
#  'altogether/RB',
#  'inaccessible/JJ',
#  'feeble/JJ',
#  'gleam/NN',
#  'encrimsoned/JJ',
#  'light/NN',
#  'make/VB',
#  'way/NN',
#  'trellised/JJ',
#  'pane/NN',
#  'serve/VB',
#  'render/VB',
#  'sufficiently/RB',
#  'distinct/JJ',
#  'more/RB',
#  'prominent/JJ',
#  'object/NN',
#  'eye/NN',
#  'however/RB',
#  'struggle/VB',
#  'vain/JJ',
#  'reach/VB',
#  'remoter/JJ',
#  'angle/NN',
#  'chamber/NN',
#  'recess/NN',
#  'vault/VB',
#  'fret/VB',
#  'ceiling/NN',
#  'dark/JJ',
#  'drapery/NN',
#  'hang/VB',
#  'wall/NN',
#  'general/JJ',
#  'furniture/NN',
#  'be/VB',
#  'profuse/JJ',
#  'comfortless/JJ',
#  'antique/NN',
#  'tattered/JJ',
#  'many/JJ',
#  'book/NN',
#  'musical/JJ',
#  'instrument/NN',
#  'lay/VB',
#  'scatter/VB',
#  'fail/VB',
#  'give/VB',
#  'vitality/NN',
#  'scene/NN',
#  'feel/VB',
#  'breathe/VB',
#  'atmosphere/NN',
#  'sorrow/NN',
#  'air/NN',
#  'stern/JJ',
#  'deep/JJ',
#  'irredeemable/JJ',
#  'gloom/NN',
#  'hung/NN',
#  'over/RB',
#  'pervade/VB',
#  'entrance/NN',
#  'usher/NN',
#  'rise/VB',
#  'sofa/NN',
#  'have/VB',
#  'be/VB',
#  'lie/VB',
#  'full/JJ',
#  'length/NN',
#  'greet/VB',
#  'vivacious/JJ',
#  'warmth/NN',
#  'have/VB',
#  'much/JJ',
#  'first/JJ',
#  'thought/NN',
#  'overdo/VB',
#  'cordiality/NN',
#  'constrain/VB',
#  'effort/NN',
#  'ennuye/JJ',
#  'man/NN',
#  'world/NN',
#  'glance/NN',
#  'however/RB',
#  'countenance/NN',
#  'convince/VB',
#  'perfect/JJ',
#  'sincerity/NN',
#  'sit/VB',
#  'down/RB',
#  'moment/NN',
#  'speak/VB',
#  'not/RB',
#  'gaze/VB',
#  'feeling/JJ',
#  'half/NN',
#  'pity/NN',
#  'half/NN',
#  'awe/NN',
#  'surely/RB',
#  'man/NN',
#  'have/VB',
#  'never/RB',
#  'before/RB',
#  'so/RB',
#  'terribly/RB',
#  'alter/VB',
#  'so/RB',
#  'brief/JJ',
#  'period/NN',
#  'have/VB',
#  'roderick/JJ',
#  'usher/NN',
#  'be/VB',
#  'difficulty/NN',
#  'bring/VB',
#  'admit/VB',
#  'identity/NN',
#  'wan/JJ',
#  'be/VB',
#  'companion/NN',
#  'early/JJ',
#  'boyhood/NN',
#  'yet/RB',
#  'character/NN',
#  'face/NN',
#  'have/VB',
#  'be/VB',
#  'time/NN',
#  'remarkable/JJ',
#  'cadaverousness/NN',
#  'complexion/NN',
#  'eye/NN',
#  'large/JJ',
#  'liquid/NN',
#  'luminous/JJ',
#  'comparison/NN',
#  'lip/NN',
#  'somewhat/RB',
#  'thin/JJ',
#  'very/RB',
#  'pallid/JJ',
#  'surpassingly/RB',
#  'beautiful/JJ',
#  'curve/NN',
#  'nose/NN',
#  'delicate/JJ',
#  'hebrew/NN',
#  'model/NN',
#  'breadth/NN',
#  'nostril/NN',
#  'unusual/JJ',
#  'similar/JJ',
#  'formation/NN',
#  'finely/RB',
#  'moulded/JJ',
#  'chin/NN',
#  'speaking/NN',
#  'want/NN',
#  'prominence/NN',
#  'want/NN',
#  'moral/JJ',
#  'energy/NN',
#  'hair/NN',
#  'more/JJ',
#  'web/NN',
#  'softness/NN',
#  'tenuity/NN',
#  'feature/NN',
#  'inordinate/JJ',
#  'expansion/NN',
#  'region/NN',
#  'temple/NN',
#  'make/VB',
#  'altogether/RB',
#  'countenance/NN',
#  'not/RB',
#  'easily/RB',
#  'be/VB',
#  'forget/VB',
#  'now/RB',
#  'mere/JJ',
#  'exaggeration/NN',
#  'prevailing/JJ',
#  'character/NN',
#  'feature/NN',
#  'expression/NN',
#  'be/VB',
#  'wont/JJ',
#  'convey/VB',
#  'lay/VB',
#  'so/RB',
#  'much/JJ',
#  'change/NN',
#  'doubt/VB',
#  'speak/VB',
#  'now/RB',
#  'ghastly/JJ',
#  'pallor/NN',
#  'skin/NN',
#  'now/RB',
#  'miraculous/JJ',
#  'lustre/NN',
#  'eye/NN',
#  'thing/NN',
#  'startle/VB',
#  'even/RB',
#  'awe/VB',
#  'silken/JJ',
#  'hair/NN',
#  'too/RB',
#  'have/VB',
#  'be/VB',
#  'suffer/VB',
#  'grow/VB',
#  'unheeded/JJ',
#  'wild/JJ',
#  'gossamer/NN',
#  'texture/NN',
#  'float/VB',
#  'rather/RB',
#  'fall/VB',
#  'face/NN',
#  'not/RB',
#  'even/RB',
#  'effort/NN',
#  ...]

# %%
source_dir
# Out:
# '/Users/rachelbrynsvold/dsi/capstone_dir/top_100_dev_corp/books/clean/'

# %%
lemmatize("I took an extra turn")
# Out:
# ['take/VB', 'extra/JJ', 'turn/NN']

# %%
lemmatize("Turn around, there is a gator chasing you")
# Out:
# ['turn/VB', 'be/VB', 'gator/NN', 'chasing/NN']

# %%
output_v3 = eda(transform_txt_file_v3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-4ac189527f33> in <module>()
# ----> 1 output_v3 = eda(transform_txt_file_v3)
#
# <ipython-input-105-1826c30132a9> in eda(transform_txt_file, fileid_lst)
#       4     '''
#       5
# ----> 6     all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
#       7
#       8     book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
#
# <ipython-input-133-ca9c24f8f437> in transform_txt_file_v3(fname, root, stop_words, lemma)
#      12
#      13             if lemma == True:
# ---> 14                 line = lemmatize(line)
#      15
#      16             else:
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/utils.pyc in lemmatize(content, allowed_tags, light, stopwords, min_length, max_length)
#    1079     content = u(' ').join(tokenize(content, lower=True, errors='ignore'))
#    1080
# -> 1081     parsed = parse(content, lemmata=True, collapse=False)
#    1082     result = []
#    1083     for sentence in parsed:
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/pattern/text/en/__init__.pyc in parse(s, *args, **kwargs)
#     154     """ Returns a tagged Unicode string.
#     155     """
# --> 156     return parser.parse(s, *args, **kwargs)
#     157
#     158 def parsetree(s, *args, **kwargs):
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/pattern/text/__init__.pyc in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#     728         # Tokenizer.
#     729         if tokenize is True:
# --> 730             s = self.find_tokens(s, **kwargs)
#     731         if isinstance(s, (list, tuple)):
#     732             s = [isinstance(s, basestring) and s.split(" ") or s for s in s]
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/pattern/text/__init__.pyc in find_tokens(self, string, **kwargs)
#     673               abbreviations = kwargs.get("abbreviations", ABBREVIATIONS),
#     674                     replace = kwargs.get(      "replace", replacements),
# --> 675                   linebreak = r"\n{2,}")
#     676
#     677     def find_tags(self, tokens, **kwargs):
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/pattern/text/__init__.pyc in find_tokens(string, punctuation, abbreviations, replace, linebreak)
#     921 EOS = "END-OF-SENTENCE"
#     922
# --> 923 def find_tokens(string, punctuation=PUNCTUATION, abbreviations=ABBREVIATIONS, replace=replacements, linebreak=r"\n{2,}"):
#     924     """ Returns a list of sentences. Each sentence is a space-separated string of tokens (words).
#     925         Handles common cases of abbreviations (e.g., etc., ...).
#
# KeyboardInterrupt:

# %%
book_lengths3, avg_num_tokens3, dictionary3, dictionary_length3, \
    unique_toks_per_fileid3, avg_unique_toks3, corpus3 = output_v3

# %%
print "Average number of tokens in a book: ", avg_num_tokens3
print "   "
print "Average unique tokens in a book: ", avg_unique_toks3
print "   "
print "Total number of words (dictionary length): ", dictionary_length3
# Out:
# Average number of tokens in a book:  66904
#
#  ('526-clean.txt', 5917),
#  ('55-clean.txt', 2877),
#  ('55387-clean.txt', 3037),
#  ('55404-clean.txt', 9117),
#  ('6130-clean.txt', 14134),
#  ('730-clean.txt', 11299),
#  ('7370-clean.txt', 4634),
#  ('74-clean.txt', 8250),
#  ('76-clean.txt', 7448),
#  ('768-clean.txt', 10092),
#  ('829-clean.txt', 8286),
#  ('84-clean.txt', 7077),
#  ('844-clean.txt', 2581),
#  ('851-clean.txt', 2238),
#  ('863-clean.txt', 5646),
#  ('8800-clean.txt', 11206),
#  ('932-clean.txt', 2013),
#  ('98-clean.txt', 10675),
#  ('996-clean.txt', 16742)]

# %%
save_stuff('lemmatized')

# %% [markdown]
# ## EDA Step 4: + frequency filters

# %%
#Think I can do this by pruning existing dictionary

# %%
def eda(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, model, outputs_dir='/Users/rachelbrynsvold/dsi/capstone_dir/top_100_dev_corp/outputs/'):
    '''
    Save the outputs of the most recent eda step
    '''
    if dictionary != None:
        dictionary.save(outputs_dir + distinguishing_str + '.dict')
        
    if corpus != None:
        corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)
    
    if model != None:
        pass

# %%
gensim.utils.prune_vocabctionary3.copy()
gensim.utils.prune_vocab(dictionary3, min_reduce=10)

# %%
len(dictionary3)

# %% [markdown]
# # First LDA Model!!!

# %%
from gensim.models import ldamodel

# %%
lda = ldamodel.LdaModel(corpus=corpus,alpha='auto', id2word=dictionary, num_topics=20, update_every=0, passes=20)

# %%
name = 'first_lda.model'
lda.save(outpoutputs_dir_dir + name)

# %%
print lda

# %%
lda.get_document_topics(dictionary.doc2bow(transform_txt_file_v2(usher)))
# Out:
# [(17, 0.99976736796572041)]

# %%
lda.get_term_topics(3)
# Out:
# []

# %%
lda.get_topic_terms(1)
# Out:
# [(91660, 0.0010124057909801489),
#  (10364, 0.00061426842891210544),
#  (91597, 0.00051999185286401111),
#  (91667, 0.00049671380979222706),
#  (91536, 0.00041714172695244539),
#  (91596, 0.0003260759552575187),
#  (91657, 0.00029770823944895501),
#  (12919, 0.00023973092674403279),
#  (2729, 0.00021683942578643836),
#  (1443, 0.00021455100956580147)]

# %%
#dewey decimal system recreation??
#recreate gutenberg topics?

# %% [markdown]
# At the end - bar chart of changes?
