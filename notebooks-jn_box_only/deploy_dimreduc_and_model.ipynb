# %%
import os, codecs
import gensim
from gensim import corpora
from collections import defaultdict
import string
from string import punctuation
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### THESE SHOULD BE ALL THE RELATIVE PATHS

# %%
source_dir = '/Users/rachelbrynsvold/dsi/capstone_dir/Capstone/books/clean' + '/'
outputs_dir = '/Users/rachelbrynsvold/dsi/capstone_dir/Capstone/outputs' + '/'

# %%
class IterFile(object):
    '''
    class object to do the iterating on individual book txt documents, including file i/o.
    '''
    
    def __init__(self, filepath):
        self.filepath = filepath
        
    def _open_file(self):
        self.file = codecs.open(self.filepath, 'r', encoding='utf_8')
        
    def _close_file(self):
        self.file.close()
    
    def __iter__(self):
        '''
        overwrite iteration to include file i/o
        '''
        self._open_file()
        
        for line in self.file:
            yield line
        
        self._close_file()

# %%
def transform_txt_file_v1(fname, root=source_dir):
    '''
    Initial pass at text transformation
    Reimplemented later (v2 etc) as a caller of various subfunctions to do all the transformation
    '''
    fp = root + fname

    book_as_lst = []
    for line in IterFile(fp):
        if line == "\n":
            pass
        else: 
            line_lst= [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]
            book_as_lst.extend(line_lst)
            
    #add in stop word removal and frequency threshhold
    return book_as_lst

# %%
temp_corp = PlaintextCorpusReader(source_dir, '.*\.txt')
fileid_lst = temp_corp.fileids()
fileid_lst
# Out:
# ['10-clean.txt',
#  '100-clean.txt',
#  '105-clean.txt',
#  '108-clean.txt',
#  '1080-clean.txt',
#  '11-clean.txt',
#  '1112-clean.txt',
#  '1184-clean.txt',
#  '12-clean.txt',
#  '120-clean.txt',
#  '1232-clean.txt',
#  '1260-clean.txt',
#  '1322-clean.txt',
#  '1342-clean.txt',
#  '135-clean.txt',
#  '1399-clean.txt',
#  '140-clean.txt',
#  '1400-clean.txt',
#  '1404-clean.txt',
#  '14264-clean.txt',
#  '147-clean.txt',
#  '1497-clean.txt',
#  '15399-clean.txt',
#  '158-clean.txt',
#  '16-clean.txt',
#  '160-clean.txt',
#  '161-clean.txt',
#  '16382-clean.txt',
#  '1661-clean.txt',
#  '1727-clean.txt',
#  '174-clean.txt',
#  '1952-yellow_wallpaper-clean.txt',
#  '19942-clean.txt',
#  '20-clean.txt',
#  '20203-clean.txt',
#  '203-clean.txt',
#  '205-clean.txt',
#  '21279-clean.txt',
#  '2148-clean.txt',
#  '2174-clean.txt',
#  '219-clean.txt',
#  '224-clean.txt',
#  '23-clean.txt',
#  '236-clean.txt',
#  '2500-clean.txt',
#  '25305-clean.txt',
#  '2591-clean.txt',
#  '2600-clean.txt',
#  '2680-clean.txt',
#  '2701-moby-clean.txt',
#  '28054-clean.txt',
#  '2814-clean.txt',
#  '2852-clean.txt',
#  '28520-clean.txt',
#  '30360-clean.txt',
#  '30601-clean.txt',
#  '3207-clean.txt',
#  '33-clean.txt',
#  '33283-clean.txt',
#  '345-clean.txt',
#  '34901-clean.txt',
#  '35-clean.txt',
#  '36-clean.txt',
#  '3600-clean.txt',
#  '38427-clean.txt',
#  '408-clean.txt',
#  '41-clean.txt',
#  '42-clean.txt',
#  '4300-clean.txt',
#  '4363-clean.txt',
#  '45-clean.txt',
#  '4517-clean.txt',
#  '46-clean.txt',
#  '514-clean.txt',
#  '5200-clean.txt',
#  '521-clean.txt',
#  '526-clean.txt',
#  '55-clean.txt',
#  '55387-clean.txt',
#  '55404-clean.txt',
#  '6130-clean.txt',
#  '730-clean.txt',
#  '7370-clean.txt',
#  '74-clean.txt',
#  '76-clean.txt',
#  '768-clean.txt',
#  '829-clean.txt',
#  '84-clean.txt',
#  '844-clean.txt',
#  '851-clean.txt',
#  '863-clean.txt',
#  '8800-clean.txt',
#  '932-clean.txt',
#  '98-clean.txt',
#  '996-clean.txt']

# %% [markdown]
# ## EDA and Saving helper funtions
#
# To automate EDA steps

# %%
def eda(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, outputs_dir=outputs_dir):
    '''
    Save the outputs of the most recent eda step
    '''
    dictionary.save(outputs_dir + distinguishing_str + '.dict')
    corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)

# %% [markdown]
# ### EDA items
# * List of book lengths (total num of tokens for each book)
# * Average number of tokens per book
# * Number of words in corpus (dictionary length)
#     * Dictionary (not viewed)
# * Unique tokens per book
# * Average number of unique tokens per book
#     * Corpus (not viewe)
#
# Save everything after eda step

# %% [markdown]
# ### To summarize the 'simple tokenization' EDA step (#1):

# %%
output_v1 = eda(transform_txt_file_v1)

# %%
book_lengths1, avg_num_tokens1, dictionary1, dictionary_length1, unique_toks_per_fileid1, \
    avg_unique_toks1, corpus1 = output_v1

# %%
print "Average number of tokens in a book: ", avg_num_tokens1
print "   "
print "Average unique tokens in a book: ", avg_unique_toks1
print "   "
print "Total number of words (dictionary length): ", dictionary_length1
# Out:
# Average number of tokens in a book:  132124
#
# Average unique tokens in a book:  9004
#
# Total number of words (dictionary length):  195104

# %%
##for pres, note the sparcity problem - 9000 vs. 195k == 186k empty

# %%
save_stuff('simple_tok', dictionary1, corpus1)

# %% [markdown]
# ## EDA Step 2: + stop word removal

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = set(stopwords.words('english'))
print stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rachelbrynsvold/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# set([u'all', u'just', u'being', u'over', u'both', u'through', u'yourselves', u'its', u'before', u'o', u'hadn', u'herself', u'll', u'had', u'should', u'to', u'only', u'won', u'under', u'ours', u'has', u'do', u'them', u'his', u'very', u'they', u'not', u'during', u'now', u'him', u'nor', u'd', u'did', u'didn', u'this', u'she', u'each', u'further', u'where', u'few', u'because', u'doing', u'some', u'hasn', u'are', u'our', u'ourselves', u'out', u'what', u'for', u'while', u're', u'does', u'above', u'between', u'mustn', u't', u'be', u'we', u'who', u'were', u'here', u'shouldn', u'hers', u'by', u'on', u'about', u'couldn', u'of', u'against', u's', u'isn', u'or', u'own', u'into', u'yourself', u'down', u'mightn', u'wasn', u'your', u'from', u'her', u'their', u'aren', u'there', u'been', u'whom', u'too', u'wouldn', u'themselves', u'weren', u'was', u'until', u'more', u'himself', u'that', u'but', u'don', u'with', u'than', u'those', u'he', u'me', u'myself', u'ma', u'these', u'up', u'will', u'below', u'ain', u'can', u'theirs', u'my', u'and', u've', u'then', u'is', u'am', u'it', u'doesn', u'an', u'as', u'itself', u'at', u'have', u'in', u'any', u'if', u'again', u'no', u'when', u'same', u'how', u'other', u'which', u'you', u'shan', u'needn', u'haven', u'after', u'most', u'such', u'why', u'a', u'off', u'i', u'm', u'yours', u'so', u'y', u'the', u'having', u'once'])

# %%
def transform_txt_file_v2(fname, root=source_dir, stop_words=stop):
    '''
    Top-level function to call all of the subfunctions for text transformation
    Assumes you want to remove empty lines and tokenize (because you do)
    '''
    fp = root + fname
    book_as_lst = []
    for line in IterFile(fp):
        
        if empty_line_check(line) == False:
            line = basic_tokenize(line)
            
            if stop_words !=None:
                line = remove_stop_words(line, stop_words)
        
            book_as_lst.extend(line)
        
    return book_as_lst

def empty_line_check(line) :
    '''
    checks for empty line
    '''
    if line == "\n":
        empty = True
    else:
        empty = False
    return empty
    
def basic_tokenize(line):
    '''
    convert to list
    strip punctuation, lowercase
    '''
    return [tok.lower().strip(punctuation) for tok in line.strip('\n').split()]    
            
def remove_stop_words(line, stop_words):
    return [tok for tok in line if tok not in stop_words]

# %%
output_v2 = eda(transform_txt_file_v2)

# %%
book_lengths2, avg_num_tokens2, dictionary2, dictionary_length2, \
    unique_toks_per_fileid2, avg_unique_toks2, corpus2 = output_v2

# %%
print "Average number of tokens in a book: ", avg_num_tokens2
print "   "
print "Average unique tokens in a book: ", avg_unique_toks2
print "   "
print "Total number of words (dictionary length): ", dictionary_length2
# Out:
# Average number of tokens in a book:  66904
#
# Average unique tokens in a book:  8882
#
# Total number of words (dictionary length):  194961

# %%
#make graph of reduction

# %%
save_stuff('no_stopwords', dictionary2, corpus2)

# %% [markdown]
# ## EDA Step 4: + frequency filters

# %%
def eda_w_filter(transform_txt_file, fileid_lst=fileid_lst):
    '''
    Do transformations with updated transformation function and return all the eda items
    '''
    
    all_transf_books_lst = [transform_txt_file(f) for f in fileid_lst]
    
    book_lengths = [(tup[0], len(tup[1])) for tup in zip(fileid_lst, all_transf_books_lst)]
    avg_num_tokens = int(np.mean([len(book) for book in all_transf_books_lst]))
    
    dictionary = corpora.Dictionary(all_transf_books_lst)
    dictionary.filter_extremes(no_below=1)
    dictionary_length = len(dictionary)
    
    corpus = [dictionary.doc2bow(book) for book in all_transf_books_lst]
    
    unique_toks_num_lst = [len(book) for book in corpus]
    unique_toks_per_fileid = zip(fileid_lst, unique_toks_num_lst)
    avg_unique_toks = int(np.mean(unique_toks_num_lst))
    
    
    return book_lengths, avg_num_tokens, dictionary, dictionary_length, unique_toks_per_fileid, avg_unique_toks, corpus


def save_stuff(distinguishing_str, dictionary, corpus, model, outputs_dir=outputs_dir):
    '''
    Save the outputs of the most recent eda step
    '''
    if dictionary != None:
        dictionary.save(outputs_dir + distinguishing_str + '.dict')
        
    if corpus != None:
        corpora.MmCorpus.serialize(outputs_dir + distinguishing_str + '_corpus.mm', corpus)
    
    if model != None:
        pass

# %%
outputs4 = eda_w_filter(transform_txt_file_v2)

# %%
book_lengths4, avg_num_tokens4, dictionary4, dictionary_length4, \
    unique_toks_per_fileid4, avg_unique_toks4, corpus4 = outputs4

# %%
print "Average number of tokens in a book: ", avg_num_tokens4, avg_num_tokens2
print "   "
print "Average unique tokens in a book: ", avg_unique_toks4, avg_unique_toks2
print "   "
print "Total number of words (dictionary length): ", dictionary_length4, dictionary_length2
# Out:
# Average number of tokens in a book:  66904 66904
#
# Average unique tokens in a book:  5461 8882
#
# Total number of words (dictionary length):  100000 194961

# %%
save_stuff('frequency_filtered', dictionary4, corpus4, model=None)

# %% [markdown]
# ## Dimensionality Reduction Summary:

# %%
book_lengths4, avg_num_tokens4, dictionary4, dictionary_length4, \
    unique_toks_per_fileid4, avg_unique_toks4, corpus4 = outputs4

# %%
print "Average total words per book: "
print "   ", "Initial (tokenized): ", avg_num_tokens1
print "   ", "Stop words removed: ", avg_num_tokens2
print "   ", "Frequency filtered: ", avg_num_tokens4
print "   "
print "Average unique words per book: "
print "   ", "Initial (tokenized): ", avg_unique_toks1
print "   ", "Stop words removed: ", avg_unique_toks2
print "   ", "Frequency filtered: ", avg_unique_toks4
print "   "
print "Vocabulary length: "
print "   ", "Initial (tokenized): ", dictionary_length1
print "   ", "Stop words removed: ", dictionary_length2
print "   ", "Frequency filtered: ", dictionary_length4
# Out:
# Average total words per book:
#     Initial (tokenized):  132124
#     Stop words removed:  66904
#     Frequency filtered:  66904
#
# Average unique words per book:
#     Initial (tokenized):  9004
#     Stop words removed:  8882
#     Frequency filtered:  5461
#
# Vocabulary length:
#     Initial (tokenized):  195104
#     Stop words removed:  194961
#     Frequency filtered:  100000

# %%
avg_num_tokens_lst = [avg_num_tokens1, avg_num_tokens2, avg_num_tokens4]
avg_unique_toks_lst =  [avg_unique_toks1, avg_unique_toks2, avg_unique_toks4]
vocab_size_lst =[dictionary_length1, dictionary_length2, dictionary_length4]
avg_num_tokens_lst, avg_unique_toks_lst, vocab_size_lst
# Out:
# ([132124, 66904, 66904], [9004, 8882, 5461], [195104, 194961, 100000])

# %%
tokenized_lst = [avg_unique_toks1, avg_num_tokens1, dictionary_length1]
stop_words_removed_lst =  [avg_unique_toks2, avg_num_tokens2, dictionary_length2]
frequency_filtered_lst =[avg_unique_toks4, avg_num_tokens4, dictionary_length4]
tokenized_lst, stop_words_removed_lst, frequency_filtered_lst
# Out:
# ([9004, 132124, 195104], [8882, 66904, 194961], [5461, 66904, 100000])

# %%
import matplotlib.pyplot as plt
#%matplotinline

# %%
n_groups = 3
pos = list(range(n_groups))

dim_red_1 = tokenized_lst

dim_red_2 = stop_words_removed_lst

dim_red_3 = frequency_filtered_lst


fig, ax = plt.subplots()

pos = list(range(n_groups))
bar_width = 0.25

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(pos, 
                 dim_red_1, bar_width,
                 alpha=opacity,
                 #color='b',
                 label='Initial')

rects2 = plt.bar([p + bar_width for p in pos], 
                 dim_red_2, bar_width,
                 alpha=opacity,
                 #color='b',
                 label='Stop Word Removal')

rects3 = plt.bar([p + bar_width*2 for p in pos], 
                 dim_red_3, bar_width,
                 alpha=opacity,
                 #color='b',
                 label= 'Frequency Filtering')

#plt.xlabel('Group')
plt.ylabel('Number of Words')
plt.title('Counts Over Dimensionality Reduction')
plt.xticks(index + bar_width / 2, ('Avg unique per book', \
                        'Avg total per book', 'Total vocab size'))
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-49777c82f6c9> in <module>()
#      38 plt.ylabel('Number of Words')
#      39 plt.title('Counts Over Dimensionality Reduction')
# ---> 40 plt.xticks(index + bar_width / 2, ('Avg unique per book',                         'Avg total per book', 'Total vocab size'))
#      41 plt.legend()
#      42
#
# NameError: name 'index' is not defined

# %%
all_transf_books_lst = [transform_txt_file_v2(f) for f in fileid_lst]
all_tokens = sum(all_transf_books_lst, [])
all_tokens
# Out:
# [u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'old',
#  u'testament',
#  u'king',
#  u'james',
#  u'version',
#  u'bible',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'\n',
#  u'first',
#  u'book',
#  u'moses',
#  u'called',
#  u'genesis',
#  u'\n',
#  u'\n',
#  u'1:1',
#  u'beginning',
#  u'god',
#  u'created',
#  u'heavens',
#  u'earth',
#  u'\n',
#  u'1:2',
#  u'earth',
#  u'without',
#  u'form',
#  u'void',
#  u'darkness',
#  u'upon',
#  u'face',
#  u'deep',
#  u'spirit',
#  u'god',
#  u'moved',
#  u'upon',
#  u'face',
#  u'waters',
#  u'\n',
#  u'1:3',
#  u'god',
#  u'said',
#  u'let',
#  u'light',
#  u'light',
#  u'\n',
#  u'1:4',
#  u'god',
#  u'saw',
#  u'light',
#  u'good',
#  u'god',
#  u'divided',
#  u'light',
#  u'darkness',
#  u'\n',
#  u'1:5',
#  u'god',
#  u'called',
#  u'light',
#  u'day',
#  u'darkness',
#  u'called',
#  u'night',
#  u'evening',
#  u'morning',
#  u'first',
#  u'day',
#  u'\n',
#  u'1:6',
#  u'god',
#  u'said',
#  u'let',
#  u'firmament',
#  u'midst',
#  u'waters',
#  u'let',
#  u'divide',
#  u'waters',
#  u'waters',
#  u'\n',
#  u'1:7',
#  u'god',
#  u'made',
#  u'firmament',
#  u'divided',
#  u'waters',
#  u'firmament',
#  u'waters',
#  u'firmament',
#  u'\n',
#  u'1:8',
#  u'god',
#  u'called',
#  u'firmament',
#  u'heaven',
#  u'evening',
#  u'morning',
#  u'second',
#  u'day',
#  u'\n',
#  u'1:9',
#  u'god',
#  u'said',
#  u'let',
#  u'waters',
#  u'heaven',
#  u'gathered',
#  u'together',
#  u'unto',
#  u'one',
#  u'place',
#  u'let',
#  u'dry',
#  u'land',
#  u'appear',
#  u'\n',
#  u'1:10',
#  u'god',
#  u'called',
#  u'dry',
#  u'land',
#  u'earth',
#  u'gathering',
#  u'together',
#  u'waters',
#  u'called',
#  u'seas',
#  u'god',
#  u'saw',
#  u'good',
#  u'\n',
#  u'1:11',
#  u'god',
#  u'said',
#  u'let',
#  u'earth',
#  u'bring',
#  u'forth',
#  u'grass',
#  u'herb',
#  u'yielding',
#  u'seed',
#  u'fruit',
#  u'tree',
#  u'yielding',
#  u'fruit',
#  u'kind',
#  u'whose',
#  u'seed',
#  u'upon',
#  u'earth',
#  u'\n',
#  u'1:12',
#  u'earth',
#  u'brought',
#  u'forth',
#  u'grass',
#  u'herb',
#  u'yielding',
#  u'seed',
#  u'kind',
#  u'tree',
#  u'yielding',
#  u'fruit',
#  u'whose',
#  u'seed',
#  u'kind',
#  u'god',
#  u'saw',
#  u'good',
#  u'\n',
#  u'1:13',
#  u'evening',
#  u'morning',
#  u'third',
#  u'day',
#  u'\n',
#  u'1:14',
#  u'god',
#  u'said',
#  u'let',
#  u'lights',
#  u'firmament',
#  u'heaven',
#  u'divide',
#  u'day',
#  u'night',
#  u'let',
#  u'signs',
#  u'seasons',
#  u'days',
#  u'years',
#  u'1:15',
#  u'let',
#  u'lights',
#  u'firmament',
#  u'heaven',
#  u'give',
#  u'light',
#  u'upon',
#  u'earth',
#  u'\n',
#  u'1:16',
#  u'god',
#  u'made',
#  u'two',
#  u'great',
#  u'lights',
#  u'greater',
#  u'light',
#  u'rule',
#  u'day',
#  u'lesser',
#  u'light',
#  u'rule',
#  u'night',
#  u'made',
#  u'stars',
#  u'also',
#  u'\n',
#  u'1:17',
#  u'god',
#  u'set',
#  u'firmament',
#  u'heaven',
#  u'give',
#  u'light',
#  u'upon',
#  u'earth',
#  u'1:18',
#  u'rule',
#  u'day',
#  u'night',
#  u'divide',
#  u'light',
#  u'darkness',
#  u'god',
#  u'saw',
#  u'good',
#  u'\n',
#  u'1:19',
#  u'evening',
#  u'morning',
#  u'fourth',
#  u'day',
#  u'\n',
#  u'1:20',
#  u'god',
#  u'said',
#  u'let',
#  u'waters',
#  u'bring',
#  u'forth',
#  u'abundantly',
#  u'moving',
#  u'creature',
#  u'hath',
#  u'life',
#  u'fowl',
#  u'may',
#  u'fly',
#  u'earth',
#  u'open',
#  u'firmament',
#  u'heaven',
#  u'\n',
#  u'1:21',
#  u'god',
#  u'created',
#  u'great',
#  u'whales',
#  u'every',
#  u'living',
#  u'creature',
#  u'moveth',
#  u'waters',
#  u'brought',
#  u'forth',
#  u'abundantly',
#  u'kind',
#  u'every',
#  u'winged',
#  u'fowl',
#  u'kind',
#  u'god',
#  u'saw',
#  u'good',
#  u'\n',
#  u'1:22',
#  u'god',
#  u'blessed',
#  u'saying',
#  u'fruitful',
#  u'multiply',
#  u'fill',
#  u'waters',
#  u'seas',
#  u'let',
#  u'fowl',
#  u'multiply',
#  u'earth',
#  u'\n',
#  u'1:23',
#  u'evening',
#  u'morning',
#  u'fifth',
#  u'day',
#  u'\n',
#  u'1:24',
#  u'god',
#  u'said',
#  u'let',
#  u'earth',
#  u'bring',
#  u'forth',
#  u'living',
#  u'creature',
#  u'kind',
#  u'cattle',
#  u'creeping',
#  u'thing',
#  u'beast',
#  u'earth',
#  u'kind',
#  u'\n',
#  u'1:25',
#  u'god',
#  u'made',
#  u'beast',
#  u'earth',
#  u'kind',
#  u'cattle',
#  u'kind',
#  u'every',
#  u'thing',
#  u'creepeth',
#  u'upon',
#  u'earth',
#  u'kind',
#  u'god',
#  u'saw',
#  u'good',
#  u'\n',
#  u'1:26',
#  u'god',
#  u'said',
#  u'let',
#  u'us',
#  u'make',
#  u'man',
#  u'image',
#  u'likeness',
#  u'let',
#  u'dominion',
#  u'fish',
#  u'sea',
#  u'fowl',
#  u'air',
#  u'cattle',
#  u'earth',
#  u'every',
#  u'creeping',
#  u'thing',
#  u'creepeth',
#  u'upon',
#  u'earth',
#  u'\n',
#  u'1:27',
#  u'god',
#  u'created',
#  u'man',
#  u'image',
#  u'image',
#  u'god',
#  u'created',
#  u'male',
#  u'female',
#  u'created',
#  u'\n',
#  u'1:28',
#  u'god',
#  u'blessed',
#  u'god',
#  u'said',
#  u'unto',
#  u'fruitful',
#  u'multiply',
#  u'replenish',
#  u'earth',
#  u'subdue',
#  u'dominion',
#  u'fish',
#  u'sea',
#  u'fowl',
#  u'air',
#  u'every',
#  u'living',
#  u'thing',
#  u'moveth',
#  u'upon',
#  u'earth',
#  u'\n',
#  u'1:29',
#  u'god',
#  u'said',
#  u'behold',
#  u'given',
#  u'every',
#  u'herb',
#  u'bearing',
#  u'seed',
#  u'upon',
#  u'face',
#  u'earth',
#  u'every',
#  u'tree',
#  u'fruit',
#  u'tree',
#  u'yielding',
#  u'seed',
#  u'shall',
#  u'meat',
#  u'\n',
#  u'1:30',
#  u'every',
#  u'beast',
#  u'earth',
#  u'every',
#  u'fowl',
#  u'air',
#  u'every',
#  u'thing',
#  u'creepeth',
#  u'upon',
#  u'earth',
#  u'wherein',
#  u'life',
#  u'given',
#  u'every',
#  u'green',
#  u'herb',
#  u'meat',
#  u'\n',
#  u'1:31',
#  u'god',
#  u'saw',
#  u'every',
#  u'thing',
#  u'made',
#  u'behold',
#  u'good',
#  u'evening',
#  u'morning',
#  u'sixth',
#  u'day',
#  u'\n',
#  u'2:1',
#  u'thus',
#  u'heavens',
#  u'earth',
#  u'finished',
#  u'host',
#  u'\n',
#  u'2:2',
#  u'seventh',
#  u'day',
#  u'god',
#  u'ended',
#  u'work',
#  u'made',
#  u'rested',
#  u'seventh',
#  u'day',
#  u'work',
#  u'made',
#  u'\n',
#  u'2:3',
#  u'god',
#  u'blessed',
#  u'seventh',
#  u'day',
#  u'sanctified',
#  u'rested',
#  u'work',
#  u'god',
#  u'created',
#  u'made',
#  u'\n',
#  u'2:4',
#  u'generations',
#  u'heavens',
#  u'earth',
#  u'created',
#  u'day',
#  u'lord',
#  u'god',
#  u'made',
#  u'earth',
#  u'heavens',
#  u'2:5',
#  u'every',
#  u'plant',
#  u'field',
#  u'earth',
#  u'every',
#  u'herb',
#  u'field',
#  u'grew',
#  u'lord',
#  u'god',
#  u'caused',
#  u'rain',
#  u'upon',
#  u'earth',
#  u'man',
#  u'till',
#  u'ground',
#  u'\n',
#  u'2:6',
#  u'went',
#  u'mist',
#  u'earth',
#  u'watered',
#  u'whole',
#  u'face',
#  u'ground',
#  u'\n',
#  u'2:7',
#  u'lord',
#  u'god',
#  u'formed',
#  u'man',
#  u'dust',
#  u'ground',
#  u'breathed',
#  u'nostrils',
#  u'breath',
#  u'life',
#  u'man',
#  u'became',
#  u'living',
#  u'soul',
#  u'\n',
#  u'2:8',
#  u'lord',
#  u'god',
#  u'planted',
#  u'garden',
#  u'eastward',
#  u'eden',
#  u'put',
#  u'man',
#  u'formed',
#  u'\n',
#  u'2:9',
#  u'ground',
#  u'made',
#  u'lord',
#  u'god',
#  u'grow',
#  u'every',
#  u'tree',
#  u'pleasant',
#  u'sight',
#  u'good',
#  u'food',
#  u'tree',
#  u'life',
#  u'also',
#  u'midst',
#  u'garden',
#  u'tree',
#  u'knowledge',
#  u'good',
#  u'evil',
#  u'\n',
#  u'2:10',
#  u'river',
#  u'went',
#  u'eden',
#  u'water',
#  u'garden',
#  u'thence',
#  u'parted',
#  u'became',
#  u'four',
#  u'heads',
#  u'\n',
#  u'2:11',
#  u'name',
#  u'first',
#  u'pison',
#  u'compasseth',
#  u'whole',
#  u'land',
#  u'havilah',
#  u'gold',
#  u'2:12',
#  u'gold',
#  u'land',
#  u'good',
#  u'bdellium',
#  u'onyx',
#  u'stone',
#  u'\n',
#  u'2:13',
#  u'name',
#  u'second',
#  u'river',
#  u'gihon',
#  u'compasseth',
#  u'whole',
#  u'land',
#  u'ethiopia',
#  u'\n',
#  u'2:14',
#  u'name',
#  u'third',
#  u'river',
#  u'hiddekel',
#  u'goeth',
#  u'toward',
#  u'east',
#  u'assyria',
#  u'fourth',
#  u'river',
#  u'euphrates',
#  u'\n',
#  u'2:15',
#  u'lord',
#  u'god',
#  u'took',
#  u'man',
#  u'put',
#  u'garden',
#  u'eden',
#  u'dress',
#  u'keep',
#  u'\n',
#  u'2:16',
#  u'lord',
#  u'god',
#  u'commanded',
#  u'man',
#  u'saying',
#  u'every',
#  u'tree',
#  u'garden',
#  u'thou',
#  u'mayest',
#  u'freely',
#  u'eat',
#  u'2:17',
#  u'tree',
#  u'knowledge',
#  u'good',
#  u'evil',
#  u'thou',
#  u'shalt',
#  u'eat',
#  u'day',
#  u'thou',
#  u'eatest',
#  u'thereof',
#  u'thou',
#  u'shalt',
#  u'surely',
#  u'die',
#  u'\n',
#  u'2:18',
#  u'lord',
#  u'god',
#  u'said',
#  u'good',
#  u'man',
#  u'alone',
#  u'make',
#  u'help',
#  u'meet',
#  u'\n',
#  u'2:19',
#  u'ground',
#  u'lord',
#  u'god',
#  u'formed',
#  u'every',
#  u'beast',
#  u'field',
#  u'every',
#  u'fowl',
#  u'air',
#  u'brought',
#  u'unto',
#  u'adam',
#  u'see',
#  u'would',
#  u'call',
#  u'whatsoever',
#  u'adam',
#  u'called',
#  u'every',
#  u'living',
#  u'creature',
#  u'name',
#  u'thereof',
#  u'\n',
#  u'2:20',
#  u'adam',
#  u'gave',
#  u'names',
#  u'cattle',
#  u'fowl',
#  u'air',
#  u'every',
#  u'beast',
#  u'field',
#  u'adam',
#  u'found',
#  u'help',
#  u'meet',
#  u'\n',
#  u'2:21',
#  u'lord',
#  u'god',
#  u'caused',
#  u'deep',
#  u'sleep',
#  u'fall',
#  u'upon',
#  u'adam',
#  u'slept',
#  u'took',
#  u'one',
#  u'ribs',
#  u'closed',
#  u'flesh',
#  u'instead',
#  u'thereof',
#  u'2:22',
#  u'rib',
#  u'lord',
#  u'god',
#  u'taken',
#  u'man',
#  u'made',
#  u'woman',
#  u'brought',
#  u'unto',
#  u'man',
#  u'\n',
#  u'2:23',
#  u'adam',
#  u'said',
#  u'bone',
#  u'bones',
#  u'flesh',
#  u'flesh',
#  u'shall',
#  u'called',
#  u'woman',
#  u'taken',
#  u'man',
#  u'\n',
#  u'2:24',
#  u'therefore',
#  u'shall',
#  u'man',
#  u'leave',
#  u'father',
#  u'mother',
#  u'shall',
#  u'cleave',
#  u'unto',
#  u'wife',
#  u'shall',
#  u'one',
#  u'flesh',
#  u'\n',
#  u'2:25',
#  u'naked',
#  u'man',
#  u'wife',
#  u'ashamed',
#  u'\n',
#  u'3:1',
#  u'serpent',
#  u'subtil',
#  u'beast',
#  u'field',
#  u'lord',
#  u'god',
#  u'made',
#  u'said',
#  u'unto',
#  u'woman',
#  u'yea',
#  u'hath',
#  u'god',
#  u'said',
#  u'ye',
#  u'shall',
#  u'eat',
#  u'every',
#  u'tree',
#  u'garden',
#  u'3:2',
#  u'woman',
#  u'said',
#  u'unto',
#  u'serpent',
#  u'may',
#  u'eat',
#  u'fruit',
#  u'trees',
#  u'garden',
#  u'3:3',
#  u'fruit',
#  u'tree',
#  u'midst',
#  u'garden',
#  u'god',
#  u'hath',
#  u'said',
#  u'ye',
#  u'shall',
#  u'eat',
#  u'neither',
#  u'shall',
#  u'ye',
#  u'touch',
#  u'lest',
#  u'ye',
#  u'die',
#  u'\n',
#  u'3:4',
#  u'serpent',
#  u'said',
#  u'unto',
#  u'woman',
#  u'ye',
#  u'shall',
#  u'surely',
#  u'die',
#  u'3:5',
#  u'god',
#  u'doth',
#  u'know',
#  u'day',
#  u'ye',
#  u'eat',
#  u'thereof',
#  u'eyes',
#  u'shall',
#  u'opened',
#  u'ye',
#  u'shall',
#  u'gods',
#  u'knowing',
#  u'good',
#  u'evil',
#  u'\n',
#  u'3:6',
#  u'woman',
#  u'saw',
#  u'tree',
#  u'good',
#  u'food',
#  u'pleasant',
#  u'eyes',
#  u'tree',
#  u'desired',
#  u'make',
#  u'one',
#  u'wise',
#  u'took',
#  u'fruit',
#  u'thereof',
#  u'eat',
#  u'gave',
#  u'also',
#  u'unto',
#  u'husband',
#  u'eat',
#  u'\n',
#  u'3:7',
#  u'eyes',
#  u'opened',
#  u'knew',
#  u'naked',
#  u'sewed',
#  u'fig',
#  u'leaves',
#  u'together',
#  u'made',
#  u'aprons',
#  u'\n',
#  u'3:8',
#  u'heard',
#  u'voice',
#  u'lord',
#  u'god',
#  u'walking',
#  u'garden',
#  u'cool',
#  u'day',
#  u'adam',
#  u'wife',
#  u'hid',
#  u'presence',
#  u'lord',
#  u'god',
#  u'amongst',
#  u'trees',
#  u'garden',
#  u'\n',
#  u'3:9',
#  u'lord',
#  u'god',
#  u'called',
#  u'unto',
#  u'adam',
#  u'said',
#  u'unto',
#  u'art',
#  u'thou',
#  u'3:10',
#  u'said',
#  u'heard',
#  u'thy',
#  u'voice',
#  u'garden',
#  u'afraid',
#  u'naked',
#  u'hid',
#  u'\n',
#  u'3:11',
#  u'said',
#  u'told',
#  u'thee',
#  u'thou',
#  u'wast',
#  u'naked',
#  u'hast',
#  u'thou',
#  u'eaten',
#  u'tree',
#  u'whereof',
#  u'commanded',
#  u'thee',
#  u'thou',
#  u'shouldest',
#  u'eat',
#  u'3:12',
#  u'man',
#  u'said',
#  u'woman',
#  u'thou',
#  u'gavest',
#  u'gave',
#  u'tree',
#  u'eat',
#  u'\n',
#  u'3:13',
#  u'lord',
#  u'god',
#  u'said',
#  u'unto',
#  u'woman',
#  u'thou',
#  u'hast',
#  u'done',
#  u'woman',
#  u'said',
#  u'serpent',
#  u'beguiled',
#  u'eat',
#  u'\n',
#  u'3:14',
#  u'lord',
#  u'god',
#  u'said',
#  u'unto',
#  u'serpent',
#  u'thou',
#  ...]

# %%
all_tokens_set = set(all_tokens)

# %%
tokens_once = set([word for word in all_tokens_set if all_tokens.count(word) == 1])
tokens_once
#texts = [[word for word in text if word not in tokens_once] for text in texts]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-82f51d7cea00> in <module>()
# ----> 1 tokens_once = set([word for word in all_tokens_set if all_tokens.count(word) == 1])
#       2 tokens_once
#       3 #texts = [[word for word in text if word not in tokens_once] for text in texts]
#
# KeyboardInterrupt:

# %%
b_l = transform_txt_file_v2(f)
b_l
# Out:
# [u'quixote',
#  u'complete',
#  u'miguel',
#  u'de',
#  u'cervantes',
#  u'saavedra',
#  u'translated',
#  u'john',
#  u'ormsby',
#  u'contents',
#  u'volume',
#  u'chapter',
#  u'treats',
#  u'character',
#  u'pursuits',
#  u'famous',
#  u'gentleman',
#  u'quixote',
#  u'la',
#  u'mancha',
#  u'chapter',
#  u'ii',
#  u'treats',
#  u'first',
#  u'sally',
#  u'ingenious',
#  u'quixote',
#  u'made',
#  u'home',
#  u'chapter',
#  u'iii',
#  u'wherein',
#  u'related',
#  u'droll',
#  u'way',
#  u'quixote',
#  u'dubbed',
#  u'knight',
#  u'chapter',
#  u'iv',
#  u'happened',
#  u'knight',
#  u'left',
#  u'inn',
#  u'chapter',
#  u'v',
#  u'narrative',
#  u"knight's",
#  u'mishap',
#  u'continued',
#  u'chapter',
#  u'vi',
#  u'diverting',
#  u'important',
#  u'scrutiny',
#  u'curate',
#  u'barber',
#  u'made',
#  u'library',
#  u'ingenious',
#  u'gentleman',
#  u'chapter',
#  u'vii',
#  u'second',
#  u'sally',
#  u'worthy',
#  u'knight',
#  u'quixote',
#  u'la',
#  u'mancha',
#  u'chapter',
#  u'viii',
#  u'good',
#  u'fortune',
#  u'valiant',
#  u'quixote',
#  u'terrible',
#  u'undreamt-of',
#  u'adventure',
#  u'windmills',
#  u'occurrences',
#  u'worthy',
#  u'fitly',
#  u'recorded',
#  u'chapter',
#  u'ix',
#  u'concluded',
#  u'finished',
#  u'terrific',
#  u'battle',
#  u'gallant',
#  u'biscayan',
#  u'valiant',
#  u'manchegan',
#  u'chapter',
#  u'x',
#  u'pleasant',
#  u'discourse',
#  u'passed',
#  u'quixote',
#  u'squire',
#  u'sancho',
#  u'panza',
#  u'chapter',
#  u'xi',
#  u'befell',
#  u'quixote',
#  u'certain',
#  u'goatherds',
#  u'chapter',
#  u'xii',
#  u'goatherd',
#  u'related',
#  u'quixote',
#  u'chapter',
#  u'xiii',
#  u'ended',
#  u'story',
#  u'shepherdess',
#  u'marcela',
#  u'incidents',
#  u'chapter',
#  u'xiv',
#  u'wherein',
#  u'inserted',
#  u'despairing',
#  u'verses',
#  u'dead',
#  u'shepherd',
#  u'together',
#  u'incidents',
#  u'looked',
#  u'chapter',
#  u'xv',
#  u'related',
#  u'unfortunate',
#  u'adventure',
#  u'quixote',
#  u'fell',
#  u'fell',
#  u'certain',
#  u'heartless',
#  u'yanguesans',
#  u'chapter',
#  u'xvi',
#  u'happened',
#  u'ingenious',
#  u'gentleman',
#  u'inn',
#  u'took',
#  u'castle',
#  u'chapter',
#  u'xvii',
#  u'contained',
#  u'innumerable',
#  u'troubles',
#  u'brave',
#  u'quixote',
#  u'good',
#  u'squire',
#  u'sancho',
#  u'panza',
#  u'endured',
#  u'inn',
#  u'misfortune',
#  u'took',
#  u'castle',
#  u'chapter',
#  u'xviii',
#  u'related',
#  u'discourse',
#  u'sancho',
#  u'panza',
#  u'held',
#  u'master',
#  u'quixote',
#  u'adventures',
#  u'worth',
#  u'relating',
#  u'chapter',
#  u'xix',
#  u'shrewd',
#  u'discourse',
#  u'sancho',
#  u'held',
#  u'master',
#  u'adventure',
#  u'befell',
#  u'dead',
#  u'body',
#  u'together',
#  u'notable',
#  u'occurrences',
#  u'chapter',
#  u'xx',
#  u'unexampled',
#  u'unheard-of',
#  u'adventure',
#  u'achieved',
#  u'valiant',
#  u'quixote',
#  u'la',
#  u'mancha',
#  u'less',
#  u'peril',
#  u'ever',
#  u'achieved',
#  u'famous',
#  u'knight',
#  u'world',
#  u'chapter',
#  u'xxi',
#  u'treats',
#  u'exalted',
#  u'adventure',
#  u'rich',
#  u'prize',
#  u"mambrino's",
#  u'helmet',
#  u'together',
#  u'things',
#  u'happened',
#  u'invincible',
#  u'knight',
#  u'chapter',
#  u'xxii',
#  u'freedom',
#  u'quixote',
#  u'conferred',
#  u'several',
#  u'unfortunates',
#  u'carried',
#  u'wish',
#  u'go',
#  u'chapter',
#  u'xxiii',
#  u'befell',
#  u'quixote',
#  u'sierra',
#  u'morena',
#  u'one',
#  u'rarest',
#  u'adventures',
#  u'related',
#  u'veracious',
#  u'history',
#  u'chapter',
#  u'xxiv',
#  u'continued',
#  u'adventure',
#  u'sierra',
#  u'morena',
#  u'chapter',
#  u'xxv',
#  u'treats',
#  u'strange',
#  u'things',
#  u'happened',
#  u'stout',
#  u'knight',
#  u'la',
#  u'mancha',
#  u'sierra',
#  u'morena',
#  u'imitation',
#  u'penance',
#  u'beltenebros',
#  u'chapter',
#  u'xxvi',
#  u'continued',
#  u'refinements',
#  u'wherewith',
#  u'quixote',
#  u'played',
#  u'part',
#  u'lover',
#  u'sierra',
#  u'morena',
#  u'chapter',
#  u'xxvii',
#  u'curate',
#  u'barber',
#  u'proceeded',
#  u'scheme',
#  u'together',
#  u'matters',
#  u'worthy',
#  u'record',
#  u'great',
#  u'history',
#  u'chapter',
#  u'xxviii',
#  u'treats',
#  u'strange',
#  u'delightful',
#  u'adventure',
#  u'befell',
#  u'curate',
#  u'barber',
#  u'sierra',
#  u'chapter',
#  u'xxix',
#  u'treats',
#  u'droll',
#  u'device',
#  u'method',
#  u'adopted',
#  u'extricate',
#  u'love-stricken',
#  u'knight',
#  u'severe',
#  u'penance',
#  u'imposed',
#  u'upon',
#  u'chapter',
#  u'xxx',
#  u'treats',
#  u'address',
#  u'displayed',
#  u'fair',
#  u'dorothea',
#  u'matters',
#  u'pleasant',
#  u'amusing',
#  u'chapter',
#  u'xxxi',
#  u'delectable',
#  u'discussion',
#  u'quixote',
#  u'sancho',
#  u'panza',
#  u'squire',
#  u'together',
#  u'incidents',
#  u'chapter',
#  u'xxxii',
#  u'treats',
#  u'befell',
#  u"quixote's",
#  u'party',
#  u'inn',
#  u'chapter',
#  u'xxxiii',
#  u'related',
#  u'novel',
#  u'ill-advised',
#  u'curiosity',
#  u'chapter',
#  u'xxxiv',
#  u'continued',
#  u'novel',
#  u'ill-advised',
#  u'curiosity',
#  u'chapter',
#  u'xxxv',
#  u'treats',
#  u'heroic',
#  u'prodigious',
#  u'battle',
#  u'quixote',
#  u'certain',
#  u'skins',
#  u'red',
#  u'wine',
#  u'brings',
#  u'novel',
#  u'ill-advised',
#  u'curiosity',
#  u'close',
#  u'chapter',
#  u'xxxvi',
#  u'treats',
#  u'curious',
#  u'incidents',
#  u'occurred',
#  u'inn',
#  u'chapter',
#  u'xxxvii',
#  u'continued',
#  u'story',
#  u'famous',
#  u'princess',
#  u'micomicona',
#  u'droll',
#  u'adventures',
#  u'chapter',
#  u'xxxviii',
#  u'treats',
#  u'curious',
#  u'discourse',
#  u'quixote',
#  u'delivered',
#  u'arms',
#  u'letters',
#  u'chapter',
#  u'xxxix',
#  u'wherein',
#  u'captive',
#  u'relates',
#  u'life',
#  u'adventures',
#  u'chapter',
#  u'xl',
#  u'story',
#  u'captive',
#  u'continued',
#  u'chapter',
#  u'xli',
#  u'captive',
#  u'still',
#  u'continues',
#  u'adventures',
#  u'chapter',
#  u'xlii',
#  u'treats',
#  u'took',
#  u'place',
#  u'inn',
#  u'several',
#  u'things',
#  u'worth',
#  u'knowing',
#  u'chapter',
#  u'xliii',
#  u'wherein',
#  u'related',
#  u'pleasant',
#  u'story',
#  u'muleteer',
#  u'together',
#  u'strange',
#  u'things',
#  u'came',
#  u'pass',
#  u'inn',
#  u'chapter',
#  u'xliv',
#  u'continued',
#  u'unheard-of',
#  u'adventures',
#  u'inn',
#  u'chapter',
#  u'xlv',
#  u'doubtful',
#  u'question',
#  u"mambrino's",
#  u'helmet',
#  u'pack-saddle',
#  u'finally',
#  u'settled',
#  u'adventures',
#  u'occurred',
#  u'truth',
#  u'earnest',
#  u'chapter',
#  u'xlvi',
#  u'end',
#  u'notable',
#  u'adventure',
#  u'officers',
#  u'holy',
#  u'brotherhood',
#  u'great',
#  u'ferocity',
#  u'worthy',
#  u'knight',
#  u'quixote',
#  u'chapter',
#  u'xlvii',
#  u'strange',
#  u'manner',
#  u'quixote',
#  u'la',
#  u'mancha',
#  u'carried',
#  u'away',
#  u'enchanted',
#  u'together',
#  u'remarkable',
#  u'incidents',
#  u'chapter',
#  u'xlviii',
#  u'canon',
#  u'pursues',
#  u'subject',
#  u'books',
#  u'chivalry',
#  u'matters',
#  u'worthy',
#  u'wit',
#  u'chapter',
#  u'xlix',
#  u'treats',
#  u'shrewd',
#  u'conversation',
#  u'sancho',
#  u'panza',
#  u'held',
#  u'master',
#  u'quixote',
#  u'chapter',
#  u'l',
#  u'shrewd',
#  u'controversy',
#  u'quixote',
#  u'canon',
#  u'held',
#  u'together',
#  u'incidents',
#  u'chapter',
#  u'li',
#  u'deals',
#  u'goatherd',
#  u'told',
#  u'carrying',
#  u'quixote',
#  u'chapter',
#  u'lii',
#  u'quarrel',
#  u'quixote',
#  u'goatherd',
#  u'together',
#  u'rare',
#  u'adventure',
#  u'penitents',
#  u'expenditure',
#  u'sweat',
#  u'brought',
#  u'happy',
#  u'conclusion',
#  u"translator's",
#  u'preface',
#  u'translation',
#  u'considerable',
#  u'reluctance',
#  u'abandoned',
#  u'favour',
#  u'present',
#  u'undertaking',
#  u'long',
#  u'favourite',
#  u'project',
#  u'new',
#  u'edition',
#  u"shelton's",
#  u'quixote',
#  u'become',
#  u'somewhat',
#  u'scarce',
#  u'book',
#  u'some--and',
#  u'confess',
#  u'one--for',
#  u"shelton's",
#  u'racy',
#  u'old',
#  u'version',
#  u'defects',
#  u'charm',
#  u'modern',
#  u'translation',
#  u'however',
#  u'skilful',
#  u'correct',
#  u'could',
#  u'possess',
#  u'shelton',
#  u'inestimable',
#  u'advantage',
#  u'belonging',
#  u'generation',
#  u'cervantes',
#  u'quixote',
#  u'vitality',
#  u'contemporary',
#  u'could',
#  u'feel',
#  u'cost',
#  u'dramatic',
#  u'effort',
#  u'see',
#  u'things',
#  u'cervantes',
#  u'saw',
#  u'anachronism',
#  u'language',
#  u'put',
#  u'spanish',
#  u'cervantes',
#  u'english',
#  u'shakespeare',
#  u'shakespeare',
#  u'likely',
#  u'knew',
#  u'book',
#  u'may',
#  u'carried',
#  u'home',
#  u'saddle-bags',
#  u'stratford',
#  u'one',
#  u'last',
#  u'journeys',
#  u'mulberry',
#  u'tree',
#  u'new',
#  u'place',
#  u'joined',
#  u'hands',
#  u'kindred',
#  u'genius',
#  u'pages',
#  u'soon',
#  u'made',
#  u'plain',
#  u'hope',
#  u'even',
#  u'moderate',
#  u'popularity',
#  u'shelton',
#  u'vain',
#  u'fine',
#  u'old',
#  u'crusted',
#  u'english',
#  u'would',
#  u'doubt',
#  u'relished',
#  u'minority',
#  u'would',
#  u'minority',
#  u'warmest',
#  u'admirers',
#  u'must',
#  u'admit',
#  u'satisfactory',
#  u'representative',
#  u'cervantes',
#  u'translation',
#  u'first',
#  u'part',
#  u'hastily',
#  u'made',
#  u'never',
#  u'revised',
#  u'freshness',
#  u'vigour',
#  u'also',
#  u'full',
#  u'measure',
#  u'faults',
#  u'hasty',
#  u'production',
#  u'often',
#  u'literal--barbarously',
#  u'literal',
#  u'frequently--but',
#  u'often',
#  u'loose',
#  u'evidently',
#  u'good',
#  u'colloquial',
#  u'knowledge',
#  u'spanish',
#  u'apparently',
#  u'much',
#  u'never',
#  u'seems',
#  u'occur',
#  u'translation',
#  u'word',
#  u'suit',
#  u'every',
#  u'case',
#  u'often',
#  u'said',
#  u'satisfactory',
#  u'translation',
#  u'quixote',
#  u'familiar',
#  u'original',
#  u'savours',
#  u'truism',
#  u'platitude',
#  u'say',
#  u'truth',
#  u'thoroughly',
#  u'satisfactory',
#  u'translation',
#  u'quixote',
#  u'english',
#  u'language',
#  u'spanish',
#  u'idioms',
#  u'utterly',
#  u'unmanageable',
#  u'untranslatable',
#  u'words',
#  u'numerous',
#  u'enough',
#  u'doubt',
#  u'superabundant',
#  u'rather',
#  u'sententious',
#  u'terseness',
#  u'humour',
#  u'book',
#  u'owes',
#  u'flavour',
#  u'peculiar',
#  u'spanish',
#  u'best',
#  u'distantly',
#  u'imitated',
#  u'tongue',
#  u'history',
#  u'english',
#  u'translations',
#  u'quixote',
#  u'instructive',
#  u"shelton's",
#  u'first',
#  u'language',
#  u'made',
#  u'apparently',
#  u'1608',
#  u'published',
#  u'till',
#  u'1612',
#  u'course',
#  u'first',
#  u'part',
#  u'asserted',
#  u'second',
#  u'published',
#  u'1620',
#  u'work',
#  u'shelton',
#  u'nothing',
#  u'support',
#  u'assertion',
#  u'save',
#  u'fact',
#  u'less',
#  u'spirit',
#  u'less',
#  u'generally',
#  u'understand',
#  u'go',
#  u'first',
#  u'would',
#  u'natural',
#  u'first',
#  u'work',
#  u'young',
#  u'man',
#  u'writing',
#  u'currente',
#  u'calamo',
#  u'second',
#  u'middle-aged',
#  u'man',
#  u'writing',
#  u'bookseller',
#  u'hand',
#  u'closer',
#  u'literal',
#  u'style',
#  u'translations',
#  u'mistranslations',
#  u'occur',
#  u'extremely',
#  u'unlikely',
#  u'new',
#  u'translator',
#  u'would',
#  u'suppressing',
#  u'name',
#  u'allowed',
#  u'shelton',
#  u'carry',
#  u'credit',
#  u'1687',
#  u'john',
#  u'phillips',
#  u"milton's",
#  u'nephew',
#  u'produced',
#  u'quixote',
#  u'made',
#  u'english',
#  u'says',
#  u'according',
#  u'humour',
#  u'modern',
#  u'language',
#  u'quixote',
#  u'much',
#  u'translation',
#  u'travesty',
#  u'travesty',
#  u'coarseness',
#  u'vulgarity',
#  u'buffoonery',
#  u'almost',
#  u'unexampled',
#  u'even',
#  u'literature',
#  u'day',
#  u'ned',
#  u"ward's",
#  u'life',
#  u'notable',
#  u'adventures',
#  u'quixote',
#  u'merrily',
#  u'translated',
#  u'hudibrastic',
#  u'verse',
#  u'1700',
#  u'scarcely',
#  u'reckoned',
#  u'translation',
#  u'serves',
#  u'show',
#  u'light',
#  u'quixote',
#  u'regarded',
#  u'time',
#  u'illustration',
#  u'may',
#  u'found',
#  u'version',
#  u'published',
#  u'1712',
#  u'peter',
#  u'motteux',
#  u'recently',
#  u'combined',
#  u'tea-dealing',
#  u'literature',
#  u'described',
#  u'translated',
#  u'original',
#  u'several',
#  u'hands',
#  u'spanish',
#  u'flavour',
#  u'entirely',
#  u'evaporated',
#  u'manipulation',
#  u'several',
#  u'hands',
#  u'flavour',
#  u'hand',
#  u'distinctly',
#  u'franco-cockney',
#  u'anyone',
#  u'compares',
#  u'carefully',
#  u'original',
#  u'little',
#  u'doubt',
#  u'concoction',
#  u'shelton',
#  u'french',
#  u'filleau',
#  u'de',
#  u'saint',
#  u'martin',
#  u'eked',
#  u'borrowings',
#  u'phillips',
#  u'whose',
#  u'mode',
#  u'treatment',
#  u'adopts',
#  u'sure',
#  u'decent',
#  u'decorous',
#  u'treats',
#  u'quixote',
#  u'fashion',
#  u'comic',
#  u'book',
#  u'cannot',
#  u'made',
#  u'comic',
#  u'attempt',
#  u'improve',
#  u'humour',
#  u'quixote',
#  u'infusion',
#  u'cockney',
#  u'flippancy',
#  u'facetiousness',
#  u"motteux's",
#  u'operators',
#  u'merely',
#  u'impertinence',
#  u'like',
#  u'larding',
#  u'sirloin',
#  u'prize',
#  u'beef',
#  u'absolute',
#  u'falsification',
#  u'spirit',
#  u'book',
#  u'proof',
#  u'uncritical',
#  u'way',
#  u'quixote',
#  u'generally',
#  u'read',
#  u'worse',
#  u'worthless',
#  u'translation--worthless',
#  u'failing',
#  u'represent',
#  u'worse',
#  u'worthless',
#  u'misrepresenting--should',
#  u'favoured',
#  u'effect',
#  u'however',
#  u'bringing',
#  u'translation',
#  u'undertaken',
#  u'executed',
#  u'different',
#  u'spirit',
#  u'charles',
#  u'jervas',
#  u'portrait',
#  u'painter',
#  u'friend',
#  u'pope',
#  u'swift',
#  u'arbuthnot',
#  u'gay',
#  u'jervas',
#  u'allowed',
#  u'little',
#  u'credit',
#  u'work',
#  u'indeed',
#  u'may',
#  u'said',
#  u'none',
#  u'known',
#  u'world',
#  u'general',
#  u"jarvis's",
#  u'published',
#  u'death',
#  u'printers',
#  u'gave',
#  u'name',
#  u'according',
#  u'current',
#  u'pronunciation',
#  u'day',
#  u'freely',
#  u'used',
#  u'freely',
#  u'abused',
#  u'translations',
#  u'seen',
#  u'far',
#  u'editions',
#  u'admitted',
#  u'hands',
#  u'far',
#  u'faithful',
#  u'yet',
#  u'nobody',
#  u'seems',
#  u'good',
#  u'word',
#  u'say',
#  u'author',
#  u'jervas',
#  u'doubt',
#  u'prejudiced',
#  u'readers',
#  u'preface',
#  u'among',
#  u'many',
#  u'true',
#  u'words',
#  u'shelton',
#  u'stevens',
#  u'motteux',
#  u'rashly',
#  u'unjustly',
#  u'charges',
#  u'shelton',
#  u'translated',
#  u'spanish',
#  ...]

# %%
#this goes to slow - see this post for frequency filtering (if time):
#https://stackoverflow.com/questions/24688116/how-to-filter-out-words-with-low-tf-idf-in-a-corpus-with-gensim

# %%
all_tokens_set = set(b_l)
# %time
print "tokens set done"
tokens_once = set(word for word in all_tokens_set if b_l.count(word) <= 1)
# %time
print "part two done"
print [word for word in b_l if word not in tokens_once]
# %time
# Out:
# CPU times: user 20 µs, sys: 15 µs, total: 35 µs
# Wall time: 64.1 µs
# tokens set done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-d4dbe81969a9> in <module>()
#       2 get_ipython().magic(u'time')
#       3 print "tokens set done"
# ----> 4 tokens_once = set(word for word in all_tokens_set if b_l.count(word) <= 1)
#       5 get_ipython().magic(u'time')
#       6 print "part two done"
#
# <ipython-input-49-d4dbe81969a9> in <genexpr>((word,))
#       2 get_ipython().magic(u'time')
#       3 print "tokens set done"
# ----> 4 tokens_once = set(word for word in all_tokens_set if b_l.count(word) <= 1)
#       5 get_ipython().magic(u'time')
#       6 print "part two done"
#
# KeyboardInterrupt:

# %% [markdown]
# ## LDA Model

# %%
from gensim.models import ldamodel
from gensim.models import LdaMulticore

# %%
lda = ldamodel.LdaModel(corpus=corpus4,alpha='auto', id2word=dictionary2, \
                        num_topics=100, update_every=0, passes=20)
# %time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-7937757739b2> in <module>()
# ----> 1 lda = ldamodel.LdaModel(corpus=corpus4,alpha='auto', id2word=dictionary2,                         num_topics=100, update_every=0, passes=20)
#       2 get_ipython().magic(u'time')
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     328         self.state = LdaState(self.eta, (self.num_topics, self.num_terms))
#     329         self.state.sstats = self.random_state.gamma(100., 1. / 100., (self.num_topics, self.num_terms))
# --> 330         self.expElogbeta = np.exp(dirichlet_expectation(self.state.sstats))
#     331
#     332         # if a training corpus was provided, start estimating the model right away
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/matutils.pyc in dirichlet_expectation(alpha)
#     591         result = psi(alpha) - psi(np.sum(alpha))
#     592     else:
# --> 593         result = psi(alpha) - psi(np.sum(alpha, 1))[:, np.newaxis]
#     594     return result.astype(alpha.dtype)  # keep the same precision as input
#     595
#
# KeyboardInterrupt:

# %%
name = 'lda.model'
lda.save(outputs_dir + name)

# %%
print lda

# %%
lda_multi = LdaMulticore(corpus=corpus4, id2word=dictionary4, \
                        num_topics=100, passes=20, workers=4)
# %time
# Out:
# Process PoolWorker-4:
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Process PoolWorker-1:
# Process PoolWorker-2:
# Process PoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     self._target(*self._args, **self._kwargs)
#     initializer(*initargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.py", line 274, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#     initializer(*initargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.py", line 274, in worker_e_step
#     initializer(*initargs)
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/queues.py", line 115, in get
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.py", line 274, in worker_e_step
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.py", line 274, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#     chunk_no, chunk, worker_lda = input_queue.get()
#     self._rlock.acquire()
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/queues.py", line 115, in get
# KeyboardInterrupt
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/queues.py", line 115, in get
#     self._rlock.acquire()
#   File "/Users/rachelbrynsvold/anaconda/lib/python2.7/multiprocessing/queues.py", line 117, in get
#     self._rlock.acquire()
# KeyboardInterrupt
#     res = self._recv()
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-bebc4d622523> in <module>()
# ----> 1 lda_multi = LdaMulticore(corpus=corpus4, id2word=dictionary4,                         num_topics=100, passes=20, workers=4)
#       2 get_ipython().magic(u'time')
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.pyc in __init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics)
#     147             decay=decay, offset=offset, eval_every=eval_every, iterations=iterations,
#     148             gamma_threshold=gamma_threshold, random_state=random_state, minimum_probability= minimum_probability,
# --> 149             minimum_phi_value=minimum_phi_value, per_word_topics=per_word_topics)
#     150
#     151
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     333         if corpus is not None:
#     334             use_numpy = self.dispatcher is not None
# --> 335             self.update(corpus, chunks_as_numpy=use_numpy)
#     336
#     337     def init_dir_prior(self, prior, name):
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.pyc in update(self, corpus, chunks_as_numpy)
#     254             # wait for all outstanding jobs to finish
#     255             while queue_size[0] > 0:
# --> 256                 process_result_queue(force=True)
#     257
#     258             if reallen != lencorpus:
#
# /Users/rachelbrynsvold/anaconda/lib/python2.7/site-packages/gensim/models/ldamulticore.pyc in process_result_queue(force)
#     224                     queue_size[0] -= 1
#     225                     merged_new = True
# --> 226                 if (force and merged_new and queue_size[0] == 0) or (not self.batch and (other.numdocs >= updateafter)):
#     227                     self.do_mstep(rho(), other, pass_ > 0)
#     228                     other.reset()
#
# KeyboardInterrupt:

# %%
name = 'lda_multi.model'
lda_multi.save(outputs_dir + name)

# %%
print lda_multi

# %% [markdown]
# See the topics and their most significant terms

# %%
lda.show_topics()
#also lda.show_topics() - what is difference?

# %% [markdown]
# For a given document (in bow format), see most relevant topics

# %%
lda.get_document_topics(dictionary2.doc2bow(transform_txt_file_v2('1080-clean.txt')))

# %% [markdown]
# For a given term in vocab, see what topics are most likely/relevant

# %%
lda.get_term_topics(100, minimum_probability=0.00001)

# %% [markdown]
# Inverse of above

# %%
lda.get_topic_terms(1)

# %%
for tup in lda.get_topic_terms(0):
    print dictionary2[tup[0]]

# %%
#Document alignment
#softmax - zeroing - zero out all not in the top2 alignment
    #manually creat label from top word
    #need to include logic to use two topics if below certain threshhold
#projection - 
#cos sim
